# %% [markdown]
# #**1. TITLE**

# %% [markdown]
# # **Deep Learning Based Pre-trained Image Detection Architecture and Machine Learning Algorithms for Food Image Calorie Estimation**

# %% [markdown]
# #**BY BASSEY CHIBUIKE KALU**

# %% [markdown]
# #**2. BACKGROUND**

# %% [markdown]
# Obesity is said to happen when an individual’s Body Mass Index (BMI) is more than 30 Kg/m2 (Zheng et al., 2011). This is because of the difference between the amount of calories taken in and the energy expended by the individual. Obesity poses a health risk to people around the world. One great and sure way to combat this is to control our daily
# calorie intake. That is, by eating healthier food. Though packaged food may come with the calorie composition as a label on the packaging, not all food served in the restaurant have the calorie content displayed to the customer. This was what motivated some researchers to begin to think of ways of developing algorithms that are able to detect food
# and calculate the Calorie Contents using Artificial Intelligence (AI).
#
# In the field of AI, Machine and Deep Learning methods with computer vision techniques have found applications in several fields including food calorie estimation (Pouladzadeh et al., 2014;
# Jia et al., 2014; and Sun et al., 2008). Deep Convolutional Neural Network-based
# algorithms are able to detect and analyze static food images. This Deep Learning (DL) approach works by taking static food images as inputs. This image is often the top and side view of the static image. After which, the algorithm performs object detection using either of the pre-trained Deep Convolutional Neural Network (CNN) based architectures
# via the Transfer Learning method. Examples of some pre-trained Deep CNN are
# ResNet50 (He et al., 2016) and AlexNet (Krizhevsky et al., 2017). Next, the algorithm computes the contour of the food and estimates the volume therein. With the volume estimate, the amount of food calories the static image has is obtained.
#
# Today, there are a lot of operational food calorie estimation applications. For
# example, we have the Im2Calories application developed by Google research scientist called Kevin Murphy and unveiled at the rework Deep Learning Summit in Boston, USA in 2015 (Myers et al., 2015). The application works by combining visual analysis with
# pattern recognition. Its accuracy gets better as it is used. Another recent application is the Azati. The application is a calorie counting application that is able to instantly estimate
# the calorie content of any static food image based on analysis. The Foodvisor application is also a recent and powerful application that was launched in 2018 in France. The application can be used on a smartphone to photograph a meal and it identifies the food and computes the calorie count, fat, proteins, carbs, and fibers. Additionally, it includes a
# module that lets the user monitor their weight loss or gain with an input of height, weight, gender, and age.
#
# In recent literature, there are numerous studies that have applied DL and computer
# vision methods for food calorie estimation. Beginning from the older publication to the latest, we will briefly describe how these authors implemented their method.
#
# For example, Sun et al. proposed an electronic photographic method that uses an image processing algorithm to estimate food portion size and other quantitative information (Sun et al.,2008). The author’s method involves semi-automatic image segmentation, camera calibration, and the estimation of the food’s portion size. Experimental results obtained suggest that the mean error and standard deviation are between 5% and 8%.
#
# Jia et al proposed an accuracy of food portion size estimation using digital pictures they obtained by participants wearing a camera on their chests. The chest-worn electronic device is able to capture images of the food during lunch, which is then semiautomatically processed using the software. The software computes the volume of the food. Results obtained suggest that out of the 50 Western and 50 Asian food images evaluated and compared, the mean relative error between the estimated and actual volume is 2.8% and a standard deviation of 20.4%. Additionally, the computer estimates
# achieved less bias than those from three raters who estimated the volume of the food visually.
#
# Pouladzadeh et al. proposed a mobile cloud-based food calorie measurement
# system (Pouladzadeh et al., 2014). The food detection algorithm in this study uses an ML cloud-based Support Vector Machine (SVM) training mechanism. It also includes a userfriendly interface that allows a seamless computation of food calories before and after consumption. The user interface allows the capturing of the top and size of the food
# image, which is processed further using image segmentation methods to identify the
# various ingredient portions present in the food and estimate their sizes. Thereafter, the cloud-based ML SVM algorithm is used to identify the ingredient portions in the images.
# After which, the ingredient portion sizes computed earlier are used to compute the mass and subsequently the calories. Experimental results obtained suggest that the cloudbased ML SVM model achieved 99% accuracy in a single food portions classification task.
#
# Regarding Region Proposal Networks (RPNs) that assist object detection
# architectures to hypothesize object locations, Ren et al. proposed an RPN that shares full-image convolutional features with the detection algorithm (Ren et al., 2015). This is
# obtained by optimizing the RPN and the detection algorithm such as the VGG-16
# architecture and Fast R-CNN (Girshick et al., 2015; Simonyan and Zisserman, 2015) in training so that they share convolutional features. The method is evaluated over the PASCAL VOC 2007 detection dataset (Everingham et al., 2007). The mean Average
# Precision (mAP) metric is used to evaluate the detection, and experimental results obtained using the fast R-CNN and the VGG-1 architectures suggest that the learned RPN improves region proposal quality and the overall object detection accuracy.
#
# Ege and Yanai proposed a method of estimating food calories using multiple-dish food images over two types of food image datasets (Ege and Yanai, 2017). The method uses the fast R-CNN as the detection algorithm, and an image-based food calorie estimation method to evaluate the food calorie of each detected dish. The two study
# dataset include the school lunch dataset with the bounding box and the UEC FOOD-100, a Japanese food photo dataset. The experiment in the study is performed by training the faster R-CNN and the RPN modules using the approximate joint training method. For evaluation, the mean Average Precision (mAP) metric is used. Results obtained suggest the model performed with high accuracy.
#
# Lu et al. proposed an AI-based system for a dietary assessment called goFOODTM
# (Lu et al., 2020). The application is able to calculate the calorie content of a meal along with other macronutrients using either images or short videos taken from the user’s smartphone. For the detection, segmentation, and recognition of food images and short videos, the application uses Deep Neural networks based on the Mask-R CNN framework
# and Inception V3 (Szegedy et al., 2016) architecture. For food volume estimation, the application reconstructs the food 3D model using gravity data from the smartphone’s Inertia Measurement Unit (IMU). To estimate the nutrients in the meal, the application combines an online nutritional database with the estimated food volume. The experiment is performed over two food image databases including MADiMa, which is a centralEuropean style meal, and a McDonald’s international fast food database. Experimental results suggest that the application performed accurately on the fast food database.
#
# Lu et al. proposed an AI-based system to access the nutrient intake of hospital
# patients (Lu et al., 2020). The system works by processing the RGB depth of the image pairs obtained by the user before and after meal consumption. For performing food image segmentation, the system uses a novel multi-task contextual network. For food recognition, the system uses a few-shot learning-based classifier model trained via metalearning. For the estimation of consumed food volume, the system uses a 3D surface construction algorithm. Evaluation of the system’s performance over the study’s nutrient
# intake is greater than 0.91 correlated to the ground truth.
#
# The efficient training of any Deep CNN consumes a lot of image datasets, requiring techniques such as data augmentation. The data augmentation technique is able to prevent overfitting as it increases the size of a limited model training dataset. The technique is able to increase the amount of data by creating randomized variations and
# unique transformations of the original image dataset (Raschka et al., 2022). This can be achieved by flipping, cropping, resizing, etc., the image dataset. Models, such as the
# Generative Adversarial Network (GAN) proposed by Goodfellow et al., 2014 is able to perform data augmentation efficiently. Several studies have applied this method in various applications including Kuanar et al., 2019 and Antoniou et al., 2018.
#
# From the literature reviewed above, none of the studies have applied the state-of-the-art Deep CNN-based image detection algorithm such as the fast R-CNN architecture together with ML-based algortihms in food calorie estimation. In this study, we therefore propose a Deep Learning Based Pre-trained Image Detection Architecture and Machine Learning Algorithms for Food Image Calorie Estimation.

# %% [markdown]
# #**3. Aim & Objectives**

# %% [markdown]
# The main aim of the proposed study is to develop a Deep Learning Based Pre-trained Image Detection Architecture and Machine Learning Algorithms for Food Image Calorie Estimation. The objectives to achieve this aim are to:
#
# a. Review current literature on AI, including Deep and Machine Laerning techniques applied to food calorie estimation;
#
# b. Review the available food database built for food recognition tasks, food
# detection/segmentation, and food volume estimation tasks;
#
# c. Select the readily available and most current food database from (b) above, and prepare the data for food calorie estimation;
#
# d. Use the PYTHON TensorFlow Object Detection libraries to compile and build the Fast Deep CNN-based
# classifier architecture for object detection task;
#
# e. Obtain relevant information from the detected images, then use them to train, test, and evaluate three ML-based Regressors on image volume, and calorie estimation tasks; and
#
# f. Evaluate the performance of the application using the MAE, MSE, RMSE, and MAPE metrics.

# %% [markdown]
# #**4. Deliverables**
#
# The project is expected to deliver the following:
#
# A thesis to communicate its findings as a result of the novelty of the study.
#
# A Python source code used to build the application.
#
# A food database adopted for the study.
#
# A web-based application of the entire project if time permits us.

# %% [markdown]
# ##**Food Database**

# %% [markdown]
# Food databases consist of food recognition database, food detection/segmentation database, and food volume estimation database. Food recognition databases are used for food recognition tasks and consist of food images that are annotated with image-level labels. Food detection/segmentation databases often require additional annotation of food location on the images as against that of food recognition database. However, for food volume estimation databases, the annotation required are both image-level labels, pixel-level food segmentation map, and food volume ground truth. In this study, and as part of our second stated objectives, we will review briefly below the available food databases that are built for food recognition tasks, food detection/segementation, and food volume estimation tasks.

# %% [markdown]
# ###**1. UEC FOOD 100 Dataset**

# %% [markdown]
# UEC FOOD 100 Dataset contains 100-kind of food photos with each photo having a bounding box indicating the location of the food item in the photo. It was developed and intended for use in Japan by (Matsuda et al., 2012). The dataset is built to implement a practical food recognition system.

# %% [markdown]
# ###**2. FOOD 101 Dataset**

# %% [markdown]
# FOOD-101 Dataset is a publicly available dataset containing only standardized fast food images taken under laboratory conditions and created by (Bossard et al., 2014). It was created by collecting novel real-world food dataset from a website (foodspotting.com) that allows taking photos of images fo food while eating and uploading it online. The images are all rescaled to 512 pixels, and include diverse, visually, and semantically similar food classes such as Apple pie, waffles, omelette, etc.

# %% [markdown]
# ###**3. UNIMIB2016 FOOD DATASET**

# %% [markdown]
# The UNIMIB2016 FOOD Dataset is one of the dataset collected from a real canteen environment by (Ciocca et al., 2017). It includes a total of 1027 tray images, 73 food categories, and a total of 3616 food instances. All images are annotated and contain multiple foods with accurate segementation. This allows the ease of working on food segementation and quantity estimation methods.

# %% [markdown]
# ###**4. MULTIMEDIA FOOD DATABASE**

# %% [markdown]
# This new multimedia food database contains RGB images pf meals in addition to their corresponding depth maps, 3D models, segementation and recognition maps, weights, and volumes. It is created by (Allegra et al., 2017). The dataset is acquired in a controlled laboratory environment with both constrained and unconstrained set-ups. 80 served Central Europeans meals are involved in the dataset creation.

# %% [markdown]
# ###**5. ECUSTFD DATASET**

# %% [markdown]
# The ECUSTFD Dataset is created by Liang and Li, 2018. It consists of 19 kinds of food with annotations, volume, and mass records, including tomato, sachima, qiwi, plum, pear, peach, orange, moon cake, mix, mango, litchi, the lemon, grapes, fired_dough_twist, eggs, donuts, bun, bread, banana, and apple. Each pair of the images contains a top view and a side view, and a 1 CNY coin used as the calibration object.

# %% [markdown]
# ###**6. FOODX-251 DATASET**

# %% [markdown]
# The FOODX-251 Dataset is one with a fine-grained (prepared) food categories and 158k images obtained from the web. It was created by (Kaur et al., 2019). The dataset includes training, validation, and testing sets. 118k images are set aside for training using the datset, 12k images are set aside for validation, and 28k images are set aside for testing. Examples of food classes in the dataset that are fine-grained are cakes, sandwiches, puddlings, soups and pastas, etc.

# %% [markdown]
# ###**7. RECIPE 1M+ DATASET**

# %% [markdown]
# This is one of the newest large-scale food image dataset with over 1 million cooking recipes and 13 million food images created by Marin et al., 2021. It claims to be the largest publicly available cooking recipe dataset in the world. The dataset is collected by scraping over 24 popular website for cooking.

# %% [markdown]
# Given the various food databases reviewed above, coupled with limited computing resources, in this study, we will build and train our deep learning CNN-based architectures for food calorie estimation using the FOODX-251 dataset that is created by (Kaur et al., 2019). In the following sections, we will obtain this dataset from kaggle website and perform exploratory data analysis.

# %% [markdown]
# #**8. FRUITS 360 DATASET**

# %% [markdown]
# A high-quality, dataset of images containing fruits. The following fruits are included: Apples - (different varieties: Golden, Golden-Red, Granny Smith, Red, Red Delicious), Apricot, Avocado, Avocado ripe, Banana (Yellow, Red), Cactus fruit, Carambula, Cherry, Clementine, Cocos, Dates, Granadilla, Grape (Pink, White, White2), Grapefruit (Pink, White), Guava, Huckleberry, Kiwi, Kaki, Kumsquats, Lemon (normal, Meyer), Lime, Litchi, Mandarine, Mango, Maracuja, Nectarine, Orange, Papaya, Passion fruit, Peach, Pepino, Pear (different varieties, Abate, Monster, Williams), Pineapple, Pitahaya Red, Plum, Pomegranate, Quince, Raspberry, Salak, Strawberry, Tamarillo, Tangelo.
#
# **Dataset properties**
#
# Training set size: 28736 images.
#
# Validation set size: 9673 images.
#
# Number of classes: 60 (fruits).
#
# Image size: 100x100 pixels.
#
# The dataset was created by [23] following the procedures below:
#
# Fruits were planted in the shaft of a low speed motor (3 rpm) and a short movie of 20 seconds was recorded.
#
# A Logitech C920 camera was used for filming the fruits. This is one of the best webcams available.
#
# Behind the fruits we placed a white sheet of paper as background.
#
# However due to the variations in the lighting conditions, the background was not uniform and we wrote a dedicated algorithm which extract the fruit from the background. This algorithm is of flood fill type: we start from each edge of the image and we mark all pixels there, then we mark all pixels found in the neighborhood of the already marked pixels for which the distance between colors is less than a prescribed value. We repeat the previous step until no more pixels can be marked.
#
# All marked pixels are considered as being background (which is then filled with white) and the rest of pixels are considered as belonging to the object.
#
# The maximum value for the distance between 2 neighbor pixels is a parameter of the algorithm and is set (by trial and error) for each movie.

# %% [markdown]
# #**9. FOODD DATASET**

# %% [markdown]
# **FooDD:**
#
# It is a Food Detection Dataset of 3000 images created by [25]. The images offer variety of food photos taken from different cameras with different illuminations. In this dataset, careful attention was placed in generating the food images characteristics pertained to camera type, shooting angle,
# and illumination variations. A strong feature of the dataset is the good distribution
# of single and mixed food images. Thus, it can be used to facilitate testing and
# benchmarking of various food detection algorithms.
#
# In the dataset, the images are divided into 6 categories considering the capturing
# device, background, and lighting condition. Each category contains more
# than 100 images.
# Note that the thumb is used as a
# calibration means to determine the size of the food items in the image.

# %% [markdown]
# ###**First Mount the Google Drive**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ###**Check if GPU is connected and display its Details**

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# /bin/bash: nvidia-smi: command not found

# %% [markdown]
# ###**Download and Import Libraries and Dependencies**

# %%
import tensorflow as tf
import numpy as np

import os
import os.path as osp
import sys
import pandas as pd
import numpy as np
from os import makedirs
import typing
import random
import pdb
from time import time
import json
import re
import functools
import math
import requests
import datetime
from datetime import datetime
from datetime import date
import urllib.request
import inspect
import logging
import urllib
import zipfile
import copy
import tqdm
from tqdm.notebook import tqdm
import os.path as osp
from math import ceil
import IPython
import IPython.display
import requests
from collections import OrderedDict
from time import time
import PIL # image processing
from IPython.display import Image

import six.moves.urllib as urllib
import tarfile
import tensorflow as tf

from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt

# Helper function for visualization.
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from matplotlib import colors
import matplotlib.lines as mlines
from matplotlib import pyplot
import seaborn as sns
sns.set()
sns.set_style('whitegrid')
from matplotlib.pyplot import figure
import plotly.graph_objects as go
import io
from sklearn.cluster import KMeans
from sklearn.metrics.cluster import (v_measure_score, homogeneity_score, completeness_score)
from sklearn.metrics import roc_auc_score
from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_score
from typing import Optional, List, Union
from collections import defaultdict
from itertools import repeat
from collections import abc as container_abcs
import matplotlib as mpl
import mpl_toolkits
mpl_toolkits.__path__.append('/usr/lib/python3.7/dist-packages/mpl_toolkits/')
from typing import Collection, Optional, Union
from tqdm import tqdm
import community as louvain
from tqdm import tqdm
import tqdm.notebook # progress bar for jupyter notebook
import time
from time import time
from zipfile import ZipFile
import shutil

from random import shuffle
from sklearn.utils import shuffle

from sklearn.model_selection import train_test_split

from PIL import Image
import cv2

import tensorflow as tf
from glob import glob

from __future__ import print_function, division

import time
import os
import copy

from __future__ import print_function
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
from keras.utils.image_utils import img_to_array, array_to_img, load_img

import PIL.Image
from PIL import JpegImagePlugin
from google.colab.patches import cv2_imshow

import six.moves.urllib as urllib
import tarfile
import zipfile

from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image
from IPython.display import display

# !pip install tflearn
# !pip install segmentation-models-pytorch
# !pip install torchsummary
# !pip install -U albumentations

# CNN Model
import tflearn
from tflearn.layers.conv import conv_2d, max_pool_2d
from tflearn.layers.core import input_data, dropout, fully_connected
from tflearn.layers.estimator import regression
import tensorflow as tf

from sklearn.model_selection import train_test_split

from torch.utils.data import Dataset , DataLoader
from torchvision import transforms as T
import torchvision
import torch.nn.functional as F
from torch.autograd import Variable

import torchvision.transforms as transforms
import torchvision.models as models
import torch.optim as optim
import torch.nn.modules.loss
import torch.nn.modules.normalization as norm

from PIL import Image
import cv2
import albumentations as A

from torchsummary import summary
import segmentation_models_pytorch as smp

import tensorflow as tf
from glob import glob
import cv2
from skimage.transform import AffineTransform, warp
from skimage import io, img_as_ubyte
from scipy.ndimage import rotate
from albumentations.augmentations.crops.transforms import CropNonEmptyMaskIfExists, RandomCrop
import albumentations as A

from __future__ import print_function, division

from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
from torchvision import datasets, models, transforms
import time
import copy

cudnn.benchmark = True
plt.ion()   # interactive mode

device =torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tflearn
#   Downloading tflearn-0.5.0.tar.gz (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.3/107.3 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tflearn) (1.22.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from tflearn) (1.16.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from tflearn) (8.4.0)
# Building wheels for collected packages: tflearn
#   Building wheel for tflearn (setup.py) ... done
#   Created wheel for tflearn: filename=tflearn-0.5.0-py3-none-any.whl size=127299 sha256=3618e1cba627f3c622664b733a28b8ed0df60e350e9b8fe7bb0d70d60e888a73
#   Stored in directory: /root/.cache/pip/wheels/55/fb/7b/e06204a0ceefa45443930b9a250cb5ebe31def0e4e8245a465
# Successfully built tflearn
# Installing collected packages: tflearn
# Successfully installed tflearn-0.5.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting segmentation-models-pytorch
#   Downloading segmentation_models_pytorch-0.3.2-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 5.9 MB/s eta 0:00:00
# Collecting timm==0.6.12
#   Downloading timm-0.6.12-py3-none-any.whl (549 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 kB 26.9 MB/s eta 0:00:00
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (0.15.1+cu118)
# Collecting efficientnet-pytorch==0.7.1
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (4.65.0)
# Collecting pretrainedmodels==0.7.4
#   Downloading pretrainedmodels-0.7.4.tar.gz (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (8.4.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2.0.0+cu118)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm==0.6.12->segmentation-models-pytorch) (6.0)
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 18.4 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (2.27.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (1.22.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (1.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.12.0)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (16.0.2)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.25.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm==0.6.12->segmentation-models-pytorch) (23.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm==0.6.12->segmentation-models-pytorch) (2023.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from munch->pretrainedmodels==0.7.4->segmentation-models-pytorch) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (1.3.0)
# Building wheels for collected packages: efficientnet-pytorch, pretrainedmodels
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16444 sha256=f88fbadb0efd0285a7117fa7e7dc2035f154ab31b4521b3178280835e9ee705d
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60962 sha256=23c0d3e4ec150277a1e47ede13b23ed99eda2894c42c8f04f9718a901bf8203e
#   Stored in directory: /root/.cache/pip/wheels/35/cb/a5/8f534c60142835bfc889f9a482e4a67e0b817032d9c6883b64
# Successfully built efficientnet-pytorch pretrainedmodels
# Installing collected packages: munch, huggingface-hub, timm, pretrainedmodels, efficientnet-pytorch, segmentation-models-pytorch
# Successfully installed efficientnet-pytorch-0.7.1 huggingface-hub-0.14.1 munch-2.5.0 pretrainedmodels-0.7.4 segmentation-models-pytorch-0.3.2 timm-0.6.12
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.10/dist-packages (1.5.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: albumentations in /usr/local/lib/python3.10/dist-packages (1.2.1)
# Collecting albumentations
#   Downloading albumentations-1.3.0-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.5/123.5 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from albumentations) (6.0)
# Requirement already satisfied: scikit-image>=0.16.1 in /usr/local/lib/python3.10/dist-packages (from albumentations) (0.19.3)
# Requirement already satisfied: qudida>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from albumentations) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from albumentations) (4.7.0.72)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from albumentations) (1.10.1)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from albumentations) (1.22.4)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from qudida>=0.0.4->albumentations) (1.2.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from qudida>=0.0.4->albumentations) (4.5.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (2023.4.12)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (8.4.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (3.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (23.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (1.4.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (3.1.0)
# Installing collected packages: albumentations
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 1.2.1
#     Uninstalling albumentations-1.2.1:
#       Successfully uninstalled albumentations-1.2.1
# Successfully installed albumentations-1.3.0
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# ##**Obtain the ECUST Food Dataset (ECUSTFD) from Github Page**

# %% [markdown]
# ECUSTFD is a free public food image dataset with 19 types of food. The number of food images is 2978. The number of images and the number of objects for the same type are:
#
# 1. apple
# 2. orange
# 3. apple
# 4. banana
# 5. qiwi
# 6. mango
# 7. tomato
# 8. lemon
# 9. pear
# 10. sachima
# 11. plum
# 12. peach
# 13. egg
# 14. litchi
# 15. grape
# 16. fired dough twist
# 17. bread
# 18. bun
# 19. doughnut
#
# To create the Dataset:
#
# Using a smart phone camera, the authors took several groups of images of a single food portion. Each group of images contains a top view and a side view of the food. For each image, there is only one coin as calibration object and no more than two foods in it. If there are two food in the same image, the type of one food is different from another. In this dataset, the original image is resized to 1000 * 1000.
#
# The diameter of the Coin used as calibration object is 25.0mm. Each food item and the calibration object are palced on either a white plate or a red plate before taking the picture. The white plate's diameter is about 20.7cm and its height is about 2.0cm; the red plate's diameter is about 18.7cm and its height is about 2.0cm.
#
# In the ECUSTFD, there are images, annotations of the images, and an excel file with the food volume and quality information.

# %% [markdown]
# **Download the Resized ECUST Dataset**

# %%
# !git clone https://github.com/Liang-yc/ECUSTFD-resized-.git
# %cd ECUSTFD-resized-
# Out:
# Cloning into 'ECUSTFD-resized-'...
# remote: Enumerating objects: 9232, done.
# remote: Total 9232 (delta 0), reused 0 (delta 0), pack-reused 9232
# Receiving objects: 100% (9232/9232), 124.79 MiB | 23.92 MiB/s, done.
# Resolving deltas: 100% (6129/6129), done.
# Updating files: 100% (5962/5962), done.
# /content/ECUSTFD-resized-

# %% [markdown]
# **Exploratory Data Analysis (EDA) - ECUSTFD Image Dataset**

# %%
# Upload the Image Dataset
print(os.listdir("/content/ECUSTFD-resized-/JPEGImages"))
# Out:
# ['orange015T(2).JPG', 'egg005S(5).JPG', 'sachima001S(8).JPG', 'orange011S(11).JPG', 'mango001S(4).JPG', 'plum001S(15).JPG', 'fired_dough_twist004S(10).JPG', 'pear002T(17).JPG', 'fired_dough_twist004T(4).JPG', 'doughnut007S(1).JPG', 'doughnut004S(3).JPG', 'mix006S(2).JPG', 'peach004S(1).JPG', 'egg003S(5).JPG', 'orange012T(7).JPG', 'pear002T(14).JPG', 'sachima005T(4).JPG', 'bun002S(5).JPG', 'plum003T(7).JPG', 'bun004T(7).JPG', 'banana009T(5).JPG', 'mix008S(4).JPG', 'orange003T(1).JPG', 'grape002S(7).JPG', 'mango006S(11).JPG', 'apple007S(4).JPG', 'mooncake002T(12).JPG', 'doughnut009T(2).JPG', 'bread007S(4).JPG', 'banana014T(4).JPG', 'doughnut008S(8).JPG', 'apple008S(3).JPG', 'tomato004T(26).JPG', 'egg004S(2).JPG', 'doughnut004T(12).JPG', 'qiwi006S(5).JPG', 'plum003S(11).JPG', 'mooncake003T(13).JPG', 'doughnut008S(11).JPG', 'lemon003T(2).JPG', 'apple017S(10).JPG', 'tomato004S(25).JPG', 'doughnut007S(12).JPG', 'lemon002T(19).JPG', 'litchi005S(2).JPG', 'mango003S(7).JPG', 'orange013T(2).JPG', 'pear005S(6).JPG', 'peach005S(3).JPG', 'mix008T(1).JPG', 'sachima001S(4).JPG', 'apple015T(10).JPG', 'mango008S(3).JPG', 'peach005T(5).JPG', 'mooncake005T(3).JPG', 'orange008S(21).JPG', 'bread001S(2).JPG', 'banana015S(6).JPG', 'mooncake002T(13).JPG', 'qiwi007S(4).JPG', 'plum004T(18).JPG', 'apple004T(1).JPG', 'plum003S(21).JPG', 'plum001S(6).JPG', 'lemon001T(6).JPG', 'lemon003S(8).JPG', 'lemon004S(5).JPG', 'plum003S(4).JPG', 'grape001T(2).JPG', 'mooncake004S(4).JPG', 'lemon004S(8).JPG', 'pear001S(2).JPG', 'apple016T(14).JPG', 'egg007S(8).JPG', 'apple017T(25).JPG', 'pear005S(1).JPG', 'banana013T(5).JPG', 'qiwi004S(7).JPG', 'grape001T(11).JPG', 'doughnut003T(1).JPG', 'apple017S(3).JPG', 'pear002T(15).JPG', 'bread003T(3).JPG', 'mango002S(4).JPG', 'grape002S(11).JPG', 'litchi004S(7).JPG', 'bread001T(5).JPG', 'mango007T(7).JPG', 'pear004T(14).JPG', 'pear005S(2).JPG', 'lemon003T(18).JPG', 'plum004T(14).JPG', 'apple014S(6).JPG', 'doughnut004S(13).JPG', 'pear003S(13).JPG', 'doughnut008S(6).JPG', 'lemon003S(4).JPG', 'mooncake004S(1).JPG', 'doughnut007T(1).JPG', 'pear004T(4).JPG', 'mooncake002T(8).JPG', 'sachima001S(10).JPG', 'pear002T(19).JPG', 'orange008T(7).JPG', 'mango005S(1).JPG', 'mix010S(3).JPG', 'lemon002T(10).JPG', 'lemon001T(15).JPG', 'orange009S(12).JPG', 'mango002T(2).JPG', 'tomato004T(22).JPG', 'lemon003T(4).JPG', 'doughnut007S(4).JPG', 'lemon004S(3).JPG', 'plum003S(8).JPG', 'lemon002S(19).JPG', 'bun002T(1).JPG', 'litchi003S(1).JPG', 'mango003T(10).JPG', 'banana010S(5).JPG', 'litchi001S(6).JPG', 'banana012T(1).JPG', 'mango001T(2).JPG', 'banana012T(2).JPG', 'banana011T(8).JPG', 'egg004S(4).JPG', 'mooncake001S(6).JPG', 'plum003T(6).JPG', 'tomato004T(14).JPG', 'orange006S(4).JPG', 'plum003T(3).JPG', 'doughnut004S(4).JPG', 'lemon004T(2).JPG', 'orange008T(12).JPG', 'fired_dough_twist005T(4).JPG', 'sachima003S(1).JPG', 'tomato002S(8).JPG', 'apple017S(1).JPG', 'orange010T(6).JPG', 'tomato003T(10).JPG', 'peach002T(7).JPG', 'doughnut006S(12).JPG', 'apple012T(5).JPG', 'lemon004S(11).JPG', 'banana001T(3).JPG', 'tomato004T(4).JPG', 'egg007S(4).JPG', 'orange011T(13).JPG', 'fired_dough_twist005S(3).JPG', 'qiwi008S(3).JPG', 'orange008T(6).JPG', 'plum002T(6).JPG', 'doughnut009T(11).JPG', 'mango004T(1).JPG', 'bread007S(1).JPG', 'bread006S(3).JPG', 'egg002s(3).JPG', 'banana010S(4).JPG', 'banana012S(4).JPG', 'pear003T(11).JPG', 'mooncake001T(7).JPG', 'apple017T(18).JPG', 'banana014S(3).JPG', 'mooncake003S(8).JPG', 'plum002S(5).JPG', 'mooncake003T(9).JPG', 'plum002S(10).JPG', 'tomato003T(24).JPG', 'apple017T(27).JPG', 'tomato003T(28).JPG', 'apple014S(5).JPG', 'mooncake002T(3).JPG', 'egg003S(4).JPG', 'peach004S(12).JPG', 'peach001S(7).JPG', 'lemon003S(10).JPG', 'egg001S(1).JPG', 'tomato004T(21).JPG', 'tomato003T(8).JPG', 'apple017T(14).JPG', 'banana010T(8).JPG', 'bun007T(1).JPG', 'fired_dough_twist007S(7).JPG', 'orange008S(8).JPG', 'doughnut005S(3).JPG', 'orange010T(12).JPG', 'doughnut007T(10).JPG', 'egg001T(5).JPG', 'mango007S(13).JPG', 'apple017S(22).JPG', 'mang ...

# %%
print(len(os.listdir("/content/ECUSTFD-resized-/JPEGImages/test")))
# Out:
# 338

# %%
# Upload the Annotation Image Dataset
print(os.listdir("/content/ECUSTFD-resized-/Annotations"))
# Out:
# ['apple015S(1).xml', 'doughnut004S(9).xml', 'litchi003T(5).xml', 'sachima002S(10).xml', 'orange002S(3).xml', 'litchi005S(6).xml', 'banana010T(1).xml', 'apple013T(4).xml', 'plum004T(17).xml', 'banana015S(6).xml', 'litchi005T(2).xml', 'lemon003T(18).xml', 'qiwi006T(9).xml', 'mango010T(5).xml', 'peach005T(1).xml', 'apple010T(1).xml', 'qiwi008S(7).xml', 'grape002T(6).xml', 'bread007S(8).xml', 'apple016T(11).xml', 'fired_dough_twist006T(1).xml', 'lemon002S(22).xml', 'fired_dough_twist002S(1).xml', 'litchi004S(4).xml', 'apple008S(4).xml', 'lemon002T(14).xml', 'qiwi003S(4).xml', 'orange013T(5).xml', 'doughnut008T(5).xml', 'tomato001T(3).xml', 'banana015S(1).xml', 'apple017S(24).xml', 'qiwi005S(5).xml', 'apple002S(2).xml', 'apple017T(25).xml', 'mango003S(11).xml', 'sachima005T(5).xml', 'orange010T(10).xml', 'mango008T(8).xml', 'apple004T(2).xml', 'bread001S(3).xml', 'orange012T(7).xml', 'mooncake003S(7).xml', 'apple017S(5).xml', 'apple018T(6).xml', 'egg007S(6).xml', 'tomato001S(5).xml', 'qiwi005T(6).xml', 'doughnut009S(14).xml', 'peach004S(19).xml', 'lemon003T(14).xml', 'apple003S(4).xml', 'lemon001T(16).xml', 'doughnut006S(2).xml', 'plum002T(5).xml', 'plum003T(4).xml', 'tomato003S(9).xml', 'tomato003T(5).xml', 'plum001T(1).xml', 'mooncake002T(3).xml', 'mango004S(5).xml', 'mooncake002T(14).xml', 'tomato004S(24).xml', 'sachima005S(21).xml', 'pear004S(14).xml', 'lemon002S(9).xml', 'pear005S(4).xml', 'banana005S(1).xml', 'grape002S(11).xml', 'fired_dough_twist007S(6).xml', 'mooncake002S(6).xml', 'grape001S(6).xml', 'orange011S(3).xml', 'banana012S(5).xml', 'orange006T(3).xml', 'banana001S(1).xml', 'sachima005S(18).xml', 'mooncake003S(3).xml', 'sachima001S(8).xml', 'mooncake004S(4).xml', 'mooncake006T(5).xml', 'doughnut004S(1).xml', 'peach001T(15).xml', 'tomato004T(25).xml', 'mix004S(3).xml', 'mix012S(4).xml', 'bread007S(6).xml', 'mooncake003T(11).xml', 'peach004T(14).xml', 'pear002S(4).xml', 'plum004S(23).xml', 'mango009T(6).xml', 'pear003T(1).xml', 'fired_dough_twist007S(7).xml', 'sachima004S(12).xml', 'orange009S(14).xml', 'orange008T(18).xml', 'mango002T(2).xml', 'qiwi005T(7).xml', 'lemon001S(17).xml', 'egg004S(4).xml', 'mooncake002S(17).xml', 'tomato003T(28).xml', 'orange007S(8).xml', 'sachima002S(15).xml', 'qiwi008T(2).xml', 'lemon001S(7).xml', 'qiwi008S(5).xml', 'mango010S(11).xml', 'sachima003S(7).xml', 'apple002S(5).xml', 'egg007T(6).xml', 'bread007S(3).xml', 'orange006S(4).xml', 'doughnut007T(4).xml', 'mango009T(4).xml', 'sachima003T(2).xml', 'qiwi006S(4).xml', 'grape001S(3).xml', 'doughnut006T(6).xml', 'orange011T(12).xml', 'fired_dough_twist004T(10).xml', 'orange013S(1).xml', 'fired_dough_twist002T(4).xml', 'egg002T(6).xml', 'plum001T(15).xml', 'mooncake006S(1).xml', 'orange001S(2).xml', 'banana013T(4).xml', 'mooncake002S(3).xml', 'egg001S(6).xml', 'tomato002T(13).xml', 'sachima005S(8).xml', 'banana008T(1).xml', 'mix002S(4).xml', 'lemon003S(9).xml', 'lemon004T(9).xml', 'mix008T(3).xml', 'apple013S(5).xml', 'mango009S(4).xml', 'doughnut005T(10).xml', 'lemon001S(18).xml', 'fired_dough_twist007S(2).xml', 'mooncake006S(8).xml', 'doughnut005T(14).xml', 'banana008T(3).xml', 'apple016T(10).xml', 'lemon001T(15).xml', 'doughnut009T(8).xml', 'apple015S(13).xml', 'pear001T(15).xml', 'orange008S(10).xml', 'sachima004T(10).xml', 'mix006S(3).xml', 'tomato004T(9).xml', 'apple007T(3).xml', 'apple015S(11).xml', 'orange010T(13).xml', 'sachima003S(5).xml', 'plum003T(17).xml', 'sachima005S(17).xml', 'lemon001S(9).xml', 'doughnut006T(13).xml', 'bun004T(4).xml', 'orange015T(3).xml', 'doughnut008T(14).xml', 'qiwi005S(7).xml', 'peach001S(3).xml', 'banana012S(7).xml', 'pear003T(2).xml', 'pear003T(12).xml', 'orange008S(14).xml', 'tomato004T(4).xml', 'mango009T(12).xml', 'peach005S(2).xml', 'mix010S(3).xml', 'orange006T(2).xml', 'apple018S(7).xml', 'peach004T(5).xml', 'plum003S(12).xml', 'mango007S(11).xml', 'mix007T(2).xml', 'mango007S(7).xml', 'qiwi008S(4).xml', 'mooncake002S(15).xml', 'doughnut008S(5).xml', 'banana011S(4).xml', 'apple015S(8).xml', 'd ...

# %%
IMG_MODE = 'RGB'
IMG_SIDE = 1000

def parseFolder(folder, ext):
    filelist = os.listdir(folder)
    imgfiles = []
    for i, file in tqdm.notebook.tqdm(enumerate(filelist), total=len(filelist)):
        if file.endswith(ext):
            imgfiles.append(os.path.join(folder, file))

    # Calling DataFrame constructor on list
    df = pd.DataFrame(data=imgfiles, columns=["filename"])
    return df

def makePatchwork(files, width, height):
    patchwork = PIL.Image.new(IMG_MODE, (IMG_SIDE * width, IMG_SIDE * height))
    matrix = [[(files[y*height+x], x, y) for x in range(width)] for y in range(height)]
    patches = [item for sublist in matrix for item in sublist]
    for (f, x, y) in patches:
        patchwork.paste(PIL.Image.open(f), (x * IMG_SIDE, y * IMG_SIDE))
    return patchwork

# Upload the Image images
image_dataset = os.path.join('/content/ECUSTFD-resized-/JPEGImages')

# parsing folder for JPG files
image_dataset = parseFolder(image_dataset, ".JPG")

print('=============================================================================')
print("Total number of images (128x128px): {}".format(len(image_dataset.index)))
print('=============================================================================')
print(image_dataset.head(10))
print('=============================================================================')
# Out:
#   0%|          | 0/2978 [00:00<?, ?it/s]
# =============================================================================
# Total number of images (128x128px): 2978
# =============================================================================
#                                             filename
# 0  /content/ECUSTFD-resized-/JPEGImages/orange015...
# 1  /content/ECUSTFD-resized-/JPEGImages/egg005S(5...
# 2  /content/ECUSTFD-resized-/JPEGImages/sachima00...
# 3  /content/ECUSTFD-resized-/JPEGImages/orange011...
# 4  /content/ECUSTFD-resized-/JPEGImages/mango001S...
# 5  /content/ECUSTFD-resized-/JPEGImages/plum001S(...
# 6  /content/ECUSTFD-resized-/JPEGImages/fired_dou...
# 7  /content/ECUSTFD-resized-/JPEGImages/pear002T(...
# 8  /content/ECUSTFD-resized-/JPEGImages/fired_dou...
# 9  /content/ECUSTFD-resized-/JPEGImages/doughnut0...
# =============================================================================

# %% [markdown]
# **Visualize the Image Dataset**

# %%
## Display some images:

# sample 100 images from the dataset
sampled = image_dataset.sample(100)

# retrieve the corresponding filenames
files = [ i for i in sampled['filename'] ]

# make a patchwork
patchwork = makePatchwork(files, 10, 10)

# display it inline
plt.figure(figsize=(10, 10))
plt.axis('off')
plt.title("Patchwork of the ECUSTFD Images Dataset", size = 20, fontweight='bold')
plt.imshow(patchwork)
today = date.today()
plt.annotate(f"Bassey Kalu {today}.",
             xy=(1, 1),  xycoords='data',
             xytext=(-0.1, -0.05), textcoords='axes fraction',
             color='black')

# save the image
patchwork.save('image_dataset_sampled.jpg')

# %%
sampled = sampled
plt.figure(figsize=(10, 10))
for i in range(12):
  img = cv2.imread(sampled.iloc[i]['filename'])
  plt.subplot(3, 4, i + 1)
  plt.suptitle("Sample of the ECUSTFD Images Dataset", size = 20, fontweight='bold')
  plt.imshow(img)

# %% [markdown]
# **Convert Image Dataset to CSV**

# %%
train_folder = '/content/ECUSTFD-resized-/JPEGImages/'

files_in_train = sorted(os.listdir(train_folder))
images=[i for i in files_in_train]

df = pd.DataFrame()
df['images']=[train_folder+str(x) for x in images]

# write the DataFrame to a CSV file
df.to_csv('/content/ecustfd.csv', header=None)

# %%
print(df.shape)
# Out:
# (2978, 1)

# %%
df.columns
# Out:
# Index(['images'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2978 entries, 0 to 2977
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   images  2978 non-null   object
# dtypes: object(1)
# memory usage: 23.4+ KB

# %%
df.isnull().sum()
# Out:
# images    0
# dtype: int64

# %%
df['images'].value_counts()
# Out:
# /content/ECUSTFD-resized-/JPEGImages/apple001S(1).JPG                1
# /content/ECUSTFD-resized-/JPEGImages/orange011S(11).JPG              1
# /content/ECUSTFD-resized-/JPEGImages/orange010T(3).JPG               1
# /content/ECUSTFD-resized-/JPEGImages/orange010T(4).JPG               1
# /content/ECUSTFD-resized-/JPEGImages/orange010T(5).JPG               1
#                                                                     ..
# /content/ECUSTFD-resized-/JPEGImages/fired_dough_twist003T(3).JPG    1
# /content/ECUSTFD-resized-/JPEGImages/fired_dough_twist003T(4).JPG    1
# /content/ECUSTFD-resized-/JPEGImages/fired_dough_twist003T(5).JPG    1
# /content/ECUSTFD-resized-/JPEGImages/fired_dough_twist003T(6).JPG    1
# /content/ECUSTFD-resized-/JPEGImages/tomato004T(9).JPG               1
# Name: images, Length: 2978, dtype: int64

# %% [markdown]
# #**USING THE ECUST FOOD DATASET**

# %% [markdown]
# **Git Clone the Application**

# %%
# !git clone https://github.com/HaaaToka/SeeFood.git
# Out:
# Cloning into 'SeeFood'...
# remote: Enumerating objects: 65, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 65 (delta 1), reused 6 (delta 1), pack-reused 56
# Unpacking objects: 100% (65/65), 49.54 MiB | 3.67 MiB/s, done.
# Updating files: 100% (35/35), done.
# Filtering content: 100% (2/2), 126.81 MiB | 51.57 MiB/s, done.

# %%
# %cd /content/SeeFood/
# Out:
# [Errno 2] No such file or directory: '/content/SeeFood/'
# /content/ECUSTFD-resized-

# %% [markdown]
# ##**Prepare the Data for Modeling**

# %% [markdown]
# **Function to Clean the Data**

# %%
os.mkdir("/content/ECUSTFD-resized-/Dataset/")
import xml.etree.ElementTree as ET

path="/content/ECUSTFD-resized-/Annotations"
for elem in os.listdir(path):
    print(elem)
    inpath = path+"/"+elem
    inputfile = open(inpath,'r')
    out = open('/content/ECUSTFD-resized-/Dataset/'+elem, 'w')

    t=0
    for line in inputfile.readlines():
        if 'owner' in line or t>0:
            t+=1
            if t==4:
                t=0
            continue

        print(line,file=out,end='')
# Out:
# apple015S(1).xml
# doughnut004S(9).xml
# litchi003T(5).xml
# sachima002S(10).xml
# orange002S(3).xml
# litchi005S(6).xml
# banana010T(1).xml
# apple013T(4).xml
# plum004T(17).xml
# banana015S(6).xml
# litchi005T(2).xml
# lemon003T(18).xml
# qiwi006T(9).xml
# mango010T(5).xml
# peach005T(1).xml
# apple010T(1).xml
# qiwi008S(7).xml
# grape002T(6).xml
# bread007S(8).xml
# apple016T(11).xml
# fired_dough_twist006T(1).xml
# lemon002S(22).xml
# fired_dough_twist002S(1).xml
# litchi004S(4).xml
# apple008S(4).xml
# lemon002T(14).xml
# qiwi003S(4).xml
# orange013T(5).xml
# doughnut008T(5).xml
# tomato001T(3).xml
# banana015S(1).xml
# apple017S(24).xml
# qiwi005S(5).xml
# apple002S(2).xml
# apple017T(25).xml
# mango003S(11).xml
# sachima005T(5).xml
# orange010T(10).xml
# mango008T(8).xml
# apple004T(2).xml
# bread001S(3).xml
# orange012T(7).xml
# mooncake003S(7).xml
# apple017S(5).xml
# apple018T(6).xml
# egg007S(6).xml
# tomato001S(5).xml
# qiwi005T(6).xml
# doughnut009S(14).xml
# peach004S(19).xml
# lemon003T(14).xml
# apple003S(4).xml
# lemon001T(16).xml
# doughnut006S(2).xml
# plum002T(5).xml
# plum003T(4).xml
# tomato003S(9).xml
# tomato003T(5).xml
# plum001T(1).xml
# mooncake002T(3).xml
# mango004S(5).xml
# mooncake002T(14).xml
# tomato004S(24).xml
# sachima005S(21).xml
# pear004S(14).xml
# lemon002S(9).xml
# pear005S(4).xml
# banana005S(1).xml
# grape002S(11).xml
# fired_dough_twist007S(6).xml
# mooncake002S(6).xml
# grape001S(6).xml
# orange011S(3).xml
# banana012S(5).xml
# orange006T(3).xml
# banana001S(1).xml
# sachima005S(18).xml
# mooncake003S(3).xml
# sachima001S(8).xml
# mooncake004S(4).xml
# mooncake006T(5).xml
# doughnut004S(1).xml
# peach001T(15).xml
# tomato004T(25).xml
# mix004S(3).xml
# mix012S(4).xml
# bread007S(6).xml
# mooncake003T(11).xml
# peach004T(14).xml
# pear002S(4).xml
# plum004S(23).xml
# mango009T(6).xml
# pear003T(1).xml
# fired_dough_twist007S(7).xml
# sachima004S(12).xml
# orange009S(14).xml
# orange008T(18).xml
# mango002T(2).xml
# qiwi005T(7).xml
# lemon001S(17).xml
# egg004S(4).xml
# mooncake002S(17).xml
# tomato003T(28).xml
# orange007S(8).xml
# sachima002S(15).xml
# qiwi008T(2).xml
# lemon001S(7).xml
# qiwi008S(5).xml
# mango010S(11).xml
# sachima003S(7).xml
# apple002S(5).xml
# egg007T(6).xml
# bread007S(3).xml
# orange006S(4).xml
# doughnut007T(4).xml
# mango009T(4).xml
# sachima003T(2).xml
# qiwi006S(4).xml
# grape001S(3).xml
# doughnut006T(6).xml
# orange011T(12).xml
# fired_dough_twist004T(10).xml
# orange013S(1).xml
# fired_dough_twist002T(4).xml
# egg002T(6).xml
# plum001T(15).xml
# mooncake006S(1).xml
# orange001S(2).xml
# banana013T(4).xml
# mooncake002S(3).xml
# egg001S(6).xml
# tomato002T(13).xml
# sachima005S(8).xml
# banana008T(1).xml
# mix002S(4).xml
# lemon003S(9).xml
# lemon004T(9).xml
# mix008T(3).xml
# apple013S(5).xml
# mango009S(4).xml
# doughnut005T(10).xml
# lemon001S(18).xml
# fired_dough_twist007S(2).xml
# mooncake006S(8).xml
# doughnut005T(14).xml
# banana008T(3).xml
# apple016T(10).xml
# lemon001T(15).xml
# doughnut009T(8).xml
# apple015S(13).xml
# pear001T(15).xml
# orange008S(10).xml
# sachima004T(10).xml
# mix006S(3).xml
# tomato004T(9).xml
# apple007T(3).xml
# apple015S(11).xml
# orange010T(13).xml
# sachima003S(5).xml
# plum003T(17).xml
# sachima005S(17).xml
# lemon001S(9).xml
# doughnut006T(13).xml
# bun004T(4).xml
# orange015T(3).xml
# doughnut008T(14).xml
# qiwi005S(7).xml
# peach001S(3).xml
# banana012S(7).xml
# pear003T(2).xml
# pear003T(12).xml
# orange008S(14).xml
# tomato004T(4).xml
# mango009T(12).xml
# peach005S(2).xml
# mix010S(3).xml
# orange006T(2).xml
# apple018S(7).xml
# peach004T(5).xml
# plum003S(12).xml
# mango007S(11).xml
# mix007T(2).xml
# mango007S(7).xml
# qiwi008S(4).xml
# mooncake002S(15).xml
# doughnut008S(5).xml
# banana011S(4).xml
# apple015S(8).xml
# doughnut005T(13).xml
# qiwi006T(10).xml
# banana003S(2).xml
# lemon004T(1).xml
# orange010T(3).xml
# orange010T(8).xml
# apple019T(6).xml
# litchi003S(5).xml
# tomato004T(23).xml
# doughnut005S(14).xml
# sachima004S(4).xml
# peach004T(6).xml
# qiwi008S(6).xml
# egg001T(7).xml
# mooncake001T(12).xml
# peach003S(2).xml
# lemon002S(5).xml
# sachima005S(16).xml
# egg003T(1).xml
# lemon001S(16).xml
# mooncake001S(12).xml
# mooncake002S(5).xml
# apple016T(23).xml
# pear003T(8).xml
# sachima002T(2).xml
# peach003T(6).xml
# mooncake001S(9).xml
# apple018S(5).xml
# sachima003T(1).xml
# apple018T(4).xml
# apple011S(5).xml
# apple017T(20).xml
# tomato004T(24).xml
# pear006S(8).xml
# orange003T(8).xml
# litchi005T(8).xml
# orange012S(4).xml
# mango010T(2).xml
# sachima001T(5).xml
# lemon002T(23).xml
# qiwi005T(1).xml
# banana015T(2).xml
# mooncake002T(10).xml
# orange015S(6).xml
# fired_dough_twist004T(6).xml
# egg005S(4).xml
# plum004S(6).xml
# orange003S(5).xml
# lemon001T(2).xml
# mango001S(8).xml
# qiwi007T(11).xml
# plum003T(14).xml
# banana003S(3).xml
# pear001S(1).xml
# apple019T(1).xml
# lemon002S(10).xml
# doughnut009S(11).xml
# egg001S(4).xml
# apple012T(5).xml
# mango001T(7).xml
# peach004S(5).xml
# qiwi002T(2).xml
# mix001T(1).xml
# bun001T(3).xml
# apple016T(5).xml
# peach003S(9).xml
# mooncake002S(12).xml
# mango002T(6).xml
# litchi005T(1).xml
# fired_dough_twist004S(1).xml
# bun006S(8).xml
# fired_dough_twist007S(5).xml
# bread007T(8).xml
# peach005T(10).xml
# litchi001T(4).xml
# egg006T(5).xml
# fired_dough_twist004S(2).xml
# plum002S(3).xml
# mango002T(9).xml
# tomato003S(3).xml
# mango006S(3).xml
# apple017S(9).xml
# mooncake003S(8).xml
# doughnut008S(8).xml
# banana013S(9).xml
# fired_dough_twist007S(1).xml
# bun004S(3).xml
# fired_dough_twist001T(4).xml
# mix014S(3).xml
# qiwi004T(6).xml
# pear002T(16).xml
# sachima005T(10).xml
# tomato002T(9).xml
# mango005S(3).xml
# apple011T(2).xml
# qiwi001S(2).xml
# lemon001S(11).xml
# pear001T(5).xml
# lemon001T(6).xml
# lemon002S(12).xml
# litchi003T(3).xml
# plum003T(2).xml
# sachima004T(4).xml
# mooncake001T(15).xml
# plum003T(7).xml
# fired_dough_twist003T(8).xml
# apple010S(1).xml
# mango003T(8).xml
# orange008S(16).xml
# egg004S(1).xml
# bun005S(1).xml
# apple018S(11).xml
# lemon003S(18).xml
# banana007S(3).xml
# doughnut005S(3).xml
# plum004T(14).xml
# orange004S(2).xml
# tomato003T(29).xml
# apple016S(6).xml
# tomato003T(24).xml
# doughnut009S(7).xml
# bread004T(1).xml
# mango010S(1).xml
# litchi004T(3).xml
# sachima004S(11).xml
# orange010S(7).xml
# orange011S(13).xml
# peach001T(10).xml
# tomato002T(12).xml
# mix012T(4).xml
# doughnut008T(10).xml
# doughnut009S(12).xml
# doughnut006T(2).xml
# banana011T(5).xml
# doughnut004T(2).xml
# banana014S(6).xml
# tomato004S(8).xml
# qiwi006S(5).xml
# mix008T(2).xml
# mango002T(4).xml
# apple012S(3).xml
# sachima003T(8).xml
# banana012T(6).xml
# litchi004T(1).xml
# sachima005T(22).xml
# mango003S(5).xml
# sachima005S(9).xml
# fired_dough_twist002S(2).xml
# apple010S(3).xml
# egg003T(5).xml
# pear004T(4).xml
# mooncake005T(3).xml
# sachima001T(6).xml
# orange010S(11).xml
# egg001T(1).xml
# tomato003S(28).xml
# mooncake006T(3).xml
# mix006T(3).xml
# mango001T(3).xml
# bun004T(1).xml
# grape002T(14).xml
# apple017T(23).xml
# plum001S(20).xml
# banana014S(4).xml
# banana013S(7).xml
# doughnut005T(12).xml
# grape002S(5).xml
# orange008T(20).xml
# bun008T(3).xml
# sachima001T(3).xml
# banana012S(2).xml
# plum002T(12).xml
# orange014T(3).xml
# qiwi007T(8).xml
# apple006S(4).xml
# mango008T(4).xml
# doughnut007S(6).xml
# doughnut004T(15).xml
# mango008T(7).xml
# peach002T(8).xml
# apple017S(21).xml
# qiwi008S(1).xml
# apple002S(4).xml
# orange006S(2).xml
# tomato001S(3).xml
# plum001T(10).xml
# doughnut004S(12).xml
# peach004T(2).xml
# doughnut001S(4).xml
# banana012T(4).xml
# apple015T(13).xml
# qiwi007S(9).xml
# banana014T(3).xml
# orange009S(11).xml
# qiwi008T(3).xml
# pear002S(13).xml
# mango003S(9).xml
# orange011T(9).xml
# doughnut004T(5).xml
# apple017T(26).xml
# egg007T(8).xml
# apple011S(2).xml
# apple017T(21).xml
# mango002S(6).xml
# mooncake005S(7).xml
# apple016T(19).xml
# doughnut006S(19).xml
# bun006S(1).xml
# banana013S(6).xml
# apple015S(6).xml
# mango007T(8).xml
# litchi001T(6).xml
# tomato004T(21).xml
# apple005S(1).xml
# peach001T(8).xml
# pear001S(10).xml
# orange008S(1).xml
# banana005T(3).xml
# apple007T(2).xml
# mooncake002T(11).xml
# apple015S(2).xml
# lemon004T(10).xml
# sachima003S(4).xml
# doughnut005S(10).xml
# tomato002T(5).xml
# banana010S(5).xml
# mix010T(2).xml
# banana014T(9).xml
# bread005S(3).xml
# mango006T(13).xml
# apple018T(8).xml
# pear003S(11).xml
# mix006T(2).xml
# doughnut006T(9).xml
# mooncake004S(1).xml
# plum004T(7).xml
# bun005T(3).xml
# apple016S(9).xml
# doughnut007T(3).xml
# sachima005T(18).xml
# apple008T(2).xml
# pear002T(1).xml
# doughnut004S(14).xml
# orange003S(1).xml
# doughnut006T(16).xml
# apple014S(2).xml
# orange008S(21).xml
# orange004S(1).xml
# mango006S(11).xml
# qiwi007T(4).xml
# mango009S(5).xml
# banana013S(3).xml
# lemon001S(5).xml
# sachima005S(12).xml
# bun006T(4).xml
# bun005S(5).xml
# sachima005T(15).xml
# banana015S(8).xml
# litchi001T(5).xml
# tomato003T(13).xml
# doughnut004S(6).xml
# tomato002S(12).xml
# pear004T(3).xml
# tomato003S(29).xml
# banana002T(1).xml
# grape002S(7).xml
# pear003S(2).xml
# mango008T(6).xml
# grape001S(10).xml
# fired_dough_twist007T(3).xml
# peach004T(19).xml
# plum002S(4).xml
# doughnut009S(3).xml
# lemon001T(11).xml
# orange013T(1).xml
# mooncake004T(1).xml
# pear002S(5).xml
# lemon002S(7).xml
# mooncake002S(9).xml
# banana006T(1).xml
# bread003S(1).xml
# peach001T(12).xml
# sachima004T(5).xml
# apple013T(7).xml
# sachima005S(7).xml
# pear001S(5).xml
# mix002T(4).xml
# apple006S(3).xml
# doughnut007T(11).xml
# pear002S(16).xml
# egg005S(6).xml
# bun004S(4).xml
# peach004S(4).xml
# peach004S(14).xml
# fired_dough_twist006S(2).xml
# mango008S(8).xml
# lemon004S(9).xml
# apple017T(12).xml
# egg007T(3).xml
# lemon002S(23).xml
# peach001S(6).xml
# apple019S(1).xml
# bread001T(6).xml
# mango003T(7).xml
# banana015S(2).xml
# plum004T(12).xml
# pear005S(3).xml
# sachima003T(4).xml
# doughnut009S(6).xml
# bread006S(3).xml
# doughnut006T(8).xml
# mango002S(8).xml
# doughnut007T(15).xml
# lemon002T(3).xml
# qiwi002T(1).xml
# plum002T(2).xml
# orange009T(2).xml
# fired_dough_twist001T(7).xml
# peach003T(9).xml
# peach001T(16).xml
# apple002S(1).xml
# banana015S(7).xml
# plum002T(15).xml
# grape002S(10).xml
# mix007S(1).xml
# fired_dough_twist001S(5).xml
# sachima004S(3).xml
# banana015S(5).xml
# apple017S(25).xml
# apple011T(3).xml
# apple003T(2).xml
# orange010T(5).xml
# orange008T(17).xml
# orange008S(11).xml
# mango006S(2).xml
# doughnut005S(6).xml
# bread001T(4).xml
# apple015T(7).xml
# sachima003T(5).xml
# apple015T(5).xml
# lemon002T(9).xml
# plum003S(17).xml
# mix013S(3).xml
# peach001T(6).xml
# plum001S(1).xml
# mango005T(11).xml
# doughnut005S(8).xml
# apple017S(23).xml
# banana013T(2).xml
# mooncake004S(3).xml
# egg007S(3).xml
# pear006T(1).xml
# pear005S(7).xml
# lemon003T(17).xml
# peach004S(13).xml
# apple019S(7).xml
# lemon002S(16).xml
# qiwi001S(3).xml
# pear003S(16).xml
# lemon002S(17).xml
# qiwi004S(5).xml
# fired_dough_twist002S(9).xml
# apple015S(10).xml
# banana015T(6).xml
# egg005S(5).xml
# sachima005S(2).xml
# banana010S(1).xml
# plum003T(18).xml
# banana012S(3).xml
# orange013S(3).xml
# orange011T(11).xml
# apple015S(5).xml
# apple002T(3).xml
# orange008T(5).xml
# mango008S(7).xml
# apple017S(16).xml
# pear004S(8).xml
# doughnut006S(7).xml
# sachima004T(9).xml
# orange009S(9).xml
# peach003T(5).xml
# orange009S(2).xml
# tomato002T(8).xml
# pear001T(14).xml
# apple008S(3).xml
# tomato002T(4).xml
# lemon002S(15).xml
# lemon002T(22).xml
# mooncake001T(16).xml
# tomato004S(25).xml
# apple016S(15).xml
# pear003T(9).xml
# sachima005S(3).xml
# peach004S(15).xml
# apple009S(2).xml
# pear005T(5).xml
# sachima005S(1).xml
# pear001T(1).xml
# apple018S(1).xml
# mango007S(4).xml
# lemon003T(13).xml
# lemon002S(20).xml
# mango004T(10).xml
# grape001T(11).xml
# bun003S(4).xml
# tomato004S(2).xml
# apple004S(4).xml
# plum004T(6).xml
# plum001T(13).xml
# orange011T(7).xml
# pear005T(6).xml
# orange008S(15).xml
# apple004T(3).xml
# banana001T(4).xml
# tomato001T(7).xml
# tomato003T(11).xml
# mooncake002T(1).xml
# pear005S(5).xml
# banana012S(4).xml
# tomato003S(23).xml
# orange004T(1).xml
# mix011T(3).xml
# lemon004S(11).xml
# mix014T(1).xml
# mango005S(4).xml
# pear002T(17).xml
# mango003T(9).xml
# mooncake006S(7).xml
# doughnut004T(3).xml
# plum004T(24).xml
# mango010S(4).xml
# peach003S(5).xml
# grape001S(8).xml
# mix004S(4).xml
# pear003S(6).xml
# orange010T(12).xml
# banana013T(5).xml
# bun002T(1).xml
# doughnut008S(13).xml
# peach005T(3).xml
# mooncake001T(14).xml
# sachima002S(14).xml
# sachima002T(1).xml
# orange004T(4).xml
# tomato002S(8).xml
# tomato003S(34).xml
# pear003S(14).xml
# orange011S(8).xml
# egg003S(1).xml
# banana005T(1).xml
# mango002T(3).xml
# qiwi006T(12).xml
# mango003S(8).xml
# plum003S(19).xml
# banana014T(7).xml
# lemon002T(15).xml
# sachima002T(5).xml
# doughnut007S(2).xml
# orange005S(3).xml
# plum004T(15).xml
# doughnut007T(8).xml
# apple010T(2).xml
# orange015T(4).xml
# mango010T(4).xml
# egg006T(2).xml
# lemon003T(7).xml
# orange003S(2).xml
# qiwi004S(4).xml
# qiwi001S(1).xml
# mango009T(1).xml
# fired_dough_twist004T(4).xml
# doughnut004S(11).xml
# tomato004S(20).xml
# grape002S(3).xml
# fired_dough_twist004S(4).xml
# apple015T(11).xml
# grape001T(4).xml
# litchi005T(4).xml
# apple006T(3).xml
# bread007S(4).xml
# sachima004S(7).xml
# orange008T(11).xml
# sachima004S(5).xml
# qiwi006S(12).xml
# pear001T(12).xml
# lemon002T(13).xml
# fired_dough_twist004S(10).xml
# orange011T(18).xml
# doughnut007S(10).xml
# bun001T(6).xml
# doughnut007S(1).xml
# mango002T(8).xml
# doughnut003T(2).xml
# sachima005S(19).xml
# orange006S(3).xml
# fired_dough_twist001T(6).xml
# apple017T(17).xml
# qiwi007T(7).xml
# peach002T(2).xml
# pear006S(1).xml
# plum003S(7).xml
# orange007T(3).xml
# egg001S(3).xml
# mango001S(2).xml
# doughnut008S(4).xml
# banana007S(2).xml
# egg002T(4).xml
# doughnut002S(7).xml
# tomato004T(15).xml
# mango002S(9).xml
# mango007T(1).xml
# tomato004S(1).xml
# banana002T(2).xml
# banana012T(5).xml
# orange011S(9).xml
# egg005S(3).xml
# tomato002T(6).xml
# orange008S(23).xml
# bread001S(6).xml
# qiwi002T(3).xml
# plum004S(12).xml
# apple016S(24).xml
# doughnut007T(10).xml
# peach001T(4).xml
# bread002S(6).xml
# mooncake001T(2).xml
# plum003S(4).xml
# grape002S(2).xml
# mooncake003T(10).xml
# litchi005S(5).xml
# lemon001T(3).xml
# banana011S(6).xml
# sachima001S(1).xml
# doughnut006T(15).xml
# tomato003T(16).xml
# apple017T(7).xml
# banana014T(6).xml
# bread001S(1).xml
# egg003S(5).xml
# mango007T(12).xml
# mango010S(3).xml
# apple002S(3).xml
# banana009S(3).xml
# orange008S(7).xml
# pear003S(12).xml
# fired_dough_twist006T(3).xml
# mango007S(13).xml
# tomato003T(6).xml
# mango006T(5).xml
# plum004S(20).xml
# bread006T(1).xml
# peach001S(9).xml
# tomato004S(27).xml
# doughnut005T(11).xml
# egg003T(6).xml
# plum002S(2).xml
# mix002T(3).xml
# plum002S(10).xml
# tomato003S(30).xml
# mooncake005S(4).xml
# mix007T(4).xml
# mooncake001S(13).xml
# fired_dough_twist004S(8).xml
# mooncake003S(12).xml
# orange010T(1).xml
# grape001T(8).xml
# doughnut002T(4).xml
# mooncake001S(8).xml
# pear002S(3).xml
# banana011T(8).xml
# doughnut006T(5).xml
# orange008T(3).xml
# apple018T(1).xml
# orange011S(1).xml
# bun001T(7).xml
# doughnut009T(3).xml
# qiwi004T(2).xml
# doughnut009S(9).xml
# orange009T(3).xml
# mix012T(2).xml
# bun004S(2).xml
# plum003T(1).xml
# mango008T(5).xml
# egg006T(1).xml
# litchi003S(4).xml
# qiwi007S(8).xml
# doughnut007T(5).xml
# litchi002S(8).xml
# sachima005T(16).xml
# bun002T(3).xml
# tomato003T(25).xml
# peach001T(1).xml
# apple018T(7).xml
# orange009S(8).xml
# mix002S(3).xml
# mango007T(9).xml
# pear002T(11).xml
# egg006S(2).xml
# plum003T(20).xml
# bread007T(1).xml
# fired_dough_twist005T(2).xml
# apple015S(4).xml
# doughnut005S(4).xml
# grape001T(3).xml
# mix014T(4).xml
# sachima004S(6).xml
# orange008S(13).xml
# qiwi006S(9).xml
# plum004T(22).xml
# apple017S(8).xml
# mango007T(7).xml
# grape002T(11).xml
# mix007S(2).xml
# lemon001S(3).xml
# apple017S(17).xml
# fired_dough_twist005T(7).xml
# sachima005T(21).xml
# banana002S(1).xml
# pear001S(13).xml
# mooncake001T(10).xml
# apple002T(2).xml
# lemon002S(8).xml
# pear006S(2).xml
# mango005T(5).xml
# litchi002S(1).xml
# bread002T(1).xml
# mango004S(3).xml
# banana013T(1).xml
# pear003S(1).xml
# mango003S(6).xml
# pear001S(15).xml
# plum004S(5).xml
# plum001T(7).xml
# peach005S(6).xml
# sachima005T(20).xml
# apple014T(1).xml
# pear004S(4).xml
# tomato002S(1).xml
# mango005S(8).xml
# banana013S(1).xml
# plum003T(19).xml
# lemon004S(5).xml
# mix009T(2).xml
# apple017S(2).xml
# mix014S(4).xml
# grape002T(7).xml
# lemon002T(10).xml
# fired_dough_twist005S(4).xml
# peach003S(4).xml
# lemon001S(6).xml
# banana014S(8).xml
# orange009T(8).xml
# bun005S(3).xml
# bun004S(1).xml
# apple014T(7).xml
# plum003S(6).xml
# qiwi002S(1).xml
# mango007T(13).xml
# qiwi007S(1).xml
# mooncake002T(6).xml
# egg003T(3).xml
# pear004S(11).xml
# bread004S(1).xml
# banana004T(1).xml
# banana011T(9).xml
# doughnut002T(7).xml
# lemon004S(10).xml
# peach002S(7).xml
# qiwi004T(7).xml
# sachima005S(5).xml
# lemon003S(13).xml
# plum001S(8).xml
# mango004S(6).xml
# sachima005T(1).xml
# doughnut002T(6).xml
# orange015S(4).xml
# mango004S(4).xml
# doughnut008S(1).xml
# plum003S(1).xml
# lemon003T(16).xml
# apple010T(3).xml
# mix013S(2).xml
# tomato003T(14).xml
# mix009S(4).xml
# egg002T(8).xml
# mango009T(11).xml
# tomato003S(24).xml
# lemon003T(1).xml
# mooncake003T(7).xml
# lemon003T(10).xml
# lemon004S(6).xml
# bread006S(1).xml
# mango008S(5).xml
# bun001S(7).xml
# mix007S(5).xml
# qiwi001S(4).xml
# orange005S(1).xml
# plum004S(13).xml
# peach005T(2).xml
# bread005T(2).xml
# plum001S(5).xml
# plum002T(3).xml
# sachima003T(13).xml
# orange010S(6).xml
# plum003T(16).xml
# lemon002S(2).xml
# peach004T(8).xml
# mango009T(7).xml
# pear001T(3).xml
# mooncake001T(1).xml
# mix007T(1).xml
# orange008S(8).xml
# litchi003T(1).xml
# doughnut002T(1).xml
# bun005S(4).xml
# lemon003S(2).xml
# sachima005S(4).xml
# banana009S(6).xml
# mix002T(2).xml
# bread001S(4).xml
# pear002T(8).xml
# doughnut009T(9).xml
# peach003T(1).xml
# lemon002T(6).xml
# bread003S(3).xml
# fired_dough_twist002T(2).xml
# mango002S(3).xml
# banana004S(1).xml
# pear004S(3).xml
# mooncake003T(8).xml
# peach001S(14).xml
# bun008T(1).xml
# orange008T(14).xml
# grape002T(15).xml
# apple015S(7).xml
# egg006T(8).xml
# fired_dough_twist003T(2).xml
# doughnut006S(6).xml
# sachima003T(9).xml
# mix001S(2).xml
# lemon004T(4).xml
# mango008S(1).xml
# orange012T(9).xml
# mango003T(5).xml
# tomato002S(4).xml
# orange008T(9).xml
# sachima002T(4).xml
# bread001T(1).xml
# lemon003S(6).xml
# apple009T(2).xml
# apple016S(25).xml
# tomato003S(8).xml
# qiwi001T(1).xml
# litchi001S(2).xml
# qiwi007T(12).xml
# mooncake003S(1).xml
# plum004S(8).xml
# tomato004S(9).xml
# litchi004S(2).xml
# bread001T(5).xml
# qiwi007S(11).xml
# mooncake001S(2).xml
# banana014S(7).xml
# apple016S(3).xml
# pear002S(11).xml
# apple012S(4).xml
# mango010S(6).xml
# plum004T(19).xml
# mix013T(1).xml
# lemon003T(12).xml
# sachima001T(12).xml
# doughnut006T(17).xml
# lemon004T(8).xml
# pear001T(7).xml
# peach003S(1).xml
# mango010T(3).xml
# qiwi001T(4).xml
# doughnut007S(4).xml
# apple007S(4).xml
# orange003S(8).xml
# fired_dough_twist001T(2).xml
# litchi002S(3).xml
# apple015S(3).xml
# orange008T(13).xml
# peach005T(6).xml
# fired_dough_twist006S(3).xml
# banana011S(5).xml
# apple013T(5).xml
# bread007T(4).xml
# apple018S(4).xml
# peach004T(7).xml
# mango008T(3).xml
# tomato001T(1).xml
# mix003T(1).xml
# apple004T(1).xml
# fired_dough_twist002T(8).xml
# pear005S(2).xml
# mooncake001T(4).xml
# grape002S(12).xml
# mix004T(1).xml
# tomato004S(18).xml
# pear002S(8).xml
# mooncake004T(2).xml
# apple017T(16).xml
# apple017S(18).xml
# banana013S(12).xml
# orange012T(5).xml
# plum004S(16).xml
# apple016T(21).xml
# mango001T(5).xml
# sachima004S(1).xml
# banana013S(5).xml
# orange014T(2).xml
# plum001S(18).xml
# banana011S(8).xml
# peach004S(6).xml
# bun004S(8).xml
# tomato003S(17).xml
# fired_dough_twist002T(5).xml
# doughnut009T(2).xml
# banana014S(2).xml
# doughnut003S(2).xml
# bread003T(1).xml
# bun003S(1).xml
# apple006S(1).xml
# mix014S(2).xml
# mango003S(1).xml
# bun006S(4).xml
# qiwi006T(2).xml
# orange013S(4).xml
# mango006T(12).xml
# apple004S(3).xml
# orange010S(12).xml
# plum002S(7).xml
# mix012T(1).xml
# orange012T(8).xml
# mango005S(9).xml
# litchi003S(6).xml
# qiwi007T(1).xml
# qiwi003T(1).xml
# tomato003T(27).xml
# apple015T(8).xml
# orange011T(17).xml
# qiwi003S(3).xml
# mango003S(3).xml
# mooncake001S(4).xml
# peach002S(6).xml
# egg006S(4).xml
# grape001T(5).xml
# mango010T(8).xml
# litchi005S(3).xml
# mooncake003T(13).xml
# bun006T(7).xml
# mango004S(9).xml
# peach004T(3).xml
# bread005S(2).xml
# peach003S(6).xml
# mango004S(2).xml
# bun002S(4).xml
# bread007S(1).xml
# banana014T(4).xml
# apple013T(2).xml
# tomato002T(10).xml
# mix012S(2).xml
# plum004S(22).xml
# mango008S(6).xml
# lemon001T(18).xml
# pear001S(2).xml
# doughnut002T(3).xml
# fired_dough_twist004T(8).xml
# tomato003T(22).xml
# mooncake006T(4).xml
# doughnut004S(10).xml
# apple017T(5).xml
# banana008S(1).xml
# apple013T(8).xml
# qiwi004S(8).xml
# sachima001T(8).xml
# plum002T(19).xml
# plum004S(21).xml
# lemon002S(18).xml
# peach001T(14).xml
# qiwi008T(7).xml
# peach002S(4).xml
# doughnut007T(9).xml
# banana013T(12).xml
# litchi003T(4).xml
# mango004T(9).xml
# plum002T(16).xml
# orange009T(13).xml
# tomato002T(7).xml
# fired_dough_twist003S(5).xml
# orange010S(9).xml
# tomato003T(3).xml
# bread001S(7).xml
# lemon001S(4).xml
# egg002T(3).xml
# bun001S(3).xml
# tomato004S(6).xml
# fired_dough_twist007T(1).xml
# apple013T(1).xml
# banana011S(1).xml
# bun007S(2).xml
# apple017S(10).xml
# mooncake006S(2).xml
# sachima003T(6).xml
# orange012S(7).xml
# mooncake002T(2).xml
# mix006S(1).xml
# bun006T(8).xml
# pear006T(4).xml
# litchi003S(7).xml
# plum004S(7).xml
# banana006T(3).xml
# bun005T(2).xml
# doughnut009T(1).xml
# egg004S(2).xml
# apple008S(1).xml
# bread007T(5).xml
# bun001S(6).xml
# banana013T(9).xml
# mix014T(3).xml
# banana015T(8).xml
# mango002S(10).xml
# litchi004T(6).xml
# grape002T(9).xml
# plum002S(16).xml
# orange009S(1).xml
# orange007S(1).xml
# pear006S(9).xml
# tomato004T(22).xml
# bun002S(5).xml
# orange003T(3).xml
# lemon004T(5).xml
# fired_dough_twist004S(5).xml
# qiwi007S(6).xml
# plum002S(13).xml
# orange010T(4).xml
# tomato004S(15).xml
# qiwi007T(3).xml
# bun004S(7).xml
# qiwi006S(10).xml
# banana011S(2).xml
# banana004S(2).xml
# qiwi005S(3).xml
# tomato004T(7).xml
# orange012S(1).xml
# bread002S(5).xml
# tomato003S(11).xml
# peach001S(8).xml
# apple018T(10).xml
# orange004S(3).xml
# plum003S(2).xml
# orange010S(2).xml
# mooncake006S(3).xml
# orange002S(1).xml
# apple005T(1).xml
# doughnut007S(7).xml
# litchi002T(2).xml
# apple019S(2).xml
# mix012T(3).xml
# tomato001T(5).xml
# mooncake001S(11).xml
# mooncake002S(2).xml
# doughnut003T(1).xml
# mix010S(1).xml
# tomato001S(1).xml
# mooncake001S(14).xml
# litchi004S(6).xml
# peach004T(10).xml
# pear002T(12).xml
# mix002T(1).xml
# lemon003S(15).xml
# apple011T(5).xml
# apple017T(27).xml
# apple018T(2).xml
# doughnut003T(3).xml
# peach004S(3).xml
# orange013S(5).xml
# bun007T(1).xml
# apple019T(2).xml
# orange005T(1).xml
# lemon003T(6).xml
# plum001S(13).xml
# grape002T(8).xml
# apple002T(4).xml
# plum001T(4).xml
# qiwi006T(11).xml
# peach002T(7).xml
# pear005S(6).xml
# mango004S(8).xml
# orange007T(1).xml
# sachima002S(7).xml
# lemon001T(1).xml
# apple015T(6).xml
# orange010T(11).xml
# mix008S(2).xml
# doughnut004T(10).xml
# mix009S(2).xml
# pear001S(7).xml
# mango007S(3).xml
# sachima002S(6).xml
# lemon002S(14).xml
# egg001T(5).xml
# pear002T(9).xml
# mooncake003T(3).xml
# lemon002S(1).xml
# apple010S(4).xml
# fired_dough_twist005T(8).xml
# mix003S(3).xml
# bun002T(4).xml
# mango002S(2).xml
# plum004S(4).xml
# peach003T(8).xml
# mix014S(1).xml
# bun004S(5).xml
# banana013T(8).xml
# tomato003S(16).xml
# orange007S(2).xml
# qiwi003S(1).xml
# doughnut006T(4).xml
# sachima002S(9).xml
# mix014T(2).xml
# plum002S(5).xml
# tomato004T(27).xml
# bun006T(3).xml
# grape001S(2).xml
# pear006T(2).xml
# peach005S(4).xml
# plum003S(16).xml
# plum003T(22).xml
# pear002S(15).xml
# apple015T(12).xml
# apple002S(8).xml
# mango005T(1).xml
# banana006T(2).xml
# litchi004T(5).xml
# bread007S(2).xml
# litchi005T(3).xml
# sachima003S(13).xml
# lemon003T(2).xml
# grape001S(11).xml
# qiwi005T(3).xml
# apple002S(6).xml
# banana010T(5).xml
# bread001S(2).xml
# banana013T(11).xml
# lemon001T(14).xml
# apple008T(3).xml
# banana013S(8).xml
# peach005S(1).xml
# peach004S(9).xml
# banana010T(7).xml
# plum004S(17).xml
# mango006T(8).xml
# mooncake005S(6).xml
# doughnut004T(9).xml
# orange011S(17).xml
# tomato001T(6).xml
# doughnut007T(7).xml
# apple014T(2).xml
# banana015T(5).xml
# qiwi007S(7).xml
# bun001S(4).xml
# lemon004T(12).xml
# pear006S(3).xml
# mango009T(5).xml
# mooncake003S(5).xml
# egg002s(5).xml
# sachima004S(10).xml
# doughnut005T(3).xml
# doughnut001S(3).xml
# bun005T(4).xml
# mango007S(8).xml
# bun005T(5).xml
# banana009T(6).xml
# pear001T(9).xml
# orange005S(4).xml
# banana003T(2).xml
# sachima003S(10).xml
# qiwi007S(3).xml
# banana001S(3).xml
# lemon004S(2).xml
# plum004T(13).xml
# egg002s(6).xml
# apple017S(4).xml
# tomato003S(10).xml
# pear004T(12).xml
# lemon001S(13).xml
# mooncake006T(8).xml
# lemon002T(11).xml
# doughnut009S(8).xml
# apple017S(15).xml
# apple017S(14).xml
# mooncake001S(1).xml
# orange007S(3).xml
# orange010T(2).xml
# apple008S(2).xml
# egg003T(4).xml
# tomato003T(31).xml
# banana011T(4).xml
# orange015T(5).xml
# pear002S(7).xml
# litchi005T(7).xml
# plum004T(1).xml
# apple017S(6).xml
# orange014T(1).xml
# tomato003T(1).xml
# pear004T(7).xml
# orange010S(4).xml
# fired_dough_twist002S(3).xml
# doughnut003S(1).xml
# orange012T(6).xml
# mango004T(5).xml
# orange007T(2).xml
# apple014T(6).xml
# mango004T(3).xml
# plum004S(14).xml
# doughnut005T(6).xml
# fired_dough_twist001S(9).xml
# mango008S(2).xml
# pear004T(14).xml
# banana011T(2).xml
# litchi003S(1).xml
# lemon002T(2).xml
# peach005T(8).xml
# mango001S(6).xml
# tomato003T(4).xml
# qiwi008T(1).xml
# plum001T(5).xml
# tomato002S(2).xml
# apple016S(12).xml
# sachima005T(4).xml
# orange011S(16).xml
# plum001S(14).xml
# doughnut007T(12).xml
# sachima002S(13).xml
# apple015T(10).xml
# plum002S(9).xml
# lemon003T(11).xml
# mango001T(2).xml
# peach001S(11).xml
# pear001T(8).xml
# lemon003T(15).xml
# mix004T(2).xml
# orange002S(4).xml
# qiwi008S(3).xml
# doughnut005T(1).xml
# doughnut004S(4).xml
# bread003S(2).xml
# litchi001T(1).xml
# doughnut004T(6).xml
# pear005T(2).xml
# plum004T(4).xml
# tomato003S(27).xml
# orange009S(3).xml
# doughnut007S(14).xml
# orange002S(2).xml
# lemon003T(4).xml
# pear006T(5).xml
# apple009S(4).xml
# fired_dough_twist002T(7).xml
# apple017T(22).xml
# egg004S(5).xml
# lemon001S(2).xml
# pear004S(10).xml
# mango005S(10).xml
# doughnut008S(14).xml
# sachima005T(14).xml
# litchi002T(4).xml
# egg006S(3).xml
# orange015T(2).xml
# sachima002T(7).xml
# mooncake002S(4).xml
# doughnut008S(10).xml
# banana004S(3).xml
# orange009S(7).xml
# banana008S(2).xml
# banana001T(1).xml
# peach004T(1).xml
# pear004S(15).xml
# orange010T(7).xml
# egg003S(6).xml
# plum004S(3).xml
# apple017T(6).xml
# apple016T(7).xml
# plum003S(23).xml
# tomato003T(18).xml
# egg001T(2).xml
# mango004T(7).xml
# fired_dough_twist002S(5).xml
# mooncake002S(1).xml
# lemon003S(11).xml
# bun001T(1).xml
# orange009T(14).xml
# mango005T(10).xml
# qiwi006S(3).xml
# orange009T(12).xml
# doughnut009T(4).xml
# fired_dough_twist006S(4).xml
# mooncake003S(4).xml
# tomato003S(33).xml
# qiwi008T(4).xml
# apple007T(1).xml
# tomato004T(3).xml
# apple012T(1).xml
# egg005S(7).xml
# fired_dough_twist006S(6).xml
# banana011T(7).xml
# apple016T(8).xml
# grape001T(12).xml
# apple011S(1).xml
# orange007T(5).xml
# apple004S(1).xml
# grape002T(10).xml
# fired_dough_twist006T(5).xml
# qiwi004T(4).xml
# fired_dough_twist002S(10).xml
# qiwi006T(6).xml
# fired_dough_twist002T(9).xml
# mooncake005S(5).xml
# apple015T(1).xml
# mix010T(4).xml
# mango002T(1).xml
# mango003T(4).xml
# lemon002T(25).xml
# mix001T(2).xml
# lemon003T(9).xml
# plum001S(16).xml
# orange008T(4).xml
# peach004T(11).xml
# grape001T(2).xml
# bread006S(2).xml
# egg005T(6).xml
# mooncake002T(15).xml
# sachima005T(13).xml
# qiwi005T(5).xml
# pear005T(7).xml
# tomato003T(2).xml
# orange011T(1).xml
# mix002S(2).xml
# mooncake002S(8).xml
# tomato003S(22).xml
# bun006S(3).xml
# egg002s(4).xml
# plum003S(13).xml
# mix004S(1).xml
# lemon004S(4).xml
# bread002T(2).xml
# tomato004S(16).xml
# mooncake006S(6).xml
# mooncake005T(5).xml
# plum002S(11).xml
# apple017T(15).xml
# egg007T(2).xml
# apple016S(17).xml
# plum004T(10).xml
# banana013T(6).xml
# doughnut004T(8).xml
# apple017T(10).xml
# peach004T(15).xml
# doughnut005S(13).xml
# banana015S(4).xml
# peach002T(4).xml
# orange010T(6).xml
# plum001T(19).xml
# doughnut007T(13).xml
# pear002S(1).xml
# orange010S(13).xml
# lemon003T(5).xml
# pear002S(12).xml
# mix009S(3).xml
# egg002s(8).xml
# banana013S(11).xml
# sachima005T(7).xml
# mooncake001S(16).xml
# qiwi006S(8).xml
# sachima003S(11).xml
# banana010T(8).xml
# plum004T(20).xml
# peach004S(8).xml
# doughnut008T(9).xml
# litchi002S(5).xml
# sachima001S(9).xml
# peach003S(8).xml
# lemon003S(17).xml
# egg003T(2).xml
# mooncake004S(5).xml
# qiwi006T(7).xml
# mango005T(4).xml
# grape001T(6).xml
# mooncake001T(3).xml
# tomato003S(25).xml
# plum004S(9).xml
# litchi001S(6).xml
# sachima003S(1).xml
# mooncake005S(3).xml
# tomato003S(32).xml
# plum001T(2).xml
# apple017T(9).xml
# fired_dough_twist005S(6).xml
# mango009T(2).xml
# orange011T(15).xml
# orange003T(4).xml
# tomato004T(11).xml
# banana001S(2).xml
# mango004S(1).xml
# qiwi004T(8).xml
# plum004S(1).xml
# sachima003T(7).xml
# orange008T(22).xml
# tomato004T(1).xml
# plum003T(11).xml
# banana008S(3).xml
# fired_dough_twist002S(8).xml
# litchi003S(2).xml
# bun007S(4).xml
# grape002T(13).xml
# grape002S(13).xml
# grape002S(17).xml
# doughnut007T(14).xml
# banana005S(3).xml
# fired_dough_twist003T(5).xml
# apple016T(13).xml
# sachima005S(11).xml
# sachima004T(3).xml
# apple017S(1).xml
# litchi003S(3).xml
# sachima005T(6).xml
# litchi004T(2).xml
# apple014S(8).xml
# mango003T(3).xml
# mango006T(11).xml
# sachima005T(11).xml
# qiwi004S(6).xml
# apple005T(6).xml
# mix010T(7).xml
# lemon002T(1).xml
# doughnut006S(10).xml
# doughnut006T(18).xml
# doughnut009T(6).xml
# peach004T(18).xml
# egg003S(4).xml
# apple012S(2).xml
# egg006T(4).xml
# apple013T(6).xml
# mooncake006T(6).xml
# plum002T(9).xml
# orange012T(2).xml
# mango009S(9).xml
# orange012S(5).xml
# mooncake003T(12).xml
# orange008T(10).xml
# pear003S(15).xml
# mix008S(3).xml
# tomato002T(11).xml
# egg005T(7).xml
# mooncake006T(7).xml
# apple014T(8).xml
# sachima001S(10).xml
# doughnut006S(13).xml
# bread007T(3).xml
# doughnut007T(1).xml
# qiwi006T(5).xml
# orange011T(10).xml
# banana008S(4).xml
# mix013T(3).xml
# orange009T(5).xml
# plum001T(17).xml
# apple012S(1).xml
# mango010T(1).xml
# orange005S(2).xml
# fired_dough_twist005S(3).xml
# orange003T(6).xml
# bread001T(2).xml
# pear001S(6).xml
# orange008T(23).xml
# mango006T(6).xml
# mango005S(6).xml
# tomato002S(11).xml
# tomato001S(9).xml
# apple016S(5).xml
# doughnut005T(2).xml
# lemon003S(1).xml
# pear004T(6).xml
# egg002T(1).xml
# peach004S(1).xml
# mix007T(3).xml
# plum004T(2).xml
# plum002T(14).xml
# doughnut008T(3).xml
# pear002T(3).xml
# tomato002S(5).xml
# plum003S(3).xml
# egg001S(5).xml
# mango005S(2).xml
# pear005T(1).xml
# pear004T(10).xml
# plum003S(11).xml
# peach004S(20).xml
# banana012T(7).xml
# banana001T(3).xml
# orange003S(6).xml
# banana002T(3).xml
# mango004T(8).xml
# mix007S(4).xml
# plum002T(18).xml
# mix006S(4).xml
# orange003S(7).xml
# mix011T(1).xml
# doughnut008T(11).xml
# bun003T(4).xml
# orange009T(15).xml
# mooncake004T(5).xml
# mango007T(5).xml
# mix010S(6).xml
# litchi001S(1).xml
# pear002S(9).xml
# orange011S(12).xml
# litchi001S(7).xml
# mango002S(4).xml
# bun001S(1).xml
# banana011T(1).xml
# pear003S(7).xml
# fired_dough_twist003T(9).xml
# mix005S(4).xml
# doughnut009S(5).xml
# mango010S(7).xml
# sachima002T(13).xml
# banana010T(4).xml
# pear006T(8).xml
# apple005S(5).xml
# apple016T(9).xml
# mix008T(1).xml
# tomato004T(17).xml
# bun007T(4).xml
# litchi001S(4).xml
# bread006T(2).xml
# tomato004S(7).xml
# mooncake001T(7).xml
# tomato002T(1).xml
# banana009S(4).xml
# plum001S(4).xml
# tomato003T(33).xml
# peach001T(9).xml
# orange014S(3).xml
# grape001S(1).xml
# litchi001S(5).xml
# lemon003T(3).xml
# sachima002S(3).xml
# lemon001T(9).xml
# apple016T(2).xml
# lemon001T(10).xml
# doughnut007T(6).xml
# litchi002T(6).xml
# fired_dough_twist004T(5).xml
# orange011T(14).xml
# banana009T(4).xml
# mooncake001S(3).xml
# orange015T(1).xml
# lemon004S(8).xml
# plum002T(13).xml
# peach002S(5).xml
# sachima003S(6).xml
# apple018T(11).xml
# tomato003S(26).xml
# plum004S(18).xml
# apple017S(20).xml
# grape002S(9).xml
# egg005T(2).xml
# orange005T(4).xml
# orange001T(3).xml
# doughnut006S(3).xml
# mooncake004T(6).xml
# bun008S(2).xml
# lemon001T(5).xml
# mooncake005T(1).xml
# tomato004T(8).xml
# apple017T(14).xml
# lemon001S(8).xml
# sachima005T(8).xml
# lemon001T(7).xml
# lemon004S(1).xml
# banana015T(3).xml
# tomato001S(10).xml
# peach001S(15).xml
# mooncake001S(6).xml
# mango007T(6).xml
# doughnut004T(11).xml
# banana014S(3).xml
# fired_dough_twist004T(3).xml
# mix005T(4).xml
# qiwi004S(7).xml
# qiwi006T(8).xml
# pear001S(9).xml
# tomato004S(10).xml
# peach002T(3).xml
# grape001T(9).xml
# banana002S(3).xml
# tomato003T(30).xml
# peach004T(12).xml
# sachima005T(19).xml
# banana015T(1).xml
# tomato002T(2).xml
# bread004S(3).xml
# egg002T(7).xml
# doughnut005S(2).xml
# fired_dough_twist004S(3).xml
# apple013T(3).xml
# banana004T(2).xml
# mix009T(1).xml
# mooncake006T(2).xml
# orange011T(5).xml
# peach003S(3).xml
# mooncake001S(15).xml
# apple010S(2).xml
# plum002S(17).xml
# lemon003S(10).xml
# fired_dough_twist001S(4).xml
# egg007S(8).xml
# apple013S(2).xml
# doughnut004S(5).xml
# bread006T(4).xml
# bun004T(5).xml
# sachima001S(7).xml
# bread004T(2).xml
# mango009T(9).xml
# mango010S(8).xml
# banana001T(2).xml
# bread004S(2).xml
# sachima002S(8).xml
# orange010S(8).xml
# doughnut005T(7).xml
# apple016T(15).xml
# mooncake006T(1).xml
# apple011S(4).xml
# lemon002T(24).xml
# mango007S(1).xml
# tomato003T(23).xml
# tomato001S(2).xml
# lemon002S(21).xml
# apple006T(2).xml
# pear006T(6).xml
# pear003T(3).xml
# mango005T(12).xml
# banana014S(1).xml
# plum001S(22).xml
# mango010S(10).xml
# orange009S(6).xml
# orange007S(5).xml
# orange010S(1).xml
# apple009S(3).xml
# mango001T(6).xml
# banana006S(3).xml
# orange008T(21).xml
# banana009T(7).xml
# apple012T(2).xml
# apple018S(3).xml
# tomato003S(19).xml
# litchi002T(5).xml
# doughnut004T(1).xml
# qiwi001T(2).xml
# sachima001T(11).xml
# banana012S(8).xml
# pear006S(7).xml
# orange006T(1).xml
# mango007S(10).xml
# bread007S(5).xml
# pear006T(7).xml
# plum003T(15).xml
# fired_dough_twist005T(6).xml
# mooncake002S(11).xml
# apple008T(1).xml
# apple017T(2).xml
# mango006S(14).xml
# mango002S(5).xml
# banana015T(7).xml
# banana014T(5).xml
# plum004T(18).xml
# sachima001T(10).xml
# apple015T(2).xml
# plum004T(3).xml
# orange008S(18).xml
# mooncake005S(2).xml
# fired_dough_twist003S(4).xml
# orange011S(15).xml
# orange009T(1).xml
# mix004T(4).xml
# plum003T(13).xml
# egg007S(7).xml
# doughnut009T(11).xml
# plum004T(11).xml
# tomato003T(10).xml
# orange001T(4).xml
# plum001S(10).xml
# plum001T(9).xml
# plum004S(15).xml
# orange008S(17).xml
# mango009T(8).xml
# lemon002T(4).xml
# apple016T(4).xml
# doughnut005S(5).xml
# sachima002T(11).xml
# mango008T(2).xml
# pear002S(10).xml
# pear006T(3).xml
# qiwi008T(6).xml
# mooncake002S(10).xml
# plum002S(15).xml
# peach005S(3).xml
# bun007T(3).xml
# pear005T(4).xml
# egg007S(9).xml
# mango006S(7).xml
# tomato003T(17).xml
# mooncake002T(5).xml
# fired_dough_twist007T(2).xml
# banana014T(8).xml
# fired_dough_twist003S(10).xml
# peach001S(5).xml
# pear003T(10).xml
# fired_dough_twist002S(6).xml
# tomato003S(14).xml
# orange007S(4).xml
# peach005S(8).xml
# doughnut006S(15).xml
# mix010S(5).xml
# mooncake002S(7).xml
# lemon003T(8).xml
# mooncake002T(7).xml
# mooncake001T(6).xml
# mango009S(12).xml
# tomato003T(9).xml
# bun002T(2).xml
# bun002S(1).xml
# pear001S(14).xml
# mango001S(1).xml
# apple009T(3).xml
# pear001T(2).xml
# fired_dough_twist001T(9).xml
# grape002T(1).xml
# sachima003T(10).xml
# fired_dough_twist007S(3).xml
# apple006S(2).xml
# orange008S(20).xml
# pear002S(20).xml
# lemon001S(10).xml
# mix013S(1).xml
# mooncake003T(2).xml
# bread005S(1).xml
# sachima001T(9).xml
# lemon004T(3).xml
# pear004S(9).xml
# mix009T(3).xml
# plum002S(14).xml
# banana014S(5).xml
# fired_dough_twist002T(6).xml
# bun001T(4).xml
# egg003S(2).xml
# mix003S(1).xml
# orange006S(1).xml
# plum004T(23).xml
# orange010T(9).xml
# bun008T(4).xml
# qiwi004S(1).xml
# fired_dough_twist005S(5).xml
# tomato004S(11).xml
# tomato004T(6).xml
# sachima005T(9).xml
# grape001T(1).xml
# fired_dough_twist006T(7).xml
# banana015S(3).xml
# apple017T(1).xml
# bun006T(1).xml
# peach001T(5).xml
# doughnut002T(2).xml
# peach005S(10).xml
# litchi004T(7).xml
# doughnut008S(3).xml
# doughnut006T(14).xml
# litchi002T(8).xml
# apple009T(4).xml
# qiwi007T(10).xml
# mix013T(2).xml
# apple017T(18).xml
# lemon002S(24).xml
# orange007T(8).xml
# doughnut006S(18).xml
# orange004T(2).xml
# mango010T(11).xml
# mango006S(4).xml
# grape002T(16).xml
# plum001T(6).xml
# doughnut009S(1).xml
# orange008S(9).xml
# doughnut004T(13).xml
# apple019S(5).xml
# doughnut006S(4).xml
# tomato002T(14).xml
# tomato004T(12).xml
# apple014S(4).xml
# fired_dough_twist006S(5).xml
# tomato001S(8).xml
# sachima002S(2).xml
# doughnut001T(1).xml
# sachima001S(3).xml
# apple013S(4).xml
# doughnut003S(3).xml
# mooncake005T(6).xml
# apple019T(7).xml
# bun006S(6).xml
# apple016T(6).xml
# qiwi007S(10).xml
# fired_dough_twist005S(8).xml
# litchi003T(7).xml
# mooncake003T(5).xml
# bread007S(7).xml
# mango010S(5).xml
# mango006T(3).xml
# doughnut009S(4).xml
# doughnut008T(7).xml
# lemon002T(26).xml
# doughnut005T(5).xml
# sachima004T(12).xml
# mango003S(10).xml
# banana009S(1).xml
# apple019T(5).xml
# sachima004T(8).xml
# apple018S(8).xml
# qiwi005T(2).xml
# doughnut004S(15).xml
# plum003S(22).xml
# tomato002S(3).xml
# plum002T(17).xml
# doughnut005S(1).xml
# banana013T(7).xml
# banana009S(7).xml
# doughnut002S(2).xml
# plum002S(1).xml
# mooncake003T(6).xml
# fired_dough_twist004S(9).xml
# mix011T(2).xml
# banana014S(10).xml
# sachima001S(2).xml
# peach004T(4).xml
# bun002S(2).xml
# egg001T(3).xml
# bread002S(2).xml
# qiwi007S(4).xml
# sachima001S(5).xml
# qiwi007S(5).xml
# orange013T(2).xml
# litchi005T(6).xml
# pear001T(10).xml
# doughnut009S(10).xml
# tomato001S(6).xml
# doughnut004S(7).xml
# egg004T(1).xml
# doughnut006S(16).xml
# doughnut008T(1).xml
# orange013S(2).xml
# bun005S(2).xml
# pear002T(13).xml
# mix005T(6).xml
# lemon003S(5).xml
# apple003S(5).xml
# mix003T(2).xml
# sachima005T(3).xml
# peach004S(16).xml
# qiwi005S(2).xml
# mango007T(4).xml
# orange001T(2).xml
# litchi004S(7).xml
# mix011S(3).xml
# orange010S(5).xml
# plum002T(10).xml
# sachima005T(2).xml
# grape001T(7).xml
# apple003S(2).xml
# banana009S(5).xml
# lemon003S(12).xml
# lemon003S(3).xml
# pear003T(6).xml
# peach004S(10).xml
# peach001S(1).xml
# sachima002S(11).xml
# lemon004S(12).xml
# egg004T(2).xml
# lemon004S(3).xml
# orange008T(19).xml
# egg001T(4).xml
# doughnut004S(8).xml
# mix011S(2).xml
# tomato002T(15).xml
# litchi004S(3).xml
# litchi005S(7).xml
# qiwi003S(2).xml
# sachima001T(7).xml
# apple017S(13).xml
# egg007S(4).xml
# tomato004T(2).xml
# qiwi007T(5).xml
# plum003T(5).xml
# apple012T(4).xml
# mooncake006S(4).xml
# egg005T(8).xml
# mango002T(7).xml
# apple018T(3).xml
# apple014S(7).xml
# fired_dough_twist001T(5).xml
# apple017T(4).xml
# bread006S(4).xml
# pear004S(2).xml
# doughnut006T(10).xml
# sachima001T(2).xml
# tomato002S(14).xml
# doughnut002S(3).xml
# bread007T(6).xml
# orange011S(6).xml
# doughnut009T(14).xml
# egg004T(3).xml
# egg007T(1).xml
# mango006S(12).xml
# plum003T(8).xml
# mooncake002T(13).xml
# bun006S(7).xml
# mix003T(3).xml
# orange011T(4).xml
# egg007S(5).xml
# bread006T(3).xml
# orange010S(10).xml
# pear002T(20).xml
# banana008S(5).xml
# sachima004T(13).xml
# qiwi008T(8).xml
# mooncake005T(2).xml
# banana010T(3).xml
# qiwi005T(8).xml
# fired_dough_twist004S(6).xml
# egg002s(1).xml
# pear002T(19).xml
# mango006T(10).xml
# mango006S(1).xml
# sachima005S(22).xml
# mango004S(10).xml
# peach005T(5).xml
# mango005T(9).xml
# mango007T(3).xml
# grape001S(4).xml
# apple001T(1).xml
# banana010T(6).xml
# plum004S(19).xml
# banana010S(6).xml
# fired_dough_twist005T(1).xml
# tomato001T(9).xml
# mango003T(1).xml
# mix003S(2).xml
# plum002S(8).xml
# apple013S(3).xml
# peach004T(20).xml
# mango004T(2).xml
# mooncake003S(2).xml
# tomato003T(19).xml
# tomato003S(1).xml
# peach001S(12).xml
# doughnut008S(11).xml
# grape002S(4).xml
# qiwi005S(1).xml
# bread001S(8).xml
# apple012T(3).xml
# orange001S(1).xml
# pear002T(15).xml
# tomato003T(12).xml
# fired_dough_twist005S(1).xml
# grape001S(5).xml
# plum003S(14).xml
# bread001T(3).xml
# orange012S(3).xml
# lemon002T(21).xml
# tomato002S(7).xml
# lemon001T(17).xml
# litchi002S(4).xml
# doughnut001T(2).xml
# plum003S(20).xml
# pear001S(16).xml
# peach004S(11).xml
# tomato004T(5).xml
# bun007T(2).xml
# mix006T(1).xml
# pear006S(4).xml
# apple018S(6).xml
# fired_dough_twist001T(3).xml
# doughnut009S(2).xml
# qiwi004T(3).xml
# doughnut008S(12).xml
# mix011S(4).xml
# fired_dough_twist005S(2).xml
# orange008T(8).xml
# doughnut005T(8).xml
# grape002S(1).xml
# doughnut001T(3).xml
# orange013T(4).xml
# tomato004T(20).xml
# banana009S(8).xml
# bun001T(2).xml
# peach005T(9).xml
# litchi004T(8).xml
# pear001T(11).xml
# litchi001T(3).xml
# apple019T(3).xml
# orange008T(1).xml
# mix010T(3).xml
# pear003T(5).xml
# apple007S(2).xml
# apple006T(1).xml
# orange009S(16).xml
# pear003S(4).xml
# banana008T(2).xml
# doughnut006T(11).xml
# lemon003S(7).xml
# doughnut001S(1).xml
# plum001T(21).xml
# orange015S(5).xml
# pear004T(15).xml
# fired_dough_twist003T(4).xml
# plum002T(8).xml
# orange009T(4).xml
# egg007S(2).xml
# pear004S(6).xml
# banana003S(1).xml
# orange008S(4).xml
# tomato004S(12).xml
# pear003S(9).xml
# mooncake001T(8).xml
# egg007T(7).xml
# bun007S(3).xml
# apple013S(7).xml
# plum004T(9).xml
# mango006S(8).xml
# apple017T(3).xml
# plum002S(6).xml
# bun008T(2).xml
# lemon004T(7).xml
# litchi004S(1).xml
# mooncake004S(2).xml
# doughnut006S(1).xml
# mooncake005T(4).xml
# egg002s(7).xml
# tomato004T(19).xml
# mooncake002S(13).xml
# doughnut008S(7).xml
# tomato003S(2).xml
# mooncake003T(9).xml
# doughnut006S(12).xml
# sachima004T(6).xml
# sachima005S(10).xml
# mooncake004S(6).xml
# banana013T(3).xml
# mango001S(3).xml
# grape002T(5).xml
# doughnut001S(2).xml
# qiwi005S(6).xml
# mango006T(9).xml
# apple005T(5).xml
# orange011T(2).xml
# doughnut006T(12).xml
# apple016S(1).xml
# banana007T(3).xml
# tomato003T(26).xml
# doughnut007S(8).xml
# bun002T(5).xml
# pear003S(13).xml
# orange003T(2).xml
# grape001S(7).xml
# mix011T(4).xml
# orange002T(2).xml
# plum003S(10).xml
# apple016T(12).xml
# apple016T(24).xml
# fired_dough_twist005T(3).xml
# tomato001T(2).xml
# doughnut006S(14).xml
# plum001T(18).xml
# apple016S(8).xml
# bun004T(2).xml
# doughnut007S(9).xml
# lemon002T(17).xml
# plum001S(7).xml
# bun004T(3).xml
# doughnut001T(4).xml
# mango006T(7).xml
# fired_dough_twist006S(7).xml
# fired_dough_twist004T(2).xml
# mango009T(10).xml
# pear006S(6).xml
# peach002T(6).xml
# egg001S(1).xml
# pear006S(5).xml
# mango007S(2).xml
# plum003S(18).xml
# fired_dough_twist003T(10).xml
# apple002T(5).xml
# banana014S(9).xml
# lemon002S(25).xml
# peach001S(13).xml
# qiwi007S(2).xml
# doughnut006S(5).xml
# sachima005T(12).xml
# plum002S(19).xml
# plum001S(19).xml
# mango002S(7).xml
# qiwi008T(5).xml
# mango002S(1).xml
# plum004T(16).xml
# banana009T(2).xml
# orange014S(1).xml
# pear002T(4).xml
# mango006T(2).xml
# orange008T(12).xml
# pear002S(14).xml
# lemon002T(7).xml
# egg007S(1).xml
# peach003T(7).xml
# fired_dough_twist001S(2).xml
# qiwi004S(3).xml
# pear004T(9).xml
# orange012T(1).xml
# plum001S(15).xml
# lemon003S(4).xml
# mango005S(1).xml
# apple018S(2).xml
# doughnut008T(4).xml
# sachima004S(2).xml
# tomato003S(31).xml
# lemon004T(6).xml
# orange004T(3).xml
# mango009S(1).xml
# apple017S(26).xml
# banana007T(2).xml
# mango004T(6).xml
# mango010T(10).xml
# apple017S(12).xml
# fired_dough_twist001S(3).xml
# bun006T(2).xml
# peach001T(3).xml
# mango008T(1).xml
# bun006S(5).xml
# egg004S(3).xml
# sachima002T(15).xml
# egg005T(3).xml
# doughnut004S(13).xml
# fired_dough_twist003T(1).xml
# banana010T(2).xml
# peach002T(5).xml
# pear003S(10).xml
# egg006T(7).xml
# bread004S(4).xml
# doughnut002S(4).xml
# bread002S(1).xml
# tomato004T(18).xml
# plum001T(16).xml
# mango001S(7).xml
# litchi005S(4).xml
# pear002T(10).xml
# plum002T(7).xml
# pear003T(13).xml
# sachima003S(9).xml
# mango010T(9).xml
# bread007T(2).xml
# sachima001S(6).xml
# mix007T(5).xml
# litchi002S(6).xml
# qiwi001T(3).xml
# lemon001T(8).xml
# mix001S(1).xml
# mix004S(2).xml
# fired_dough_twist003S(7).xml
# apple003S(3).xml
# fired_dough_twist003S(6).xml
# orange011T(13).xml
# tomato002S(13).xml
# orange003S(4).xml
# doughnut005S(15).xml
# fired_dough_twist007T(5).xml
# litchi001S(3).xml
# mix007S(3).xml
# plum002T(11).xml
# egg006S(1).xml
# apple015T(4).xml
# apple001S(1).xml
# mango003S(7).xml
# egg006S(8).xml
# doughnut008T(12).xml
# orange011T(6).xml
# mango001S(4).xml
# peach005S(9).xml
# orange014S(2).xml
# grape002T(12).xml
# banana011S(7).xml
# plum004T(8).xml
# banana002S(2).xml
# fired_dough_twist005S(7).xml
# orange006T(4).xml
# pear003T(15).xml
# egg004T(4).xml
# doughnut004T(14).xml
# bun003S(2).xml
# orange007T(4).xml
# bun008S(4).xml
# plum003S(9).xml
# bun008S(3).xml
# pear001T(4).xml
# doughnut008T(13).xml
# peach002T(1).xml
# apple017S(3).xml
# banana005S(2).xml
# egg002s(9).xml
# banana011S(9).xml
# orange009T(10).xml
# litchi005T(5).xml
# pear001S(11).xml
# tomato004T(14).xml
# peach004S(2).xml
# apple013S(6).xml
# orange005T(3).xml
# mango002T(5).xml
# grape002S(14).xml
# mango006T(14).xml
# mango007S(12).xml
# peach001T(7).xml
# apple016T(17).xml
# lemon002S(6).xml
# lemon003S(14).xml
# apple019S(4).xml
# mango007T(2).xml
# fired_dough_twist006T(4).xml
# plum004S(10).xml
# doughnut002S(6).xml
# grape001T(10).xml
# tomato002S(15).xml
# doughnut005T(4).xml
# peach005T(7).xml
# fired_dough_twist007S(4).xml
# plum003S(8).xml
# litchi005S(8).xml
# pear001S(8).xml
# banana010S(7).xml
# orange011S(14).xml
# mooncake006S(5).xml
# orange008T(16).xml
# tomato002T(3).xml
# mango003S(2).xml
# apple019T(4).xml
# pear002T(7).xml
# apple016S(22).xml
# mooncake001T(5).xml
# fired_dough_twist002S(7).xml
# tomato003S(7).xml
# apple016T(25).xml
# mango005T(3).xml
# mango009T(3).xml
# qiwi006S(2).xml
# mango003T(11).xml
# banana013S(4).xml
# mango008S(3).xml
# fired_dough_twist003S(2).xml
# banana011T(3).xml
# apple016T(18).xml
# mix010S(2).xml
# fired_dough_twist001T(1).xml
# qiwi006S(11).xml
# banana013T(10).xml
# orange004S(4).xml
# apple017S(7).xml
# bun002S(3).xml
# banana009T(1).xml
# apple001T(2).xml
# qiwi004T(5).xml
# qiwi008S(2).xml
# sachima004T(11).xml
# bun001S(2).xml
# lemon001S(1).xml
# mango007S(5).xml
# mix010T(5).xml
# apple016S(10).xml
# peach004S(17).xml
# banana011S(3).xml
# mooncake005T(7).xml
# grape002T(3).xml
# pear004T(5).xml
# banana013S(2).xml
# egg004T(5).xml
# apple019S(3).xml
# egg006S(5).xml
# apple001S(2).xml
# lemon002S(3).xml
# mango005S(12).xml
# apple005S(6).xml
# banana012T(3).xml
# pear004S(13).xml
# plum003T(23).xml
# orange008S(19).xml
# apple017T(19).xml
# plum003S(5).xml
# peach004T(17).xml
# sachima003T(3).xml
# lemon002T(16).xml
# litchi003T(8).xml
# orange011S(18).xml
# mango007T(11).xml
# qiwi007S(12).xml
# apple016S(4).xml
# mango007S(6).xml
# apple019S(6).xml
# tomato003S(6).xml
# plum001S(21).xml
# bread007T(7).xml
# sachima002S(5).xml
# tomato001S(7).xml
# mooncake005S(1).xml
# tomato003T(7).xml
# fired_dough_twist001T(8).xml
# doughnut007S(5).xml
# doughnut006T(1).xml
# apple016S(16).xml
# orange009S(4).xml
# pear003T(14).xml
# orange015S(3).xml
# lemon002T(12).xml
# mooncake003T(1).xml
# mooncake003S(9).xml
# plum001S(9).xml
# apple016S(13).xml
# doughnut009T(10).xml
# bread005T(3).xml
# sachima005S(20).xml
# mango003T(10).xml
# tomato004S(26).xml
# apple015S(12).xml
# tomato004S(13).xml
# plum001S(3).xml
# apple014S(3).xml
# plum002T(1).xml
# tomato002S(9).xml
# mooncake004T(3).xml
# orange011S(11).xml
# sachima005S(14).xml
# litchi002S(7).xml
# mix011S(1).xml
# tomato004S(21).xml
# mix006S(2).xml
# mango006S(9).xml
# tomato004S(22).xml
# sachima003T(11).xml
# fired_dough_twist001S(1).xml
# litchi003T(6).xml
# pear005S(1).xml
# sachima002S(4).xml
# peach003T(2).xml
# lemon002T(5).xml
# egg006S(7).xml
# plum002S(12).xml
# sachima002T(14).xml
# bun001T(5).xml
# qiwi004S(2).xml
# mango004S(7).xml
# egg006T(3).xml
# orange012S(2).xml
# tomato004T(16).xml
# lemon002T(19).xml
# mooncake002S(16).xml
# mooncake001S(5).xml
# peach002S(2).xml
# bread001T(8).xml
# lemon001S(15).xml
# banana012T(1).xml
# mango001S(5).xml
# sachima003S(2).xml
# bun006T(6).xml
# orange012S(6).xml
# mango005S(5).xml
# peach005T(4).xml
# pear004T(13).xml
# sachima004T(1).xml
# apple003S(6).xml
# doughnut005S(11).xml
# lemon001S(14).xml
# qiwi008S(9).xml
# bun003S(3).xml
# peach001S(4).xml
# tomato003S(18).xml
# qiwi003T(2).xml
# mooncake003T(4).xml
# mango004T(4).xml
# banana012T(2).xml
# apple007S(1).xml
# bread001T(7).xml
# doughnut007S(12).xml
# orange003T(7).xml
# sachima002T(10).xml
# peach004T(16).xml
# fired_dough_twist007T(7).xml
# banana006S(1).xml
# orange009S(12).xml
# tomato003S(21).xml
# pear003S(3).xml
# mango003T(2).xml
# qiwi003T(3).xml
# egg005T(5).xml
# apple009S(1).xml
# peach001S(10).xml
# doughnut005S(7).xml
# tomato001T(4).xml
# orange011T(16).xml
# mooncake002T(8).xml
# qiwi006T(1).xml
# peach001T(2).xml
# grape001S(12).xml
# plum004T(5).xml
# sachima003S(3).xml
# bun003T(2).xml
# mango006S(13).xml
# apple016S(20).xml
# mix013S(4).xml
# tomato004S(23).xml
# fired_dough_twist005T(5).xml
# peach004S(12).xml
# qiwi002S(2).xml
# sachima005S(6).xml
# orange009S(13).xml
# mango003T(6).xml
# fired_dough_twist002S(4).xml
# banana009T(8).xml
# doughnut002S(5).xml
# mango005T(7).xml
# fired_dough_twist003S(1).xml
# sachima003S(8).xml
# fired_dough_twist004T(7).xml
# bread003T(2).xml
# apple004S(2).xml
# egg007T(5).xml
# peach001S(16).xml
# tomato004S(5).xml
# apple017T(11).xml
# apple016S(11).xml
# qiwi004T(1).xml
# banana007T(1).xml
# banana003T(1).xml
# pear002S(18).xml
# sachima003T(12).xml
# mango010T(6).xml
# banana009T(5).xml
# qiwi008T(9).xml
# mango006S(10).xml
# plum003T(21).xml
# orange007S(7).xml
# mango009S(6).xml
# egg002T(9).xml
# tomato003T(21).xml
# tomato004S(19).xml
# egg002T(5).xml
# peach001S(2).xml
# mix008S(4).xml
# fired_dough_twist007T(6).xml
# apple016S(2).xml
# apple015T(3).xml
# doughnut007S(13).xml
# sachima005S(13).xml
# lemon003S(8).xml
# plum004S(24).xml
# doughnut005S(12).xml
# peach004T(13).xml
# pear002S(17).xml
# mooncake002S(14).xml
# tomato004S(14).xml
# apple014S(6).xml
# fired_dough_twist004T(1).xml
# mix009T(4).xml
# qiwi007T(2).xml
# egg005T(1).xml
# lemon003S(16).xml
# litchi002S(2).xml
# tomato002S(6).xml
# orange008T(15).xml
# pear002T(14).xml
# egg006T(6).xml
# plum004S(2).xml
# litchi001T(7).xml
# doughnut004S(2).xml
# plum001S(12).xml
# mango006T(4).xml
# mango009S(13).xml
# tomato004T(26).xml
# lemon004T(11).xml
# apple003S(1).xml
# mooncake002T(16).xml
# fired_dough_twist003T(7).xml
# plum003T(3).xml
# mix004T(3).xml
# orange009T(11).xml
# orange012S(8).xml
# egg001S(7).xml
# apple009T(1).xml
# apple016T(3).xml
# apple016S(18).xml
# apple016S(14).xml
# peach005S(7).xml
# sachima005T(17).xml
# fired_dough_twist007T(4).xml
# banana009S(2).xml
# grape001S(9).xml
# mooncake002T(17).xml
# plum001S(17).xml
# doughnut008S(2).xml
# bread005T(1).xml
# doughnut002S(1).xml
# pear001S(4).xml
# plum001T(12).xml
# fired_dough_twist005T(9).xml
# mooncake002T(12).xml
# peach002S(3).xml
# fired_dough_twist005T(4).xml
# qiwi006T(3).xml
# peach001S(7).xml
# qiwi005S(8).xml
# doughnut008S(9).xml
# fired_dough_twist004T(9).xml
# tomato003S(15).xml
# doughnut006T(3).xml
# plum003S(15).xml
# litchi004S(8).xml
# mooncake002T(4).xml
# apple014S(5).xml
# tomato003T(20).xml
# sachima004S(9).xml
# orange001T(1).xml
# litchi002T(1).xml
# mooncake003S(11).xml
# apple018S(10).xml
# doughnut004T(4).xml
# orange008T(6).xml
# bun003T(3).xml
# tomato002S(10).xml
# orange015S(1).xml
# pear004T(2).xml
# lemon002T(8).xml
# apple014T(4).xml
# bun004T(7).xml
# mix012S(3).xml
# pear004T(1).xml
# doughnut007T(2).xml
# plum003T(12).xml
# grape002T(2).xml
# mango006S(6).xml
# apple014T(3).xml
# orange012S(9).xml
# bun008S(1).xml
# orange011T(8).xml
# fired_dough_twist002T(3).xml
# pear003T(4).xml
# mix012S(1).xml
# doughnut009T(7).xml
# orange013T(3).xml
# plum003T(9).xml
# plum004T(21).xml
# plum001T(20).xml
# tomato003S(4).xml
# apple003T(1).xml
# pear001S(3).xml
# pear002T(6).xml
# apple011T(1).xml
# qiwi005S(4).xml
# banana009T(3).xml
# bun004T(6).xml
# mooncake003S(13).xml
# pear004S(7).xml
# egg005S(1).xml
# tomato004S(17).xml
# apple017T(24).xml
# mango003S(4).xml
# apple016S(19).xml
# bread002S(4).xml
# egg005S(8).xml
# apple002T(6).xml
# mooncake003S(6).xml
# bun006S(2).xml
# doughnut009T(5).xml
# orange012T(4).xml
# tomato001T(8).xml
# litchi004T(4).xml
# orange009S(10).xml
# sachima002T(8).xml
# orange011S(2).xml
# plum001T(11).xml
# bun001S(5).xml
# plum004S(11).xml
# fired_dough_twist003S(8).xml
# orange009S(15).xml
# litchi002T(3).xml
# doughnut006S(11).xml
# egg002s(3).xml
# apple017T(8).xml
# orange009T(9).xml
# orange012T(3).xml
# orange008T(2).xml
# pear002T(18).xml
# lemon004T(2).xml
# tomato003T(8).xml
# mango009T(13).xml
# pear001T(16).xml
# plum001S(2).xml
# apple017S(11).xml
# tomato004S(3).xml
# banana010S(8).xml
# fired_dough_twist006T(2).xml
# tomato003T(32).xml
# grape002S(8).xml
# doughnut007S(3).xml
# apple016T(1).xml
# banana005T(2).xml
# pear002S(6).xml
# litchi003T(2).xml
# tomato003S(13).xml
# mango009S(8).xml
# pear004S(5).xml
# fired_dough_twist005S(9).xml
# pear002T(5).xml
# lemon001T(4).xml
# mango010S(9).xml
# lemon002T(18).xml
# apple002S(7).xml
# mooncake001S(7).xml
# plum003T(6).xml
# fired_dough_twist002T(1).xml
# grape002S(15).xml
# apple013S(8).xml
# plum002T(6).xml
# peach002S(8).xml
# doughnut002T(5).xml
# apple016S(7).xml
# banana010S(3).xml
# pear003T(11).xml
# banana012S(1).xml
# sachima001S(4).xml
# peach004T(9).xml
# egg003S(3).xml
# mix008T(4).xml
# bun005T(1).xml
# mango009S(10).xml
# mix010T(1).xml
# orange009T(6).xml
# apple002T(1).xml
# bun007S(1).xml
# banana010S(2).xml
# fired_dough_twist001S(8).xml
# sachima002T(9).xml
# pear004S(12).xml
# mooncake003S(10).xml
# banana014T(1).xml
# litchi005S(2).xml
# banana007S(1).xml
# orange009S(5).xml
# plum001T(22).xml
# orange009T(7).xml
# grape002T(17).xml
# mooncake004T(4).xml
# mix006T(4).xml
# egg001S(2).xml
# banana006S(2).xml
# banana012S(6).xml
# apple011T(4).xml
# orange008S(3).xml
# doughnut004T(12).xml
# peach001T(11).xml
# banana015T(4).xml
# pear004T(8).xml
# mango010S(2).xml
# mango005T(8).xml
# bun004T(8).xml
# lemon002S(26).xml
# mooncake001T(13).xml
# qiwi006S(1).xml
# doughnut004T(7).xml
# apple014S(1).xml
# apple014T(5).xml
# fired_dough_twist003T(3).xml
# tomato003S(20).xml
# doughnut008S(6).xml
# apple018T(9).xml
# banana014T(10).xml
# orange008S(12).xml
# apple017S(19).xml
# bun006T(5).xml
# sachima004T(2).xml
# mango005S(7).xml
# tomato003S(5).xml
# mango007S(9).xml
# mango008S(4).xml
# tomato004T(13).xml
# sachima002T(12).xml
# bun003T(1).xml
# doughnut009T(12).xml
# peach005S(5).xml
# lemon002T(20).xml
# banana004T(3).xml
# doughnut005T(9).xml
# orange008T(7).xml
# mango009S(11).xml
# apple016T(16).xml
# orange010S(3).xml
# plum003T(10).xml
# banana010S(4).xml
# plum001T(14).xml
# apple013S(1).xml
# plum001S(11).xml
# doughnut006S(17).xml
# lemon002S(19).xml
# banana008T(4).xml
# apple007S(3).xml
# egg007T(9).xml
# mango001T(4).xml
# orange011S(10).xml
# orange007T(7).xml
# apple016T(14).xml
# mix010T(6).xml
# pear003S(5).xml
# apple017S(22).xml
# plum001T(8).xml
# pear003T(16).xml
# litchi004S(5).xml
# pear004T(11).xml
# orange005T(2).xml
# lemon001S(12).xml
# peach003T(4).xml
# pear001T(6).xml
# plum001S(6).xml
# doughnut006T(7).xml
# orange011S(7).xml
# mix010S(4).xml
# litchi005S(1).xml
# qiwi007T(9).xml
# mooncake001S(10).xml
# sachima004T(7).xml
# doughnut009T(13).xml
# orange015S(2).xml
# doughnut007S(11).xml
# mango005T(2).xml
# tomato001S(4).xml
# orange011S(5).xml
# fired_dough_twist003T(6).xml
# sachima002T(3).xml
# doughnut008T(2).xml
# mix008S(1).xml
# orange003T(1).xml
# tomato004T(10).xml
# mango006T(1).xml
# sachima001T(4).xml
# egg002T(2).xml
# qiwi006T(4).xml
# fired_dough_twist004S(7).xml
# egg005S(2).xml
# doughnut005T(15).xml
# apple016T(22).xml
# sachima002S(1).xml
# mooncake002T(9).xml
# apple006T(4).xml
# sachima001T(1).xml
# bread003T(3).xml
# apple017S(27).xml
# fired_dough_twist003S(3).xml
# mix002S(1).xml
# egg006S(6).xml
# tomato003T(34).xml
# mango001T(1).xml
# orange008S(6).xml
# pear002T(2).xml
# mango006S(5).xml
# qiwi008S(8).xml
# lemon002S(11).xml
# mango002T(10).xml
# orange008S(2).xml
# egg007T(4).xml
# peach002S(1).xml
# fired_dough_twist006S(1).xml
# lemon002S(4).xml
# sachima002S(12).xml
# bread002S(3).xml
# qiwi007T(6).xml
# mooncake001T(9).xml
# pear005T(3).xml
# mango009S(7).xml
# mango001T(8).xml
# sachima005S(15).xml
# plum002S(18).xml
# fired_dough_twist001S(6).xml
# orange011T(3).xml
# tomato003T(15).xml
# apple015T(9).xml
# orange015T(6).xml
# grape002S(6).xml
# qiwi006S(7).xml
# sachima002T(6).xml
# doughnut009S(13).xml
# apple016S(23).xml
# plum001T(3).xml
# pear001T(13).xml
# mango004T(1).xml
# peach003T(3).xml
# apple011S(3).xml
# egg005T(4).xml
# mango007T(10).xml
# peach004S(7).xml
# litchi001T(2).xml
# pear002S(2).xml
# apple017T(13).xml
# qiwi006S(6).xml
# pear001S(12).xml
# pear004S(1).xml
# sachima003S(12).xml
# mango005S(11).xml
# pear003T(7).xml
# apple007T(4).xml
# mooncake001T(11).xml
# apple010T(4).xml
# grape002T(4).xml
# fired_dough_twist006T(6).xml
# peach003S(7).xml
# lemon001T(13).xml
# fired_dough_twist003S(9).xml
# orange009T(16).xml
# grape002S(16).xml
# peach004S(18).xml
# qiwi002S(3).xml
# apple016S(21).xml
# sachima004S(8).xml
# pear006T(9).xml
# orange008S(5).xml
# fired_dough_twist002T(10).xml
# tomato003S(12).xml
# orange007T(6).xml
# apple008T(4).xml
# sachima001S(11).xml
# orange003S(3).xml
# banana012T(8).xml
# tomato001T(10).xml
# qiwi005T(4).xml
# apple018S(9).xml
# peach001T(13).xml
# orange003T(5).xml
# mango010T(7).xml
# mango009S(2).xml
# lemon002S(13).xml
# pear002S(19).xml
# banana014T(2).xml
# mango009S(3).xml
# sachima001S(12).xml
# doughnut008T(6).xml
# plum002T(4).xml
# orange011S(4).xml
# litchi003S(8).xml
# litchi002T(7).xml
# orange008S(22).xml
# doughnut005S(9).xml
# orange002T(1).xml
# lemon001T(12).xml
# orange007S(6).xml
# mango005T(6).xml
# doughnut004S(3).xml
# doughnut006S(8).xml
# mix013T(4).xml
# doughnut007S(15).xml
# egg002s(2).xml
# plum003S(21).xml
# banana011T(6).xml
# apple018T(5).xml
# tomato004S(4).xml
# apple016T(20).xml
# qiwi003T(4).xml
# lemon004S(7).xml
# mix009S(1).xml
# banana008T(5).xml
# apple015S(9).xml
# banana013S(10).xml
# bread001S(5).xml
# bun004S(6).xml
# pear003S(8).xml
# sachima004S(13).xml
# fired_dough_twist001S(7).xml
# doughnut008T(8).xml
# egg001T(6).xml

# %% [markdown]
# **Function to Split the Annotations in .XML into Train and Test Sets**

# %%
from collections import defaultdict
from math import ceil,floor

# Create the Train and Test Folder in the ANNOTATION Directory:
os.mkdir('/content/ECUSTFD-resized-/Annotations/train')
os.mkdir('/content/ECUSTFD-resized-/Annotations/test')

dicSide = { 'apple':[], 'banana':[], 'bread':[], 'bun':[],
        'doughnut':[], 'egg':[], 'fired':[],
        'grape':[], 'lemon':[], 'litchi':[], 'mango':[],
        'mooncake':[], 'orange':[], 'peach':[], 'pear':[],
        'plum':[], 'qiwi':[], 'sachima':[], 'tomato':[],'mix':[] }
dicTop = { 'apple':[], 'banana':[], 'bread':[], 'bun':[],
        'doughnut':[], 'egg':[], 'fired':[],
        'grape':[], 'lemon':[], 'litchi':[], 'mango':[],
        'mooncake':[], 'orange':[], 'peach':[], 'pear':[],
        'plum':[], 'qiwi':[], 'sachima':[], 'tomato':[],'mix':[] }

c=0
for file in os.listdir('/content/ECUSTFD-resized-/Annotations'):
    if 'xml' in file:
        for key in dicSide.keys():
            if key in file:
                if 'S' in file:
                    dicSide[key].append(file)
                else:
                    dicTop[key].append(file)
                break

k='qiwi'
print(dicSide[k][1])
print(dicSide[k][1].replace('S','T'))

t=0
for k in dicTop.keys():
    t+=len(dicSide[k])+len(dicTop[k])
    print(k,"\n",len(dicSide[k]))
    print(len(dicTop[k]),"\n --------------")
print(t)

for key in dicSide:
    count_food_Side = len(dicSide[key])
    train_size_Side=floor((count_food_Side/10)*9.5)+10**10
    print(count_food_Side,train_size_Side,"SIDE>>>>>>>>")
    count_food_Top = len(dicTop[key])
    train_size_Top=floor((count_food_Top/10)*8.5)
    print(count_food_Top,train_size_Top,"TOP>>>>>>>>")

    if(train_size_Side==train_size_Top):

        for i in range(train_size_Side):
            filename=dicSide[key][i]
            shutil.move("/content/ECUSTFD-resized-/Annotations/"+filename,"/content/ECUSTFD-resized-/Annotations/train/"+filename)
            filename = filename.replace('S','T')
            shutil.move("/content/ECUSTFD-resized-/Annotations/"+filename,"/content/ECUSTFD-resized-/Annotations/train/"+filename)

        for i in range(train_size_Side,count_food_Side):
            filename=dicSide[key][i]
            shutil.move("/content/ECUSTFD-resized-/Annotations/"+filename,"/content/ECUSTFD-resized-/Annotations/test/"+filename)
            filename = filename.replace('S','T')
            shutil.move("/content/ECUSTFD-resized-/Annotations/"+filename,"/content/ECUSTFD-resized-/Annotations/test/"+filename)

    else:

        lis = dicSide[key]
        dcSi = defaultdict(list)
        for elem in lis:
            name = elem.split('S')[0]
            dcSi[name].append(elem)

        print(dcSi.keys())

        lis2 = dicTop[key]
        dcTo = defaultdict(list)
        for elem in lis2:
            name = elem.split('T')[0]
            dcTo[name].append(elem)

        for kk in dcSi.keys():

            count_food_Side = len(dcSi[kk])
            train_size_Side = floor((count_food_Side/10)*9.5)
            print(count_food_Side,train_size_Side,"SIDE>>>>>>>>",kk)
            count_food_Top = len(dcTo[kk])
            train_size_Top=floor((count_food_Top/10)*9.5)
            print(count_food_Top,train_size_Top,"TOP>>>>>>>>",kk)
            print(kk,dcSi[kk])
            print(kk,dcTo[kk],"\n")

            for i in range(train_size_Side):
                filename=dcSi[kk][i]
                shutil.move("/content/ECUSTFD-resized-/Annotations/"+filename, "/content/ECUSTFD-resized-/Annotations/train/"+filename)

            for i in range(train_size_Side,count_food_Side):
                filename=dcSi[kk][i]
                shutil.move("/content/ECUSTFD-resized-/Annotations/"+filename,"/content/ECUSTFD-resized-/Annotations/test/"+filename)

            for i in range(train_size_Top):
                filename = dcTo[kk][i]
                shutil.move("/content/ECUSTFD-resized-/Annotations/"+filename,"/content/ECUSTFD-resized-/Annotations/train/"+filename)

            for i in range(train_size_Top,count_food_Top):
                filename = dcTo[kk][i]
                shutil.move("/content/ECUSTFD-resized-/Annotations/"+filename,"/content/ECUSTFD-resized-/Annotations/test/"+filename)
# Out:
# qiwi003S(4).xml
# qiwi003T(4).xml
# apple
#  151
# 145
#  --------------
# banana
#  89
# 89
#  --------------
# bread
#  36
# 30
#  --------------
# bun
#  45
# 45
#  --------------
# doughnut
#  105
# 105
#  --------------
# egg
#  43
# 61
#  --------------
# fired
#  62
# 62
#  --------------
# grape
#  29
# 29
#  --------------
# lemon
#  74
# 74
#  --------------
# litchi
#  39
# 39
#  --------------
# mango
#  110
# 110
#  --------------
# mooncake
#  67
# 67
#  --------------
# orange
#  127
# 127
#  --------------
# peach
#  63
# 63
#  --------------
# pear
#  83
# 83
#  --------------
# plum
#  88
# 88
#  --------------
# qiwi
#  60
# 60
#  --------------
# sachima
#  75
# 75
#  --------------
# tomato
#  86
# 86
#  --------------
# mix
#  53
# 55
#  --------------
# 2978
# 151 10000000143 SIDE>>>>>>>>
# 145 123 TOP>>>>>>>>
# dict_keys(['apple015', 'apple008', 'apple017', 'apple002', 'apple003', 'apple013', 'apple018', 'apple011', 'apple010', 'apple016', 'apple012', 'apple006', 'apple005', 'apple014', 'apple019', 'apple009', 'apple004', 'apple007', 'apple001'])
# 13 12 SIDE>>>>>>>> apple015
# 13 12 TOP>>>>>>>> apple015
# apple015 ['apple015S(1).xml', 'apple015S(13).xml', 'apple015S(11).xml', 'apple015S(8).xml', 'apple015S(6).xml', 'apple015S(2).xml', 'apple015S(10).xml', 'apple015S(5).xml', 'apple015S(4).xml', 'apple015S(7).xml', 'apple015S(3).xml', 'apple015S(12).xml', 'apple015S(9).xml']
# apple015 ['apple015T(13).xml', 'apple015T(7).xml', 'apple015T(5).xml', 'apple015T(11).xml', 'apple015T(8).xml', 'apple015T(6).xml', 'apple015T(12).xml', 'apple015T(10).xml', 'apple015T(1).xml', 'apple015T(2).xml', 'apple015T(4).xml', 'apple015T(3).xml', 'apple015T(9).xml']
#
# 4 3 SIDE>>>>>>>> apple008
# 4 3 TOP>>>>>>>> apple008
# apple008 ['apple008S(4).xml', 'apple008S(3).xml', 'apple008S(1).xml', 'apple008S(2).xml']
# apple008 ['apple008T(2).xml', 'apple008T(3).xml', 'apple008T(1).xml', 'apple008T(4).xml']
#
# 27 25 SIDE>>>>>>>> apple017
# 27 25 TOP>>>>>>>> apple017
# apple017 ['apple017S(24).xml', 'apple017S(5).xml', 'apple017S(9).xml', 'apple017S(21).xml', 'apple017S(25).xml', 'apple017S(23).xml', 'apple017S(16).xml', 'apple017S(8).xml', 'apple017S(17).xml', 'apple017S(2).xml', 'apple017S(18).xml', 'apple017S(10).xml', 'apple017S(4).xml', 'apple017S(15).xml', 'apple017S(14).xml', 'apple017S(6).xml', 'apple017S(1).xml', 'apple017S(20).xml', 'apple017S(13).xml', 'apple017S(26).xml', 'apple017S(12).xml', 'apple017S(3).xml', 'apple017S(7).xml', 'apple017S(11).xml', 'apple017S(19).xml', 'apple017S(22).xml', 'apple017S(27).xml']
# apple017 ['apple017T(25).xml', 'apple017T(20).xml', 'apple017T(23).xml', 'apple017T(26).xml', 'apple017T(21).xml', 'apple017T(12).xml', 'apple017T(17).xml', 'apple017T(7).xml', 'apple017T(16).xml', 'apple017T(5).xml', 'apple017T(27).xml', 'apple017T(22).xml', 'apple017T(6).xml', 'apple017T(15).xml', 'apple017T(10).xml', 'apple017T(9).xml', 'apple017T(14).xml', 'apple017T(2).xml', 'apple017T(1).xml', 'apple017T(18).xml', 'apple017T(4).xml', 'apple017T(3).xml', 'apple017T(19).xml', 'apple017T(11).xml', 'apple017T(24).xml', 'apple017T(8).xml', 'apple017T(13).xml']
#
# 8 7 SIDE>>>>>>>> apple002
# 6 5 TOP>>>>>>>> apple002
# apple002 ['apple002S(2).xml', 'apple002S(5).xml', 'apple002S(4).xml', 'apple002S(1).xml', 'apple002S(3).xml', 'apple002S(8).xml', 'apple002S(6).xml', 'apple002S(7).xml']
# apple002 ['apple002T(3).xml', 'apple002T(2).xml', 'apple002T(4).xml', 'apple002T(5).xml', 'apple002T(6).xml', 'apple002T(1).xml']
#
# 6 5 SIDE>>>>>>>> apple003
# 2 1 TOP>>>>>>>> apple003
# apple003 ['apple003S(4).xml', 'apple003S(5).xml', 'apple003S(2).xml', 'apple003S(3).xml', 'apple003S(6).xml', 'apple003S(1).xml']
# apple003 ['apple003T(2).xml', 'apple003T(1).xml']
#
# 8 7 SIDE>>>>>>>> apple013
# 8 7 TOP>>>>>>>> apple013
# apple013 ['apple013S(5).xml', 'apple013S(2).xml', 'apple013S(4).xml', 'apple013S(3).xml', 'apple013S(7).xml', 'apple013S(6).xml', 'apple013S(8).xml', 'apple013S(1).xml']
# apple013 ['apple013T(4).xml', 'apple013T(7).xml', 'apple013T(5).xml', 'apple013T(2).xml', 'apple013T(8).xml', 'apple013T(1).xml', 'apple013T(6).xml', 'apple013T(3).xml']
#
# 11 10 SIDE>>>>>>>> apple018
# 11 10 TOP>>>>>>>> apple018
# apple018 ['apple018S(7).xml', 'apple018S(5).xml', 'apple018S(11).xml', 'apple018S(1).xml', 'apple018S(4).xml', 'apple018S(3).xml', 'apple018S(8).xml', 'apple018S(6).xml', 'apple018S(2).xml', 'apple018S(10).xml', 'apple018S(9).xml']
# apple018 ['apple018T(6).xml', 'apple018T(4).xml', 'apple018T(8).xml', 'apple018T(1).xml', 'apple018T(7).xml', 'apple018T(10).xml', 'apple018T(2).xml', 'apple018T(11).xml', 'apple018T(3).xml', 'apple018T(9).xml', 'apple018T(5).xml']
#
# 5 4 SIDE>>>>>>>> apple011
# 5 4 TOP>>>>>>>> apple011
# apple011 ['apple011S(5).xml', 'apple011S(2).xml', 'apple011S(1).xml', 'apple011S(4).xml', 'apple011S(3).xml']
# apple011 ['apple011T(2).xml', 'apple011T(3).xml', 'apple011T(5).xml', 'apple011T(1).xml', 'apple011T(4).xml']
#
# 4 3 SIDE>>>>>>>> apple010
# 4 3 TOP>>>>>>>> apple010
# apple010 ['apple010S(1).xml', 'apple010S(3).xml', 'apple010S(4).xml', 'apple010S(2).xml']
# apple010 ['apple010T(1).xml', 'apple010T(2).xml', 'apple010T(3).xml', 'apple010T(4).xml']
#
# 25 23 SIDE>>>>>>>> apple016
# 25 23 TOP>>>>>>>> apple016
# apple016 ['apple016S(6).xml', 'apple016S(9).xml', 'apple016S(15).xml', 'apple016S(24).xml', 'apple016S(25).xml', 'apple016S(3).xml', 'apple016S(12).xml', 'apple016S(17).xml', 'apple016S(5).xml', 'apple016S(1).xml', 'apple016S(8).xml', 'apple016S(22).xml', 'apple016S(10).xml', 'apple016S(4).xml', 'apple016S(16).xml', 'apple016S(13).xml', 'apple016S(20).xml', 'apple016S(11).xml', 'apple016S(2).xml', 'apple016S(18).xml', 'apple016S(14).xml', 'apple016S(19).xml', 'apple016S(7).xml', 'apple016S(23).xml', 'apple016S(21).xml']
# apple016 ['apple016T(11).xml', 'apple016T(10).xml', 'apple016T(23).xml', 'apple016T(5).xml', 'apple016T(19).xml', 'apple016T(21).xml', 'apple016T(7).xml', 'apple016T(8).xml', 'apple016T(13).xml', 'apple016T(9).xml', 'apple016T(2).xml', 'apple016T(15).xml', 'apple016T(4).xml', 'apple016T(6).xml', 'apple016T(12).xml', 'apple016T(24).xml', 'apple016T(17).xml', 'apple016T(25).xml', 'apple016T(18).xml', 'apple016T(3).xml', 'apple016T(1).xml', 'apple016T(16).xml', 'apple016T(14).xml', 'apple016T(22).xml', 'apple016T(20).xml']
#
# 4 3 SIDE>>>>>>>> apple012
# 5 4 TOP>>>>>>>> apple012
# apple012 ['apple012S(3).xml', 'apple012S(4).xml', 'apple012S(2).xml', 'apple012S(1).xml']
# apple012 ['apple012T(5).xml', 'apple012T(1).xml', 'apple012T(2).xml', 'apple012T(4).xml', 'apple012T(3).xml']
#
# 4 3 SIDE>>>>>>>> apple006
# 4 3 TOP>>>>>>>> apple006
# apple006 ['apple006S(4).xml', 'apple006S(3).xml', 'apple006S(1).xml', 'apple006S(2).xml']
# apple006 ['apple006T(3).xml', 'apple006T(2).xml', 'apple006T(1).xml', 'apple006T(4).xml']
#
# 3 2 SIDE>>>>>>>> apple005
# 3 2 TOP>>>>>>>> apple005
# apple005 ['apple005S(1).xml', 'apple005S(5).xml', 'apple005S(6).xml']
# apple005 ['apple005T(1).xml', 'apple005T(6).xml', 'apple005T(5).xml']
#
# 8 7 SIDE>>>>>>>> apple014
# 8 7 TOP>>>>>>>> apple014
# apple014 ['apple014S(2).xml', 'apple014S(8).xml', 'apple014S(4).xml', 'apple014S(7).xml', 'apple014S(3).xml', 'apple014S(6).xml', 'apple014S(5).xml', 'apple014S(1).xml']
# apple014 ['apple014T(1).xml', 'apple014T(7).xml', 'apple014T(2).xml', 'apple014T(6).xml', 'apple014T(8).xml', 'apple014T(4).xml', 'apple014T(3).xml', 'apple014T(5).xml']
#
# 7 6 SIDE>>>>>>>> apple019
# 7 6 TOP>>>>>>>> apple019
# apple019 ['apple019S(1).xml', 'apple019S(7).xml', 'apple019S(2).xml', 'apple019S(5).xml', 'apple019S(4).xml', 'apple019S(3).xml', 'apple019S(6).xml']
# apple019 ['apple019T(6).xml', 'apple019T(1).xml', 'apple019T(2).xml', 'apple019T(7).xml', 'apple019T(5).xml', 'apple019T(3).xml', 'apple019T(4).xml']
#
# 4 3 SIDE>>>>>>>> apple009
# 4 3 TOP>>>>>>>> apple009
# apple009 ['apple009S(2).xml', 'apple009S(4).xml', 'apple009S(3).xml', 'apple009S(1).xml']
# apple009 ['apple009T(2).xml', 'apple009T(3).xml', 'apple009T(4).xml', 'apple009T(1).xml']
#
# 4 3 SIDE>>>>>>>> apple004
# 3 2 TOP>>>>>>>> apple004
# apple004 ['apple004S(4).xml', 'apple004S(3).xml', 'apple004S(1).xml', 'apple004S(2).xml']
# apple004 ['apple004T(2).xml', 'apple004T(3).xml', 'apple004T(1).xml']
#
# 4 3 SIDE>>>>>>>> apple007
# 4 3 TOP>>>>>>>> apple007
# apple007 ['apple007S(4).xml', 'apple007S(2).xml', 'apple007S(1).xml', 'apple007S(3).xml']
# apple007 ['apple007T(3).xml', 'apple007T(2).xml', 'apple007T(1).xml', 'apple007T(4).xml']
#
# 2 1 SIDE>>>>>>>> apple001
# 2 1 TOP>>>>>>>> apple001
# apple001 ['apple001S(1).xml', 'apple001S(2).xml']
# apple001 ['apple001T(1).xml', 'apple001T(2).xml']
#
# 89 10000000084 SIDE>>>>>>>>
# 89 75 TOP>>>>>>>>
# dict_keys(['banana015', 'banana005', 'banana012', 'banana001', 'banana011', 'banana003', 'banana013', 'banana007', 'banana014', 'banana010', 'banana009', 'banana002', 'banana004', 'banana008', 'banana006'])
# 8 7 SIDE>>>>>>>> banana015
# 8 7 TOP>>>>>>>> banana015
# banana015 ['banana015S(6).xml', 'banana015S(1).xml', 'banana015S(8).xml', 'banana015S(2).xml', 'banana015S(7).xml', 'banana015S(5).xml', 'banana015S(4).xml', 'banana015S(3).xml']
# banana015 ['banana015T(2).xml', 'banana015T(6).xml', 'banana015T(8).xml', 'banana015T(5).xml', 'banana015T(3).xml', 'banana015T(1).xml', 'banana015T(7).xml', 'banana015T(4).xml']
#
# 3 2 SIDE>>>>>>>> banana005
# 3 2 TOP>>>>>>>> banana005
# banana005 ['banana005S(1).xml', 'banana005S(3).xml', 'banana005S(2).xml']
# banana005 ['banana005T(3).xml', 'banana005T(1).xml', 'banana005T(2).xml']
#
# 8 7 SIDE>>>>>>>> banana012
# 8 7 TOP>>>>>>>> banana012
# banana012 ['banana012S(5).xml', 'banana012S(7).xml', 'banana012S(2).xml', 'banana012S(3).xml', 'banana012S(4).xml', 'banana012S(8).xml', 'banana012S(1).xml', 'banana012S(6).xml']
# banana012 ['banana012T(6).xml', 'banana012T(4).xml', 'banana012T(5).xml', 'banana012T(7).xml', 'banana012T(3).xml', 'banana012T(1).xml', 'banana012T(2).xml', 'banana012T(8).xml']
#
# 3 2 SIDE>>>>>>>> banana001
# 4 3 TOP>>>>>>>> banana001
# banana001 ['banana001S(1).xml', 'banana001S(3).xml', 'banana001S(2).xml']
# banana001 ['banana001T(4).xml', 'banana001T(1).xml', 'banana001T(3).xml', 'banana001T(2).xml']
#
# 9 8 SIDE>>>>>>>> banana011
# 9 8 TOP>>>>>>>> banana011
# banana011 ['banana011S(4).xml', 'banana011S(6).xml', 'banana011S(5).xml', 'banana011S(8).xml', 'banana011S(1).xml', 'banana011S(2).xml', 'banana011S(7).xml', 'banana011S(9).xml', 'banana011S(3).xml']
# banana011 ['banana011T(5).xml', 'banana011T(8).xml', 'banana011T(9).xml', 'banana011T(4).xml', 'banana011T(2).xml', 'banana011T(7).xml', 'banana011T(1).xml', 'banana011T(3).xml', 'banana011T(6).xml']
#
# 3 2 SIDE>>>>>>>> banana003
# 2 1 TOP>>>>>>>> banana003
# banana003 ['banana003S(2).xml', 'banana003S(3).xml', 'banana003S(1).xml']
# banana003 ['banana003T(2).xml', 'banana003T(1).xml']
#
# 12 11 SIDE>>>>>>>> banana013
# 12 11 TOP>>>>>>>> banana013
# banana013 ['banana013S(9).xml', 'banana013S(7).xml', 'banana013S(6).xml', 'banana013S(3).xml', 'banana013S(1).xml', 'banana013S(12).xml', 'banana013S(5).xml', 'banana013S(8).xml', 'banana013S(11).xml', 'banana013S(4).xml', 'banana013S(2).xml', 'banana013S(10).xml']
# banana013 ['banana013T(4).xml', 'banana013T(2).xml', 'banana013T(5).xml', 'banana013T(1).xml', 'banana013T(12).xml', 'banana013T(9).xml', 'banana013T(8).xml', 'banana013T(11).xml', 'banana013T(6).xml', 'banana013T(7).xml', 'banana013T(3).xml', 'banana013T(10).xml']
#
# 3 2 SIDE>>>>>>>> banana007
# 3 2 TOP>>>>>>>> banana007
# banana007 ['banana007S(3).xml', 'banana007S(2).xml', 'banana007S(1).xml']
# banana007 ['banana007T(3).xml', 'banana007T(2).xml', 'banana007T(1).xml']
#
# 10 9 SIDE>>>>>>>> banana014
# 10 9 TOP>>>>>>>> banana014
# banana014 ['banana014S(6).xml', 'banana014S(4).xml', 'banana014S(8).xml', 'banana014S(7).xml', 'banana014S(2).xml', 'banana014S(3).xml', 'banana014S(1).xml', 'banana014S(5).xml', 'banana014S(10).xml', 'banana014S(9).xml']
# banana014 ['banana014T(3).xml', 'banana014T(9).xml', 'banana014T(7).xml', 'banana014T(6).xml', 'banana014T(4).xml', 'banana014T(5).xml', 'banana014T(8).xml', 'banana014T(1).xml', 'banana014T(10).xml', 'banana014T(2).xml']
#
# 8 7 SIDE>>>>>>>> banana010
# 8 7 TOP>>>>>>>> banana010
# banana010 ['banana010S(5).xml', 'banana010S(1).xml', 'banana010S(6).xml', 'banana010S(7).xml', 'banana010S(8).xml', 'banana010S(3).xml', 'banana010S(2).xml', 'banana010S(4).xml']
# banana010 ['banana010T(1).xml', 'banana010T(5).xml', 'banana010T(7).xml', 'banana010T(8).xml', 'banana010T(4).xml', 'banana010T(3).xml', 'banana010T(6).xml', 'banana010T(2).xml']
#
# 8 7 SIDE>>>>>>>> banana009
# 8 7 TOP>>>>>>>> banana009
# banana009 ['banana009S(3).xml', 'banana009S(6).xml', 'banana009S(4).xml', 'banana009S(1).xml', 'banana009S(7).xml', 'banana009S(5).xml', 'banana009S(8).xml', 'banana009S(2).xml']
# banana009 ['banana009T(6).xml', 'banana009T(4).xml', 'banana009T(7).xml', 'banana009T(2).xml', 'banana009T(1).xml', 'banana009T(8).xml', 'banana009T(5).xml', 'banana009T(3).xml']
#
# 3 2 SIDE>>>>>>>> banana002
# 3 2 TOP>>>>>>>> banana002
# banana002 ['banana002S(1).xml', 'banana002S(3).xml', 'banana002S(2).xml']
# banana002 ['banana002T(1).xml', 'banana002T(2).xml', 'banana002T(3).xml']
#
# 3 2 SIDE>>>>>>>> banana004
# 3 2 TOP>>>>>>>> banana004
# banana004 ['banana004S(1).xml', 'banana004S(2).xml', 'banana004S(3).xml']
# banana004 ['banana004T(1).xml', 'banana004T(2).xml', 'banana004T(3).xml']
#
# 5 4 SIDE>>>>>>>> banana008
# 5 4 TOP>>>>>>>> banana008
# banana008 ['banana008S(1).xml', 'banana008S(2).xml', 'banana008S(3).xml', 'banana008S(4).xml', 'banana008S(5).xml']
# banana008 ['banana008T(1).xml', 'banana008T(3).xml', 'banana008T(2).xml', 'banana008T(4).xml', 'banana008T(5).xml']
#
# 3 2 SIDE>>>>>>>> banana006
# 3 2 TOP>>>>>>>> banana006
# banana006 ['banana006S(3).xml', 'banana006S(1).xml', 'banana006S(2).xml']
# banana006 ['banana006T(1).xml', 'banana006T(3).xml', 'banana006T(2).xml']
#
# 36 10000000034 SIDE>>>>>>>>
# 30 25 TOP>>>>>>>>
# dict_keys(['bread007', 'bread001', 'bread005', 'bread003', 'bread006', 'bread002', 'bread004'])
# 8 7 SIDE>>>>>>>> bread007
# 8 7 TOP>>>>>>>> bread007
# bread007 ['bread007S(8).xml', 'bread007S(6).xml', 'bread007S(3).xml', 'bread007S(4).xml', 'bread007S(1).xml', 'bread007S(2).xml', 'bread007S(5).xml', 'bread007S(7).xml']
# bread007 ['bread007T(8).xml', 'bread007T(1).xml', 'bread007T(4).xml', 'bread007T(5).xml', 'bread007T(3).xml', 'bread007T(6).xml', 'bread007T(2).xml', 'bread007T(7).xml']
#
# 8 7 SIDE>>>>>>>> bread001
# 8 7 TOP>>>>>>>> bread001
# bread001 ['bread001S(3).xml', 'bread001S(6).xml', 'bread001S(1).xml', 'bread001S(4).xml', 'bread001S(7).xml', 'bread001S(2).xml', 'bread001S(8).xml', 'bread001S(5).xml']
# bread001 ['bread001T(6).xml', 'bread001T(4).xml', 'bread001T(1).xml', 'bread001T(5).xml', 'bread001T(2).xml', 'bread001T(3).xml', 'bread001T(8).xml', 'bread001T(7).xml']
#
# 3 2 SIDE>>>>>>>> bread005
# 3 2 TOP>>>>>>>> bread005
# bread005 ['bread005S(3).xml', 'bread005S(2).xml', 'bread005S(1).xml']
# bread005 ['bread005T(2).xml', 'bread005T(3).xml', 'bread005T(1).xml']
#
# 3 2 SIDE>>>>>>>> bread003
# 3 2 TOP>>>>>>>> bread003
# bread003 ['bread003S(1).xml', 'bread003S(3).xml', 'bread003S(2).xml']
# bread003 ['bread003T(1).xml', 'bread003T(2).xml', 'bread003T(3).xml']
#
# 4 3 SIDE>>>>>>>> bread006
# 4 3 TOP>>>>>>>> bread006
# bread006 ['bread006S(3).xml', 'bread006S(1).xml', 'bread006S(2).xml', 'bread006S(4).xml']
# bread006 ['bread006T(1).xml', 'bread006T(2).xml', 'bread006T(4).xml', 'bread006T(3).xml']
#
# 6 5 SIDE>>>>>>>> bread002
# 2 1 TOP>>>>>>>> bread002
# bread002 ['bread002S(6).xml', 'bread002S(5).xml', 'bread002S(2).xml', 'bread002S(1).xml', 'bread002S(4).xml', 'bread002S(3).xml']
# bread002 ['bread002T(1).xml', 'bread002T(2).xml']
#
# 4 3 SIDE>>>>>>>> bread004
# 2 1 TOP>>>>>>>> bread004
# bread004 ['bread004S(1).xml', 'bread004S(3).xml', 'bread004S(2).xml', 'bread004S(4).xml']
# bread004 ['bread004T(1).xml', 'bread004T(2).xml']
#
# 45 10000000042 SIDE>>>>>>>>
# 45 38 TOP>>>>>>>>
# dict_keys(['bun006', 'bun004', 'bun005', 'bun003', 'bun001', 'bun002', 'bun007', 'bun008'])
# 8 7 SIDE>>>>>>>> bun006
# 8 7 TOP>>>>>>>> bun006
# bun006 ['bun006S(8).xml', 'bun006S(1).xml', 'bun006S(4).xml', 'bun006S(3).xml', 'bun006S(6).xml', 'bun006S(7).xml', 'bun006S(5).xml', 'bun006S(2).xml']
# bun006 ['bun006T(4).xml', 'bun006T(7).xml', 'bun006T(8).xml', 'bun006T(3).xml', 'bun006T(1).xml', 'bun006T(2).xml', 'bun006T(6).xml', 'bun006T(5).xml']
#
# 8 7 SIDE>>>>>>>> bun004
# 8 7 TOP>>>>>>>> bun004
# bun004 ['bun004S(3).xml', 'bun004S(4).xml', 'bun004S(2).xml', 'bun004S(1).xml', 'bun004S(8).xml', 'bun004S(7).xml', 'bun004S(5).xml', 'bun004S(6).xml']
# bun004 ['bun004T(4).xml', 'bun004T(1).xml', 'bun004T(5).xml', 'bun004T(2).xml', 'bun004T(3).xml', 'bun004T(7).xml', 'bun004T(6).xml', 'bun004T(8).xml']
#
# 5 4 SIDE>>>>>>>> bun005
# 5 4 TOP>>>>>>>> bun005
# bun005 ['bun005S(1).xml', 'bun005S(5).xml', 'bun005S(3).xml', 'bun005S(4).xml', 'bun005S(2).xml']
# bun005 ['bun005T(3).xml', 'bun005T(2).xml', 'bun005T(4).xml', 'bun005T(5).xml', 'bun005T(1).xml']
#
# 4 3 SIDE>>>>>>>> bun003
# 4 3 TOP>>>>>>>> bun003
# bun003 ['bun003S(4).xml', 'bun003S(1).xml', 'bun003S(2).xml', 'bun003S(3).xml']
# bun003 ['bun003T(4).xml', 'bun003T(2).xml', 'bun003T(3).xml', 'bun003T(1).xml']
#
# 7 6 SIDE>>>>>>>> bun001
# 7 6 TOP>>>>>>>> bun001
# bun001 ['bun001S(7).xml', 'bun001S(3).xml', 'bun001S(6).xml', 'bun001S(4).xml', 'bun001S(1).xml', 'bun001S(2).xml', 'bun001S(5).xml']
# bun001 ['bun001T(3).xml', 'bun001T(6).xml', 'bun001T(7).xml', 'bun001T(1).xml', 'bun001T(4).xml', 'bun001T(2).xml', 'bun001T(5).xml']
#
# 5 4 SIDE>>>>>>>> bun002
# 5 4 TOP>>>>>>>> bun002
# bun002 ['bun002S(4).xml', 'bun002S(5).xml', 'bun002S(1).xml', 'bun002S(2).xml', 'bun002S(3).xml']
# bun002 ['bun002T(1).xml', 'bun002T(3).xml', 'bun002T(4).xml', 'bun002T(2).xml', 'bun002T(5).xml']
#
# 4 3 SIDE>>>>>>>> bun007
# 4 3 TOP>>>>>>>> bun007
# bun007 ['bun007S(2).xml', 'bun007S(4).xml', 'bun007S(3).xml', 'bun007S(1).xml']
# bun007 ['bun007T(1).xml', 'bun007T(4).xml', 'bun007T(3).xml', 'bun007T(2).xml']
#
# 4 3 SIDE>>>>>>>> bun008
# 4 3 TOP>>>>>>>> bun008
# bun008 ['bun008S(2).xml', 'bun008S(4).xml', 'bun008S(3).xml', 'bun008S(1).xml']
# bun008 ['bun008T(3).xml', 'bun008T(1).xml', 'bun008T(4).xml', 'bun008T(2).xml']
#
# 105 10000000099 SIDE>>>>>>>>
# 105 89 TOP>>>>>>>>
# dict_keys(['doughnut004', 'doughnut009', 'doughnut006', 'doughnut008', 'doughnut005', 'doughnut007', 'doughnut001', 'doughnut002', 'doughnut003'])
# 15 14 SIDE>>>>>>>> doughnut004
# 15 14 TOP>>>>>>>> doughnut004
# doughnut004 ['doughnut004S(9).xml', 'doughnut004S(1).xml', 'doughnut004S(12).xml', 'doughnut004S(14).xml', 'doughnut004S(6).xml', 'doughnut004S(11).xml', 'doughnut004S(10).xml', 'doughnut004S(4).xml', 'doughnut004S(5).xml', 'doughnut004S(15).xml', 'doughnut004S(7).xml', 'doughnut004S(8).xml', 'doughnut004S(13).xml', 'doughnut004S(2).xml', 'doughnut004S(3).xml']
# doughnut004 ['doughnut004T(2).xml', 'doughnut004T(15).xml', 'doughnut004T(5).xml', 'doughnut004T(3).xml', 'doughnut004T(10).xml', 'doughnut004T(9).xml', 'doughnut004T(6).xml', 'doughnut004T(8).xml', 'doughnut004T(11).xml', 'doughnut004T(1).xml', 'doughnut004T(13).xml', 'doughnut004T(14).xml', 'doughnut004T(4).xml', 'doughnut004T(12).xml', 'doughnut004T(7).xml']
#
# 14 13 SIDE>>>>>>>> doughnut009
# 14 13 TOP>>>>>>>> doughnut009
# doughnut009 ['doughnut009S(14).xml', 'doughnut009S(11).xml', 'doughnut009S(7).xml', 'doughnut009S(12).xml', 'doughnut009S(3).xml', 'doughnut009S(6).xml', 'doughnut009S(9).xml', 'doughnut009S(8).xml', 'doughnut009S(5).xml', 'doughnut009S(1).xml', 'doughnut009S(4).xml', 'doughnut009S(10).xml', 'doughnut009S(2).xml', 'doughnut009S(13).xml']
# doughnut009 ['doughnut009T(8).xml', 'doughnut009T(3).xml', 'doughnut009T(9).xml', 'doughnut009T(2).xml', 'doughnut009T(1).xml', 'doughnut009T(4).xml', 'doughnut009T(6).xml', 'doughnut009T(11).xml', 'doughnut009T(14).xml', 'doughnut009T(10).xml', 'doughnut009T(7).xml', 'doughnut009T(5).xml', 'doughnut009T(12).xml', 'doughnut009T(13).xml']
#
# 18 17 SIDE>>>>>>>> doughnut006
# 18 17 TOP>>>>>>>> doughnut006
# doughnut006 ['doughnut006S(2).xml', 'doughnut006S(19).xml', 'doughnut006S(7).xml', 'doughnut006S(6).xml', 'doughnut006S(10).xml', 'doughnut006S(13).xml', 'doughnut006S(3).xml', 'doughnut006S(15).xml', 'doughnut006S(18).xml', 'doughnut006S(4).xml', 'doughnut006S(16).xml', 'doughnut006S(1).xml', 'doughnut006S(12).xml', 'doughnut006S(14).xml', 'doughnut006S(5).xml', 'doughnut006S(11).xml', 'doughnut006S(17).xml', 'doughnut006S(8).xml']
# doughnut006 ['doughnut006T(6).xml', 'doughnut006T(13).xml', 'doughnut006T(2).xml', 'doughnut006T(9).xml', 'doughnut006T(16).xml', 'doughnut006T(8).xml', 'doughnut006T(15).xml', 'doughnut006T(5).xml', 'doughnut006T(17).xml', 'doughnut006T(4).xml', 'doughnut006T(18).xml', 'doughnut006T(14).xml', 'doughnut006T(10).xml', 'doughnut006T(11).xml', 'doughnut006T(12).xml', 'doughnut006T(1).xml', 'doughnut006T(3).xml', 'doughnut006T(7).xml']
#
# 14 13 SIDE>>>>>>>> doughnut008
# 14 13 TOP>>>>>>>> doughnut008
# doughnut008 ['doughnut008S(5).xml', 'doughnut008S(8).xml', 'doughnut008S(13).xml', 'doughnut008S(4).xml', 'doughnut008S(1).xml', 'doughnut008S(14).xml', 'doughnut008S(10).xml', 'doughnut008S(3).xml', 'doughnut008S(11).xml', 'doughnut008S(12).xml', 'doughnut008S(7).xml', 'doughnut008S(2).xml', 'doughnut008S(9).xml', 'doughnut008S(6).xml']
# doughnut008 ['doughnut008T(5).xml', 'doughnut008T(14).xml', 'doughnut008T(10).xml', 'doughnut008T(9).xml', 'doughnut008T(3).xml', 'doughnut008T(11).xml', 'doughnut008T(7).xml', 'doughnut008T(1).xml', 'doughnut008T(4).xml', 'doughnut008T(12).xml', 'doughnut008T(13).xml', 'doughnut008T(2).xml', 'doughnut008T(6).xml', 'doughnut008T(8).xml']
#
# 15 14 SIDE>>>>>>>> doughnut005
# 15 14 TOP>>>>>>>> doughnut005
# doughnut005 ['doughnut005S(14).xml', 'doughnut005S(3).xml', 'doughnut005S(10).xml', 'doughnut005S(6).xml', 'doughnut005S(8).xml', 'doughnut005S(4).xml', 'doughnut005S(13).xml', 'doughnut005S(2).xml', 'doughnut005S(5).xml', 'doughnut005S(1).xml', 'doughnut005S(15).xml', 'doughnut005S(11).xml', 'doughnut005S(7).xml', 'doughnut005S(12).xml', 'doughnut005S(9).xml']
# doughnut005 ['doughnut005T(10).xml', 'doughnut005T(14).xml', 'doughnut005T(13).xml', 'doughnut005T(12).xml', 'doughnut005T(11).xml', 'doughnut005T(3).xml', 'doughnut005T(6).xml', 'doughnut005T(1).xml', 'doughnut005T(2).xml', 'doughnut005T(7).xml', 'doughnut005T(5).xml', 'doughnut005T(8).xml', 'doughnut005T(4).xml', 'doughnut005T(9).xml', 'doughnut005T(15).xml']
#
# 15 14 SIDE>>>>>>>> doughnut007
# 15 14 TOP>>>>>>>> doughnut007
# doughnut007 ['doughnut007S(6).xml', 'doughnut007S(2).xml', 'doughnut007S(10).xml', 'doughnut007S(1).xml', 'doughnut007S(4).xml', 'doughnut007S(7).xml', 'doughnut007S(14).xml', 'doughnut007S(8).xml', 'doughnut007S(9).xml', 'doughnut007S(5).xml', 'doughnut007S(12).xml', 'doughnut007S(13).xml', 'doughnut007S(3).xml', 'doughnut007S(11).xml', 'doughnut007S(15).xml']
# doughnut007 ['doughnut007T(4).xml', 'doughnut007T(3).xml', 'doughnut007T(11).xml', 'doughnut007T(15).xml', 'doughnut007T(8).xml', 'doughnut007T(10).xml', 'doughnut007T(5).xml', 'doughnut007T(9).xml', 'doughnut007T(7).xml', 'doughnut007T(12).xml', 'doughnut007T(13).xml', 'doughnut007T(14).xml', 'doughnut007T(1).xml', 'doughnut007T(6).xml', 'doughnut007T(2).xml']
#
# 4 3 SIDE>>>>>>>> doughnut001
# 4 3 TOP>>>>>>>> doughnut001
# doughnut001 ['doughnut001S(4).xml', 'doughnut001S(3).xml', 'doughnut001S(1).xml', 'doughnut001S(2).xml']
# doughnut001 ['doughnut001T(1).xml', 'doughnut001T(2).xml', 'doughnut001T(3).xml', 'doughnut001T(4).xml']
#
# 7 6 SIDE>>>>>>>> doughnut002
# 7 6 TOP>>>>>>>> doughnut002
# doughnut002 ['doughnut002S(7).xml', 'doughnut002S(2).xml', 'doughnut002S(3).xml', 'doughnut002S(4).xml', 'doughnut002S(6).xml', 'doughnut002S(5).xml', 'doughnut002S(1).xml']
# doughnut002 ['doughnut002T(4).xml', 'doughnut002T(7).xml', 'doughnut002T(6).xml', 'doughnut002T(1).xml', 'doughnut002T(3).xml', 'doughnut002T(2).xml', 'doughnut002T(5).xml']
#
# 3 2 SIDE>>>>>>>> doughnut003
# 3 2 TOP>>>>>>>> doughnut003
# doughnut003 ['doughnut003S(2).xml', 'doughnut003S(1).xml', 'doughnut003S(3).xml']
# doughnut003 ['doughnut003T(2).xml', 'doughnut003T(1).xml', 'doughnut003T(3).xml']
#
# 43 10000000040 SIDE>>>>>>>>
# 61 51 TOP>>>>>>>>
# dict_keys(['egg007', 'egg004', 'egg001', 'egg005', 'egg003', 'egg006'])
# 9 8 SIDE>>>>>>>> egg007
# 9 8 TOP>>>>>>>> egg007
# egg007 ['egg007S(6).xml', 'egg007S(3).xml', 'egg007S(8).xml', 'egg007S(7).xml', 'egg007S(9).xml', 'egg007S(4).xml', 'egg007S(5).xml', 'egg007S(2).xml', 'egg007S(1).xml']
# egg007 ['egg007T(6).xml', 'egg007T(8).xml', 'egg007T(3).xml', 'egg007T(2).xml', 'egg007T(1).xml', 'egg007T(7).xml', 'egg007T(5).xml', 'egg007T(9).xml', 'egg007T(4).xml']
#
# 5 4 SIDE>>>>>>>> egg004
# 5 4 TOP>>>>>>>> egg004
# egg004 ['egg004S(4).xml', 'egg004S(1).xml', 'egg004S(2).xml', 'egg004S(5).xml', 'egg004S(3).xml']
# egg004 ['egg004T(1).xml', 'egg004T(2).xml', 'egg004T(3).xml', 'egg004T(4).xml', 'egg004T(5).xml']
#
# 7 6 SIDE>>>>>>>> egg001
# 7 6 TOP>>>>>>>> egg001
# egg001 ['egg001S(6).xml', 'egg001S(4).xml', 'egg001S(3).xml', 'egg001S(5).xml', 'egg001S(1).xml', 'egg001S(7).xml', 'egg001S(2).xml']
# egg001 ['egg001T(7).xml', 'egg001T(1).xml', 'egg001T(5).xml', 'egg001T(2).xml', 'egg001T(3).xml', 'egg001T(4).xml', 'egg001T(6).xml']
#
# 8 7 SIDE>>>>>>>> egg005
# 8 7 TOP>>>>>>>> egg005
# egg005 ['egg005S(4).xml', 'egg005S(6).xml', 'egg005S(5).xml', 'egg005S(3).xml', 'egg005S(7).xml', 'egg005S(1).xml', 'egg005S(8).xml', 'egg005S(2).xml']
# egg005 ['egg005T(6).xml', 'egg005T(7).xml', 'egg005T(2).xml', 'egg005T(8).xml', 'egg005T(3).xml', 'egg005T(5).xml', 'egg005T(1).xml', 'egg005T(4).xml']
#
# 6 5 SIDE>>>>>>>> egg003
# 6 5 TOP>>>>>>>> egg003
# egg003 ['egg003S(1).xml', 'egg003S(5).xml', 'egg003S(6).xml', 'egg003S(4).xml', 'egg003S(2).xml', 'egg003S(3).xml']
# egg003 ['egg003T(1).xml', 'egg003T(5).xml', 'egg003T(6).xml', 'egg003T(3).xml', 'egg003T(4).xml', 'egg003T(2).xml']
#
# 8 7 SIDE>>>>>>>> egg006
# 8 7 TOP>>>>>>>> egg006
# egg006 ['egg006S(2).xml', 'egg006S(4).xml', 'egg006S(3).xml', 'egg006S(1).xml', 'egg006S(8).xml', 'egg006S(5).xml', 'egg006S(7).xml', 'egg006S(6).xml']
# egg006 ['egg006T(5).xml', 'egg006T(2).xml', 'egg006T(1).xml', 'egg006T(8).xml', 'egg006T(4).xml', 'egg006T(7).xml', 'egg006T(3).xml', 'egg006T(6).xml']
#
# 62 10000000058 SIDE>>>>>>>>
# 62 52 TOP>>>>>>>>
# dict_keys(['fired_dough_twist002', 'fired_dough_twist007', 'fired_dough_twist004', 'fired_dough_twist006', 'fired_dough_twist001', 'fired_dough_twist005', 'fired_dough_twist003'])
# 10 9 SIDE>>>>>>>> fired_dough_twist002
# 10 9 TOP>>>>>>>> fired_dough_twist002
# fired_dough_twist002 ['fired_dough_twist002S(1).xml', 'fired_dough_twist002S(2).xml', 'fired_dough_twist002S(9).xml', 'fired_dough_twist002S(3).xml', 'fired_dough_twist002S(5).xml', 'fired_dough_twist002S(10).xml', 'fired_dough_twist002S(8).xml', 'fired_dough_twist002S(6).xml', 'fired_dough_twist002S(7).xml', 'fired_dough_twist002S(4).xml']
# fired_dough_twist002 ['fired_dough_twist002T(4).xml', 'fired_dough_twist002T(2).xml', 'fired_dough_twist002T(8).xml', 'fired_dough_twist002T(5).xml', 'fired_dough_twist002T(7).xml', 'fired_dough_twist002T(9).xml', 'fired_dough_twist002T(6).xml', 'fired_dough_twist002T(3).xml', 'fired_dough_twist002T(1).xml', 'fired_dough_twist002T(10).xml']
#
# 7 6 SIDE>>>>>>>> fired_dough_twist007
# 7 6 TOP>>>>>>>> fired_dough_twist007
# fired_dough_twist007 ['fired_dough_twist007S(6).xml', 'fired_dough_twist007S(7).xml', 'fired_dough_twist007S(2).xml', 'fired_dough_twist007S(5).xml', 'fired_dough_twist007S(1).xml', 'fired_dough_twist007S(3).xml', 'fired_dough_twist007S(4).xml']
# fired_dough_twist007 ['fired_dough_twist007T(3).xml', 'fired_dough_twist007T(1).xml', 'fired_dough_twist007T(2).xml', 'fired_dough_twist007T(5).xml', 'fired_dough_twist007T(7).xml', 'fired_dough_twist007T(6).xml', 'fired_dough_twist007T(4).xml']
#
# 10 9 SIDE>>>>>>>> fired_dough_twist004
# 10 9 TOP>>>>>>>> fired_dough_twist004
# fired_dough_twist004 ['fired_dough_twist004S(1).xml', 'fired_dough_twist004S(2).xml', 'fired_dough_twist004S(4).xml', 'fired_dough_twist004S(10).xml', 'fired_dough_twist004S(8).xml', 'fired_dough_twist004S(5).xml', 'fired_dough_twist004S(3).xml', 'fired_dough_twist004S(9).xml', 'fired_dough_twist004S(6).xml', 'fired_dough_twist004S(7).xml']
# fired_dough_twist004 ['fired_dough_twist004T(10).xml', 'fired_dough_twist004T(6).xml', 'fired_dough_twist004T(4).xml', 'fired_dough_twist004T(8).xml', 'fired_dough_twist004T(5).xml', 'fired_dough_twist004T(3).xml', 'fired_dough_twist004T(2).xml', 'fired_dough_twist004T(7).xml', 'fired_dough_twist004T(1).xml', 'fired_dough_twist004T(9).xml']
#
# 7 6 SIDE>>>>>>>> fired_dough_twist006
# 7 6 TOP>>>>>>>> fired_dough_twist006
# fired_dough_twist006 ['fired_dough_twist006S(2).xml', 'fired_dough_twist006S(3).xml', 'fired_dough_twist006S(4).xml', 'fired_dough_twist006S(6).xml', 'fired_dough_twist006S(5).xml', 'fired_dough_twist006S(7).xml', 'fired_dough_twist006S(1).xml']
# fired_dough_twist006 ['fired_dough_twist006T(1).xml', 'fired_dough_twist006T(3).xml', 'fired_dough_twist006T(5).xml', 'fired_dough_twist006T(7).xml', 'fired_dough_twist006T(4).xml', 'fired_dough_twist006T(2).xml', 'fired_dough_twist006T(6).xml']
#
# 9 8 SIDE>>>>>>>> fired_dough_twist001
# 9 8 TOP>>>>>>>> fired_dough_twist001
# fired_dough_twist001 ['fired_dough_twist001S(5).xml', 'fired_dough_twist001S(9).xml', 'fired_dough_twist001S(4).xml', 'fired_dough_twist001S(2).xml', 'fired_dough_twist001S(3).xml', 'fired_dough_twist001S(1).xml', 'fired_dough_twist001S(8).xml', 'fired_dough_twist001S(6).xml', 'fired_dough_twist001S(7).xml']
# fired_dough_twist001 ['fired_dough_twist001T(4).xml', 'fired_dough_twist001T(7).xml', 'fired_dough_twist001T(6).xml', 'fired_dough_twist001T(2).xml', 'fired_dough_twist001T(9).xml', 'fired_dough_twist001T(5).xml', 'fired_dough_twist001T(3).xml', 'fired_dough_twist001T(1).xml', 'fired_dough_twist001T(8).xml']
#
# 9 8 SIDE>>>>>>>> fired_dough_twist005
# 9 8 TOP>>>>>>>> fired_dough_twist005
# fired_dough_twist005 ['fired_dough_twist005S(4).xml', 'fired_dough_twist005S(6).xml', 'fired_dough_twist005S(3).xml', 'fired_dough_twist005S(5).xml', 'fired_dough_twist005S(8).xml', 'fired_dough_twist005S(1).xml', 'fired_dough_twist005S(2).xml', 'fired_dough_twist005S(7).xml', 'fired_dough_twist005S(9).xml']
# fired_dough_twist005 ['fired_dough_twist005T(2).xml', 'fired_dough_twist005T(7).xml', 'fired_dough_twist005T(8).xml', 'fired_dough_twist005T(6).xml', 'fired_dough_twist005T(1).xml', 'fired_dough_twist005T(3).xml', 'fired_dough_twist005T(5).xml', 'fired_dough_twist005T(9).xml', 'fired_dough_twist005T(4).xml']
#
# 10 9 SIDE>>>>>>>> fired_dough_twist003
# 10 9 TOP>>>>>>>> fired_dough_twist003
# fired_dough_twist003 ['fired_dough_twist003S(5).xml', 'fired_dough_twist003S(4).xml', 'fired_dough_twist003S(10).xml', 'fired_dough_twist003S(7).xml', 'fired_dough_twist003S(6).xml', 'fired_dough_twist003S(2).xml', 'fired_dough_twist003S(1).xml', 'fired_dough_twist003S(8).xml', 'fired_dough_twist003S(3).xml', 'fired_dough_twist003S(9).xml']
# fired_dough_twist003 ['fired_dough_twist003T(8).xml', 'fired_dough_twist003T(2).xml', 'fired_dough_twist003T(5).xml', 'fired_dough_twist003T(9).xml', 'fired_dough_twist003T(4).xml', 'fired_dough_twist003T(10).xml', 'fired_dough_twist003T(1).xml', 'fired_dough_twist003T(7).xml', 'fired_dough_twist003T(3).xml', 'fired_dough_twist003T(6).xml']
#
# 29 10000000027 SIDE>>>>>>>>
# 29 24 TOP>>>>>>>>
# dict_keys(['grape002', 'grape001'])
# 17 16 SIDE>>>>>>>> grape002
# 17 16 TOP>>>>>>>> grape002
# grape002 ['grape002S(11).xml', 'grape002S(5).xml', 'grape002S(7).xml', 'grape002S(10).xml', 'grape002S(3).xml', 'grape002S(2).xml', 'grape002S(12).xml', 'grape002S(13).xml', 'grape002S(17).xml', 'grape002S(9).xml', 'grape002S(4).xml', 'grape002S(1).xml', 'grape002S(14).xml', 'grape002S(8).xml', 'grape002S(15).xml', 'grape002S(6).xml', 'grape002S(16).xml']
# grape002 ['grape002T(6).xml', 'grape002T(14).xml', 'grape002T(11).xml', 'grape002T(7).xml', 'grape002T(15).xml', 'grape002T(9).xml', 'grape002T(8).xml', 'grape002T(10).xml', 'grape002T(13).xml', 'grape002T(1).xml', 'grape002T(16).xml', 'grape002T(5).xml', 'grape002T(12).xml', 'grape002T(3).xml', 'grape002T(2).xml', 'grape002T(17).xml', 'grape002T(4).xml']
#
# 12 11 SIDE>>>>>>>> grape001
# 12 11 TOP>>>>>>>> grape001
# grape001 ['grape001S(6).xml', 'grape001S(3).xml', 'grape001S(10).xml', 'grape001S(8).xml', 'grape001S(2).xml', 'grape001S(11).xml', 'grape001S(1).xml', 'grape001S(4).xml', 'grape001S(5).xml', 'grape001S(7).xml', 'grape001S(12).xml', 'grape001S(9).xml']
# grape001 ['grape001T(11).xml', 'grape001T(4).xml', 'grape001T(8).xml', 'grape001T(3).xml', 'grape001T(5).xml', 'grape001T(12).xml', 'grape001T(2).xml', 'grape001T(6).xml', 'grape001T(9).xml', 'grape001T(1).xml', 'grape001T(7).xml', 'grape001T(10).xml']
#
# 74 10000000070 SIDE>>>>>>>>
# 74 62 TOP>>>>>>>>
# dict_keys(['lemon002', 'lemon001', 'lemon003', 'lemon004'])
# 26 24 SIDE>>>>>>>> lemon002
# 26 24 TOP>>>>>>>> lemon002
# lemon002 ['lemon002S(22).xml', 'lemon002S(9).xml', 'lemon002S(5).xml', 'lemon002S(10).xml', 'lemon002S(12).xml', 'lemon002S(7).xml', 'lemon002S(23).xml', 'lemon002S(16).xml', 'lemon002S(17).xml', 'lemon002S(15).xml', 'lemon002S(20).xml', 'lemon002S(8).xml', 'lemon002S(2).xml', 'lemon002S(18).xml', 'lemon002S(14).xml', 'lemon002S(1).xml', 'lemon002S(21).xml', 'lemon002S(24).xml', 'lemon002S(25).xml', 'lemon002S(6).xml', 'lemon002S(3).xml', 'lemon002S(26).xml', 'lemon002S(19).xml', 'lemon002S(11).xml', 'lemon002S(4).xml', 'lemon002S(13).xml']
# lemon002 ['lemon002T(14).xml', 'lemon002T(23).xml', 'lemon002T(3).xml', 'lemon002T(9).xml', 'lemon002T(22).xml', 'lemon002T(15).xml', 'lemon002T(13).xml', 'lemon002T(10).xml', 'lemon002T(6).xml', 'lemon002T(11).xml', 'lemon002T(2).xml', 'lemon002T(25).xml', 'lemon002T(1).xml', 'lemon002T(24).xml', 'lemon002T(4).xml', 'lemon002T(26).xml', 'lemon002T(21).xml', 'lemon002T(17).xml', 'lemon002T(7).xml', 'lemon002T(16).xml', 'lemon002T(12).xml', 'lemon002T(5).xml', 'lemon002T(19).xml', 'lemon002T(8).xml', 'lemon002T(18).xml', 'lemon002T(20).xml']
#
# 18 17 SIDE>>>>>>>> lemon001
# 18 17 TOP>>>>>>>> lemon001
# lemon001 ['lemon001S(17).xml', 'lemon001S(7).xml', 'lemon001S(18).xml', 'lemon001S(9).xml', 'lemon001S(16).xml', 'lemon001S(11).xml', 'lemon001S(5).xml', 'lemon001S(3).xml', 'lemon001S(6).xml', 'lemon001S(4).xml', 'lemon001S(13).xml', 'lemon001S(2).xml', 'lemon001S(8).xml', 'lemon001S(10).xml', 'lemon001S(1).xml', 'lemon001S(15).xml', 'lemon001S(14).xml', 'lemon001S(12).xml']
# lemon001 ['lemon001T(16).xml', 'lemon001T(15).xml', 'lemon001T(2).xml', 'lemon001T(6).xml', 'lemon001T(11).xml', 'lemon001T(3).xml', 'lemon001T(18).xml', 'lemon001T(1).xml', 'lemon001T(14).xml', 'lemon001T(9).xml', 'lemon001T(10).xml', 'lemon001T(5).xml', 'lemon001T(7).xml', 'lemon001T(17).xml', 'lemon001T(8).xml', 'lemon001T(4).xml', 'lemon001T(13).xml', 'lemon001T(12).xml']
#
# 18 17 SIDE>>>>>>>> lemon003
# 18 17 TOP>>>>>>>> lemon003
# lemon003 ['lemon003S(9).xml', 'lemon003S(18).xml', 'lemon003S(13).xml', 'lemon003S(2).xml', 'lemon003S(6).xml', 'lemon003S(15).xml', 'lemon003S(11).xml', 'lemon003S(17).xml', 'lemon003S(1).xml', 'lemon003S(10).xml', 'lemon003S(5).xml', 'lemon003S(12).xml', 'lemon003S(3).xml', 'lemon003S(7).xml', 'lemon003S(4).xml', 'lemon003S(14).xml', 'lemon003S(8).xml', 'lemon003S(16).xml']
# lemon003 ['lemon003T(18).xml', 'lemon003T(14).xml', 'lemon003T(17).xml', 'lemon003T(13).xml', 'lemon003T(7).xml', 'lemon003T(16).xml', 'lemon003T(1).xml', 'lemon003T(10).xml', 'lemon003T(12).xml', 'lemon003T(6).xml', 'lemon003T(2).xml', 'lemon003T(11).xml', 'lemon003T(15).xml', 'lemon003T(4).xml', 'lemon003T(9).xml', 'lemon003T(5).xml', 'lemon003T(3).xml', 'lemon003T(8).xml']
#
# 12 11 SIDE>>>>>>>> lemon004
# 12 11 TOP>>>>>>>> lemon004
# lemon004 ['lemon004S(9).xml', 'lemon004S(11).xml', 'lemon004S(5).xml', 'lemon004S(10).xml', 'lemon004S(6).xml', 'lemon004S(2).xml', 'lemon004S(4).xml', 'lemon004S(8).xml', 'lemon004S(1).xml', 'lemon004S(12).xml', 'lemon004S(3).xml', 'lemon004S(7).xml']
# lemon004 ['lemon004T(9).xml', 'lemon004T(1).xml', 'lemon004T(10).xml', 'lemon004T(4).xml', 'lemon004T(8).xml', 'lemon004T(5).xml', 'lemon004T(12).xml', 'lemon004T(3).xml', 'lemon004T(7).xml', 'lemon004T(6).xml', 'lemon004T(11).xml', 'lemon004T(2).xml']
#
# 39 10000000037 SIDE>>>>>>>>
# 39 33 TOP>>>>>>>>
# dict_keys(['litchi005', 'litchi004', 'litchi003', 'litchi002', 'litchi001'])
# 8 7 SIDE>>>>>>>> litchi005
# 8 7 TOP>>>>>>>> litchi005
# litchi005 ['litchi005S(6).xml', 'litchi005S(5).xml', 'litchi005S(3).xml', 'litchi005S(7).xml', 'litchi005S(4).xml', 'litchi005S(8).xml', 'litchi005S(2).xml', 'litchi005S(1).xml']
# litchi005 ['litchi005T(2).xml', 'litchi005T(8).xml', 'litchi005T(1).xml', 'litchi005T(4).xml', 'litchi005T(3).xml', 'litchi005T(7).xml', 'litchi005T(6).xml', 'litchi005T(5).xml']
#
# 8 7 SIDE>>>>>>>> litchi004
# 8 7 TOP>>>>>>>> litchi004
# litchi004 ['litchi004S(4).xml', 'litchi004S(2).xml', 'litchi004S(6).xml', 'litchi004S(7).xml', 'litchi004S(3).xml', 'litchi004S(1).xml', 'litchi004S(8).xml', 'litchi004S(5).xml']
# litchi004 ['litchi004T(3).xml', 'litchi004T(1).xml', 'litchi004T(6).xml', 'litchi004T(5).xml', 'litchi004T(2).xml', 'litchi004T(7).xml', 'litchi004T(8).xml', 'litchi004T(4).xml']
#
# 8 7 SIDE>>>>>>>> litchi003
# 8 7 TOP>>>>>>>> litchi003
# litchi003 ['litchi003S(5).xml', 'litchi003S(4).xml', 'litchi003S(6).xml', 'litchi003S(7).xml', 'litchi003S(1).xml', 'litchi003S(2).xml', 'litchi003S(3).xml', 'litchi003S(8).xml']
# litchi003 ['litchi003T(5).xml', 'litchi003T(3).xml', 'litchi003T(1).xml', 'litchi003T(4).xml', 'litchi003T(7).xml', 'litchi003T(8).xml', 'litchi003T(6).xml', 'litchi003T(2).xml']
#
# 8 7 SIDE>>>>>>>> litchi002
# 8 7 TOP>>>>>>>> litchi002
# litchi002 ['litchi002S(8).xml', 'litchi002S(1).xml', 'litchi002S(3).xml', 'litchi002S(5).xml', 'litchi002S(4).xml', 'litchi002S(6).xml', 'litchi002S(7).xml', 'litchi002S(2).xml']
# litchi002 ['litchi002T(2).xml', 'litchi002T(4).xml', 'litchi002T(6).xml', 'litchi002T(5).xml', 'litchi002T(8).xml', 'litchi002T(1).xml', 'litchi002T(3).xml', 'litchi002T(7).xml']
#
# 7 6 SIDE>>>>>>>> litchi001
# 7 6 TOP>>>>>>>> litchi001
# litchi001 ['litchi001S(2).xml', 'litchi001S(6).xml', 'litchi001S(1).xml', 'litchi001S(7).xml', 'litchi001S(4).xml', 'litchi001S(5).xml', 'litchi001S(3).xml']
# litchi001 ['litchi001T(4).xml', 'litchi001T(6).xml', 'litchi001T(5).xml', 'litchi001T(1).xml', 'litchi001T(3).xml', 'litchi001T(7).xml', 'litchi001T(2).xml']
#
# 110 10000000104 SIDE>>>>>>>>
# 110 93 TOP>>>>>>>>
# dict_keys(['mango003', 'mango004', 'mango010', 'mango009', 'mango007', 'mango001', 'mango006', 'mango005', 'mango002', 'mango008'])
# 11 10 SIDE>>>>>>>> mango003
# 11 10 TOP>>>>>>>> mango003
# mango003 ['mango003S(11).xml', 'mango003S(5).xml', 'mango003S(9).xml', 'mango003S(8).xml', 'mango003S(6).xml', 'mango003S(1).xml', 'mango003S(3).xml', 'mango003S(10).xml', 'mango003S(7).xml', 'mango003S(2).xml', 'mango003S(4).xml']
# mango003 ['mango003T(8).xml', 'mango003T(7).xml', 'mango003T(9).xml', 'mango003T(5).xml', 'mango003T(4).xml', 'mango003T(3).xml', 'mango003T(1).xml', 'mango003T(11).xml', 'mango003T(10).xml', 'mango003T(2).xml', 'mango003T(6).xml']
#
# 10 9 SIDE>>>>>>>> mango004
# 10 9 TOP>>>>>>>> mango004
# mango004 ['mango004S(5).xml', 'mango004S(3).xml', 'mango004S(6).xml', 'mango004S(4).xml', 'mango004S(9).xml', 'mango004S(2).xml', 'mango004S(8).xml', 'mango004S(1).xml', 'mango004S(10).xml', 'mango004S(7).xml']
# mango004 ['mango004T(10).xml', 'mango004T(9).xml', 'mango004T(5).xml', 'mango004T(3).xml', 'mango004T(7).xml', 'mango004T(8).xml', 'mango004T(2).xml', 'mango004T(6).xml', 'mango004T(4).xml', 'mango004T(1).xml']
#
# 11 10 SIDE>>>>>>>> mango010
# 11 10 TOP>>>>>>>> mango010
# mango010 ['mango010S(11).xml', 'mango010S(1).xml', 'mango010S(4).xml', 'mango010S(3).xml', 'mango010S(6).xml', 'mango010S(7).xml', 'mango010S(8).xml', 'mango010S(10).xml', 'mango010S(5).xml', 'mango010S(9).xml', 'mango010S(2).xml']
# mango010 ['mango010T(5).xml', 'mango010T(2).xml', 'mango010T(4).xml', 'mango010T(3).xml', 'mango010T(8).xml', 'mango010T(1).xml', 'mango010T(11).xml', 'mango010T(10).xml', 'mango010T(9).xml', 'mango010T(6).xml', 'mango010T(7).xml']
#
# 13 12 SIDE>>>>>>>> mango009
# 13 12 TOP>>>>>>>> mango009
# mango009 ['mango009S(4).xml', 'mango009S(5).xml', 'mango009S(9).xml', 'mango009S(12).xml', 'mango009S(1).xml', 'mango009S(6).xml', 'mango009S(13).xml', 'mango009S(8).xml', 'mango009S(10).xml', 'mango009S(11).xml', 'mango009S(7).xml', 'mango009S(2).xml', 'mango009S(3).xml']
# mango009 ['mango009T(6).xml', 'mango009T(4).xml', 'mango009T(12).xml', 'mango009T(1).xml', 'mango009T(11).xml', 'mango009T(7).xml', 'mango009T(5).xml', 'mango009T(2).xml', 'mango009T(9).xml', 'mango009T(8).xml', 'mango009T(10).xml', 'mango009T(3).xml', 'mango009T(13).xml']
#
# 13 12 SIDE>>>>>>>> mango007
# 13 12 TOP>>>>>>>> mango007
# mango007 ['mango007S(11).xml', 'mango007S(7).xml', 'mango007S(4).xml', 'mango007S(13).xml', 'mango007S(3).xml', 'mango007S(8).xml', 'mango007S(1).xml', 'mango007S(10).xml', 'mango007S(2).xml', 'mango007S(12).xml', 'mango007S(5).xml', 'mango007S(6).xml', 'mango007S(9).xml']
# mango007 ['mango007T(8).xml', 'mango007T(1).xml', 'mango007T(12).xml', 'mango007T(9).xml', 'mango007T(7).xml', 'mango007T(13).xml', 'mango007T(5).xml', 'mango007T(6).xml', 'mango007T(4).xml', 'mango007T(3).xml', 'mango007T(2).xml', 'mango007T(11).xml', 'mango007T(10).xml']
#
# 8 7 SIDE>>>>>>>> mango001
# 8 7 TOP>>>>>>>> mango001
# mango001 ['mango001S(8).xml', 'mango001S(2).xml', 'mango001S(6).xml', 'mango001S(1).xml', 'mango001S(3).xml', 'mango001S(7).xml', 'mango001S(4).xml', 'mango001S(5).xml']
# mango001 ['mango001T(7).xml', 'mango001T(3).xml', 'mango001T(5).xml', 'mango001T(2).xml', 'mango001T(6).xml', 'mango001T(4).xml', 'mango001T(1).xml', 'mango001T(8).xml']
#
# 14 13 SIDE>>>>>>>> mango006
# 14 13 TOP>>>>>>>> mango006
# mango006 ['mango006S(3).xml', 'mango006S(11).xml', 'mango006S(2).xml', 'mango006S(14).xml', 'mango006S(7).xml', 'mango006S(4).xml', 'mango006S(12).xml', 'mango006S(1).xml', 'mango006S(8).xml', 'mango006S(9).xml', 'mango006S(13).xml', 'mango006S(10).xml', 'mango006S(6).xml', 'mango006S(5).xml']
# mango006 ['mango006T(13).xml', 'mango006T(5).xml', 'mango006T(12).xml', 'mango006T(8).xml', 'mango006T(11).xml', 'mango006T(6).xml', 'mango006T(3).xml', 'mango006T(10).xml', 'mango006T(9).xml', 'mango006T(7).xml', 'mango006T(2).xml', 'mango006T(14).xml', 'mango006T(4).xml', 'mango006T(1).xml']
#
# 12 11 SIDE>>>>>>>> mango005
# 12 11 TOP>>>>>>>> mango005
# mango005 ['mango005S(3).xml', 'mango005S(4).xml', 'mango005S(8).xml', 'mango005S(9).xml', 'mango005S(10).xml', 'mango005S(6).xml', 'mango005S(2).xml', 'mango005S(1).xml', 'mango005S(12).xml', 'mango005S(5).xml', 'mango005S(7).xml', 'mango005S(11).xml']
# mango005 ['mango005T(11).xml', 'mango005T(5).xml', 'mango005T(1).xml', 'mango005T(10).xml', 'mango005T(4).xml', 'mango005T(12).xml', 'mango005T(9).xml', 'mango005T(3).xml', 'mango005T(7).xml', 'mango005T(8).xml', 'mango005T(2).xml', 'mango005T(6).xml']
#
# 10 9 SIDE>>>>>>>> mango002
# 10 9 TOP>>>>>>>> mango002
# mango002 ['mango002S(6).xml', 'mango002S(8).xml', 'mango002S(9).xml', 'mango002S(3).xml', 'mango002S(10).xml', 'mango002S(2).xml', 'mango002S(4).xml', 'mango002S(5).xml', 'mango002S(7).xml', 'mango002S(1).xml']
# mango002 ['mango002T(2).xml', 'mango002T(6).xml', 'mango002T(9).xml', 'mango002T(4).xml', 'mango002T(3).xml', 'mango002T(8).xml', 'mango002T(1).xml', 'mango002T(7).xml', 'mango002T(5).xml', 'mango002T(10).xml']
#
# 8 7 SIDE>>>>>>>> mango008
# 8 7 TOP>>>>>>>> mango008
# mango008 ['mango008S(8).xml', 'mango008S(7).xml', 'mango008S(5).xml', 'mango008S(1).xml', 'mango008S(6).xml', 'mango008S(2).xml', 'mango008S(3).xml', 'mango008S(4).xml']
# mango008 ['mango008T(8).xml', 'mango008T(4).xml', 'mango008T(7).xml', 'mango008T(6).xml', 'mango008T(5).xml', 'mango008T(3).xml', 'mango008T(2).xml', 'mango008T(1).xml']
#
# 67 10000000063 SIDE>>>>>>>>
# 67 56 TOP>>>>>>>>
# dict_keys(['mooncake003', 'mooncake002', 'mooncake004', 'mooncake006', 'mooncake001', 'mooncake005'])
# 13 12 SIDE>>>>>>>> mooncake003
# 13 12 TOP>>>>>>>> mooncake003
# mooncake003 ['mooncake003S(7).xml', 'mooncake003S(3).xml', 'mooncake003S(8).xml', 'mooncake003S(12).xml', 'mooncake003S(1).xml', 'mooncake003S(5).xml', 'mooncake003S(4).xml', 'mooncake003S(2).xml', 'mooncake003S(9).xml', 'mooncake003S(11).xml', 'mooncake003S(13).xml', 'mooncake003S(6).xml', 'mooncake003S(10).xml']
# mooncake003 ['mooncake003T(11).xml', 'mooncake003T(10).xml', 'mooncake003T(7).xml', 'mooncake003T(8).xml', 'mooncake003T(13).xml', 'mooncake003T(3).xml', 'mooncake003T(12).xml', 'mooncake003T(2).xml', 'mooncake003T(5).xml', 'mooncake003T(6).xml', 'mooncake003T(9).xml', 'mooncake003T(1).xml', 'mooncake003T(4).xml']
#
# 17 16 SIDE>>>>>>>> mooncake002
# 17 16 TOP>>>>>>>> mooncake002
# mooncake002 ['mooncake002S(6).xml', 'mooncake002S(17).xml', 'mooncake002S(3).xml', 'mooncake002S(15).xml', 'mooncake002S(5).xml', 'mooncake002S(12).xml', 'mooncake002S(9).xml', 'mooncake002S(2).xml', 'mooncake002S(4).xml', 'mooncake002S(1).xml', 'mooncake002S(8).xml', 'mooncake002S(11).xml', 'mooncake002S(10).xml', 'mooncake002S(7).xml', 'mooncake002S(13).xml', 'mooncake002S(16).xml', 'mooncake002S(14).xml']
# mooncake002 ['mooncake002T(3).xml', 'mooncake002T(14).xml', 'mooncake002T(10).xml', 'mooncake002T(11).xml', 'mooncake002T(1).xml', 'mooncake002T(6).xml', 'mooncake002T(2).xml', 'mooncake002T(15).xml', 'mooncake002T(5).xml', 'mooncake002T(7).xml', 'mooncake002T(13).xml', 'mooncake002T(8).xml', 'mooncake002T(16).xml', 'mooncake002T(17).xml', 'mooncake002T(12).xml', 'mooncake002T(4).xml', 'mooncake002T(9).xml']
#
# 6 5 SIDE>>>>>>>> mooncake004
# 6 5 TOP>>>>>>>> mooncake004
# mooncake004 ['mooncake004S(4).xml', 'mooncake004S(1).xml', 'mooncake004S(3).xml', 'mooncake004S(5).xml', 'mooncake004S(2).xml', 'mooncake004S(6).xml']
# mooncake004 ['mooncake004T(1).xml', 'mooncake004T(2).xml', 'mooncake004T(5).xml', 'mooncake004T(6).xml', 'mooncake004T(3).xml', 'mooncake004T(4).xml']
#
# 8 7 SIDE>>>>>>>> mooncake006
# 8 7 TOP>>>>>>>> mooncake006
# mooncake006 ['mooncake006S(1).xml', 'mooncake006S(8).xml', 'mooncake006S(7).xml', 'mooncake006S(2).xml', 'mooncake006S(3).xml', 'mooncake006S(6).xml', 'mooncake006S(4).xml', 'mooncake006S(5).xml']
# mooncake006 ['mooncake006T(5).xml', 'mooncake006T(3).xml', 'mooncake006T(4).xml', 'mooncake006T(8).xml', 'mooncake006T(6).xml', 'mooncake006T(7).xml', 'mooncake006T(2).xml', 'mooncake006T(1).xml']
#
# 16 15 SIDE>>>>>>>> mooncake001
# 16 15 TOP>>>>>>>> mooncake001
# mooncake001 ['mooncake001S(12).xml', 'mooncake001S(9).xml', 'mooncake001S(13).xml', 'mooncake001S(8).xml', 'mooncake001S(2).xml', 'mooncake001S(4).xml', 'mooncake001S(11).xml', 'mooncake001S(14).xml', 'mooncake001S(1).xml', 'mooncake001S(16).xml', 'mooncake001S(3).xml', 'mooncake001S(6).xml', 'mooncake001S(15).xml', 'mooncake001S(5).xml', 'mooncake001S(7).xml', 'mooncake001S(10).xml']
# mooncake001 ['mooncake001T(12).xml', 'mooncake001T(15).xml', 'mooncake001T(16).xml', 'mooncake001T(14).xml', 'mooncake001T(2).xml', 'mooncake001T(10).xml', 'mooncake001T(1).xml', 'mooncake001T(4).xml', 'mooncake001T(3).xml', 'mooncake001T(7).xml', 'mooncake001T(6).xml', 'mooncake001T(8).xml', 'mooncake001T(5).xml', 'mooncake001T(13).xml', 'mooncake001T(9).xml', 'mooncake001T(11).xml']
#
# 7 6 SIDE>>>>>>>> mooncake005
# 7 6 TOP>>>>>>>> mooncake005
# mooncake005 ['mooncake005S(7).xml', 'mooncake005S(4).xml', 'mooncake005S(6).xml', 'mooncake005S(5).xml', 'mooncake005S(3).xml', 'mooncake005S(2).xml', 'mooncake005S(1).xml']
# mooncake005 ['mooncake005T(3).xml', 'mooncake005T(5).xml', 'mooncake005T(1).xml', 'mooncake005T(6).xml', 'mooncake005T(2).xml', 'mooncake005T(4).xml', 'mooncake005T(7).xml']
#
# 127 10000000120 SIDE>>>>>>>>
# 127 107 TOP>>>>>>>>
# dict_keys(['orange002', 'orange011', 'orange009', 'orange007', 'orange006', 'orange013', 'orange001', 'orange008', 'orange012', 'orange015', 'orange003', 'orange004', 'orange010', 'orange005', 'orange014'])
# 4 3 SIDE>>>>>>>> orange002
# 2 1 TOP>>>>>>>> orange002
# orange002 ['orange002S(3).xml', 'orange002S(1).xml', 'orange002S(4).xml', 'orange002S(2).xml']
# orange002 ['orange002T(2).xml', 'orange002T(1).xml']
#
# 18 17 SIDE>>>>>>>> orange011
# 18 17 TOP>>>>>>>> orange011
# orange011 ['orange011S(3).xml', 'orange011S(13).xml', 'orange011S(8).xml', 'orange011S(9).xml', 'orange011S(1).xml', 'orange011S(17).xml', 'orange011S(16).xml', 'orange011S(12).xml', 'orange011S(15).xml', 'orange011S(6).xml', 'orange011S(14).xml', 'orange011S(18).xml', 'orange011S(11).xml', 'orange011S(2).xml', 'orange011S(10).xml', 'orange011S(7).xml', 'orange011S(5).xml', 'orange011S(4).xml']
# ...
#
# 19 18 SIDE>>>>>>>> plum002
# 19 18 TOP>>>>>>>> plum002
# plum002 ['plum002S(3).xml', 'plum002S(4).xml', 'plum002S(2).xml', 'plum002S(10).xml', 'plum002S(7).xml', 'plum002S(16).xml', 'plum002S(13).xml', 'plum002S(5).xml', 'plum002S(9).xml', 'plum002S(11).xml', 'plum002S(17).xml', 'plum002S(15).xml', 'plum002S(14).xml', 'plum002S(1).xml', 'plum002S(8).xml', 'plum002S(6).xml', 'plum002S(19).xml', 'plum002S(12).xml', 'plum002S(18).xml']
# plum002 ['plum002T(5).xml', 'plum002T(12).xml', 'plum002T(2).xml', 'plum002T(15).xml', 'plum002T(3).xml', 'plum002T(19).xml', 'plum002T(16).xml', 'plum002T(9).xml', 'plum002T(14).xml', 'plum002T(18).xml', 'plum002T(13).xml', 'plum002T(17).xml', 'plum002T(10).xml', 'plum002T(8).xml', 'plum002T(7).xml', 'plum002T(11).xml', 'plum002T(1).xml', 'plum002T(6).xml', 'plum002T(4).xml']
#
# 22 20 SIDE>>>>>>>> plum001
# 22 20 TOP>>>>>>>> plum001
# plum001 ['plum001S(20).xml', 'plum001S(1).xml', 'plum001S(8).xml', 'plum001S(5).xml', 'plum001S(18).xml', 'plum001S(13).xml', 'plum001S(14).xml', 'plum001S(16).xml', 'plum001S(4).xml', 'plum001S(22).xml', 'plum001S(10).xml', 'plum001S(7).xml', 'plum001S(19).xml', 'plum001S(15).xml', 'plum001S(21).xml', 'plum001S(9).xml', 'plum001S(3).xml', 'plum001S(12).xml', 'plum001S(17).xml', 'plum001S(2).xml', 'plum001S(11).xml', 'plum001S(6).xml']
# plum001 ['plum001T(1).xml', 'plum001T(15).xml', 'plum001T(10).xml', 'plum001T(13).xml', 'plum001T(7).xml', 'plum001T(4).xml', 'plum001T(5).xml', 'plum001T(19).xml', 'plum001T(2).xml', 'plum001T(17).xml', 'plum001T(9).xml', 'plum001T(6).xml', 'plum001T(21).xml', 'plum001T(18).xml', 'plum001T(16).xml', 'plum001T(12).xml', 'plum001T(20).xml', 'plum001T(11).xml', 'plum001T(22).xml', 'plum001T(14).xml', 'plum001T(8).xml', 'plum001T(3).xml']
#
# 60 10000000057 SIDE>>>>>>>>
# 60 51 TOP>>>>>>>>
# dict_keys(['qiwi008', 'qiwi003', 'qiwi005', 'qiwi006', 'qiwi001', 'qiwi007', 'qiwi004', 'qiwi002'])
# 9 8 SIDE>>>>>>>> qiwi008
# 9 8 TOP>>>>>>>> qiwi008
# qiwi008 ['qiwi008S(7).xml', 'qiwi008S(5).xml', 'qiwi008S(4).xml', 'qiwi008S(6).xml', 'qiwi008S(1).xml', 'qiwi008S(3).xml', 'qiwi008S(2).xml', 'qiwi008S(9).xml', 'qiwi008S(8).xml']
# qiwi008 ['qiwi008T(2).xml', 'qiwi008T(3).xml', 'qiwi008T(7).xml', 'qiwi008T(1).xml', 'qiwi008T(4).xml', 'qiwi008T(6).xml', 'qiwi008T(8).xml', 'qiwi008T(5).xml', 'qiwi008T(9).xml']
#
# 4 3 SIDE>>>>>>>> qiwi003
# 4 3 TOP>>>>>>>> qiwi003
# qiwi003 ['qiwi003S(4).xml', 'qiwi003S(3).xml', 'qiwi003S(1).xml', 'qiwi003S(2).xml']
# qiwi003 ['qiwi003T(1).xml', 'qiwi003T(2).xml', 'qiwi003T(3).xml', 'qiwi003T(4).xml']
#
# 8 7 SIDE>>>>>>>> qiwi005
# 8 7 TOP>>>>>>>> qiwi005
# qiwi005 ['qiwi005S(5).xml', 'qiwi005S(7).xml', 'qiwi005S(3).xml', 'qiwi005S(2).xml', 'qiwi005S(1).xml', 'qiwi005S(6).xml', 'qiwi005S(8).xml', 'qiwi005S(4).xml']
# qiwi005 ['qiwi005T(6).xml', 'qiwi005T(7).xml', 'qiwi005T(1).xml', 'qiwi005T(3).xml', 'qiwi005T(5).xml', 'qiwi005T(2).xml', 'qiwi005T(8).xml', 'qiwi005T(4).xml']
#
# 12 11 SIDE>>>>>>>> qiwi006
# 12 11 TOP>>>>>>>> qiwi006
# qiwi006 ['qiwi006S(4).xml', 'qiwi006S(5).xml', 'qiwi006S(12).xml', 'qiwi006S(9).xml', 'qiwi006S(10).xml', 'qiwi006S(3).xml', 'qiwi006S(8).xml', 'qiwi006S(2).xml', 'qiwi006S(11).xml', 'qiwi006S(1).xml', 'qiwi006S(7).xml', 'qiwi006S(6).xml']
# qiwi006 ['qiwi006T(9).xml', 'qiwi006T(10).xml', 'qiwi006T(12).xml', 'qiwi006T(2).xml', 'qiwi006T(11).xml', 'qiwi006T(6).xml', 'qiwi006T(7).xml', 'qiwi006T(5).xml', 'qiwi006T(8).xml', 'qiwi006T(1).xml', 'qiwi006T(3).xml', 'qiwi006T(4).xml']
#
# 4 3 SIDE>>>>>>>> qiwi001
# 4 3 TOP>>>>>>>> qiwi001
# qiwi001 ['qiwi001S(2).xml', 'qiwi001S(3).xml', 'qiwi001S(1).xml', 'qiwi001S(4).xml']
# qiwi001 ['qiwi001T(1).xml', 'qiwi001T(4).xml', 'qiwi001T(2).xml', 'qiwi001T(3).xml']
#
# 12 11 SIDE>>>>>>>> qiwi007
# 12 11 TOP>>>>>>>> qiwi007
# qiwi007 ['qiwi007S(9).xml', 'qiwi007S(8).xml', 'qiwi007S(1).xml', 'qiwi007S(11).xml', 'qiwi007S(6).xml', 'qiwi007S(7).xml', 'qiwi007S(3).xml', 'qiwi007S(10).xml', 'qiwi007S(4).xml', 'qiwi007S(5).xml', 'qiwi007S(2).xml', 'qiwi007S(12).xml']
# qiwi007 ['qiwi007T(11).xml', 'qiwi007T(8).xml', 'qiwi007T(4).xml', 'qiwi007T(7).xml', 'qiwi007T(12).xml', 'qiwi007T(1).xml', 'qiwi007T(3).xml', 'qiwi007T(10).xml', 'qiwi007T(5).xml', 'qiwi007T(2).xml', 'qiwi007T(9).xml', 'qiwi007T(6).xml']
#
# 8 7 SIDE>>>>>>>> qiwi004
# 8 7 TOP>>>>>>>> qiwi004
# qiwi004 ['qiwi004S(5).xml', 'qiwi004S(4).xml', 'qiwi004S(8).xml', 'qiwi004S(6).xml', 'qiwi004S(7).xml', 'qiwi004S(1).xml', 'qiwi004S(3).xml', 'qiwi004S(2).xml']
# qiwi004 ['qiwi004T(6).xml', 'qiwi004T(2).xml', 'qiwi004T(7).xml', 'qiwi004T(4).xml', 'qiwi004T(8).xml', 'qiwi004T(3).xml', 'qiwi004T(5).xml', 'qiwi004T(1).xml']
#
# 3 2 SIDE>>>>>>>> qiwi002
# 3 2 TOP>>>>>>>> qiwi002
# qiwi002 ['qiwi002S(1).xml', 'qiwi002S(2).xml', 'qiwi002S(3).xml']
# qiwi002 ['qiwi002T(2).xml', 'qiwi002T(1).xml', 'qiwi002T(3).xml']
#
# 75 10000000071 SIDE>>>>>>>>
# 75 63 TOP>>>>>>>>
# dict_keys(['sachima002', 'sachima005', 'sachima001', 'sachima004', 'sachima003'])
# 15 14 SIDE>>>>>>>> sachima002
# 15 14 TOP>>>>>>>> sachima002
# sachima002 ['sachima002S(10).xml', 'sachima002S(15).xml', 'sachima002S(14).xml', 'sachima002S(7).xml', 'sachima002S(6).xml', 'sachima002S(9).xml', 'sachima002S(13).xml', 'sachima002S(3).xml', 'sachima002S(8).xml', 'sachima002S(2).xml', 'sachima002S(11).xml', 'sachima002S(5).xml', 'sachima002S(4).xml', 'sachima002S(1).xml', 'sachima002S(12).xml']
# sachima002 ['sachima002T(2).xml', 'sachima002T(1).xml', 'sachima002T(5).xml', 'sachima002T(4).xml', 'sachima002T(7).xml', 'sachima002T(13).xml', 'sachima002T(11).xml', 'sachima002T(15).xml', 'sachima002T(14).xml', 'sachima002T(10).xml', 'sachima002T(8).xml', 'sachima002T(9).xml', 'sachima002T(12).xml', 'sachima002T(3).xml', 'sachima002T(6).xml']
#
# 22 20 SIDE>>>>>>>> sachima005
# 22 20 TOP>>>>>>>> sachima005
# sachima005 ['sachima005S(21).xml', 'sachima005S(18).xml', 'sachima005S(8).xml', 'sachima005S(17).xml', 'sachima005S(16).xml', 'sachima005S(9).xml', 'sachima005S(12).xml', 'sachima005S(7).xml', 'sachima005S(2).xml', 'sachima005S(3).xml', 'sachima005S(1).xml', 'sachima005S(19).xml', 'sachima005S(5).xml', 'sachima005S(4).xml', 'sachima005S(11).xml', 'sachima005S(22).xml', 'sachima005S(10).xml', 'sachima005S(20).xml', 'sachima005S(14).xml', 'sachima005S(6).xml', 'sachima005S(13).xml', 'sachima005S(15).xml']
# sachima005 ['sachima005T(5).xml', 'sachima005T(10).xml', 'sachima005T(22).xml', 'sachima005T(18).xml', 'sachima005T(15).xml', 'sachima005T(16).xml', 'sachima005T(21).xml', 'sachima005T(20).xml', 'sachima005T(1).xml', 'sachima005T(4).xml', 'sachima005T(14).xml', 'sachima005T(13).xml', 'sachima005T(7).xml', 'sachima005T(6).xml', 'sachima005T(11).xml', 'sachima005T(8).xml', 'sachima005T(19).xml', 'sachima005T(9).xml', 'sachima005T(3).xml', 'sachima005T(2).xml', 'sachima005T(12).xml', 'sachima005T(17).xml']
#
# 12 11 SIDE>>>>>>>> sachima001
# 12 11 TOP>>>>>>>> sachima001
# sachima001 ['sachima001S(8).xml', 'sachima001S(1).xml', 'sachima001S(9).xml', 'sachima001S(10).xml', 'sachima001S(7).xml', 'sachima001S(3).xml', 'sachima001S(2).xml', 'sachima001S(5).xml', 'sachima001S(6).xml', 'sachima001S(4).xml', 'sachima001S(11).xml', 'sachima001S(12).xml']
# sachima001 ['sachima001T(5).xml', 'sachima001T(6).xml', 'sachima001T(3).xml', 'sachima001T(12).xml', 'sachima001T(8).xml', 'sachima001T(11).xml', 'sachima001T(10).xml', 'sachima001T(9).xml', 'sachima001T(7).xml', 'sachima001T(2).xml', 'sachima001T(4).xml', 'sachima001T(1).xml']
#
# 13 12 SIDE>>>>>>>> sachima004
# 13 12 TOP>>>>>>>> sachima004
# sachima004 ['sachima004S(12).xml', 'sachima004S(4).xml', 'sachima004S(11).xml', 'sachima004S(3).xml', 'sachima004S(7).xml', 'sachima004S(5).xml', 'sachima004S(6).xml', 'sachima004S(1).xml', 'sachima004S(10).xml', 'sachima004S(2).xml', 'sachima004S(9).xml', 'sachima004S(8).xml', 'sachima004S(13).xml']
# sachima004 ['sachima004T(10).xml', 'sachima004T(4).xml', 'sachima004T(5).xml', 'sachima004T(9).xml', 'sachima004T(3).xml', 'sachima004T(12).xml', 'sachima004T(8).xml', 'sachima004T(13).xml', 'sachima004T(6).xml', 'sachima004T(11).xml', 'sachima004T(1).xml', 'sachima004T(2).xml', 'sachima004T(7).xml']
#
# 13 12 SIDE>>>>>>>> sachima003
# 13 12 TOP>>>>>>>> sachima003
# sachima003 ['sachima003S(7).xml', 'sachima003S(5).xml', 'sachima003S(4).xml', 'sachima003S(13).xml', 'sachima003S(10).xml', 'sachima003S(11).xml', 'sachima003S(1).xml', 'sachima003S(6).xml', 'sachima003S(9).xml', 'sachima003S(2).xml', 'sachima003S(3).xml', 'sachima003S(8).xml', 'sachima003S(12).xml']
# sachima003 ['sachima003T(2).xml', 'sachima003T(1).xml', 'sachima003T(8).xml', 'sachima003T(4).xml', 'sachima003T(5).xml', 'sachima003T(13).xml', 'sachima003T(9).xml', 'sachima003T(6).xml', 'sachima003T(7).xml', 'sachima003T(10).xml', 'sachima003T(3).xml', 'sachima003T(11).xml', 'sachima003T(12).xml']
#
# 86 10000000081 SIDE>>>>>>>>
# 86 73 TOP>>>>>>>>
# dict_keys(['tomato001', 'tomato003', 'tomato004', 'tomato002'])
# 10 9 SIDE>>>>>>>> tomato001
# 10 9 TOP>>>>>>>> tomato001
# tomato001 ['tomato001S(5).xml', 'tomato001S(3).xml', 'tomato001S(1).xml', 'tomato001S(9).xml', 'tomato001S(10).xml', 'tomato001S(2).xml', 'tomato001S(8).xml', 'tomato001S(6).xml', 'tomato001S(7).xml', 'tomato001S(4).xml']
# tomato001 ['tomato001T(3).xml', 'tomato001T(7).xml', 'tomato001T(1).xml', 'tomato001T(5).xml', 'tomato001T(6).xml', 'tomato001T(9).xml', 'tomato001T(2).xml', 'tomato001T(4).xml', 'tomato001T(8).xml', 'tomato001T(10).xml']
#
# 34 32 SIDE>>>>>>>> tomato003
# 34 32 TOP>>>>>>>> tomato003
# tomato003 ['tomato003S(9).xml', 'tomato003S(3).xml', 'tomato003S(28).xml', 'tomato003S(29).xml', 'tomato003S(23).xml', 'tomato003S(34).xml', 'tomato003S(30).xml', 'tomato003S(24).xml', 'tomato003S(8).xml', 'tomato003S(17).xml', 'tomato003S(11).xml', 'tomato003S(16).xml', 'tomato003S(10).xml', 'tomato003S(27).xml', 'tomato003S(33).xml', 'tomato003S(22).xml', 'tomato003S(25).xml', 'tomato003S(32).xml', 'tomato003S(26).xml', 'tomato003S(19).xml', 'tomato003S(14).xml', 'tomato003S(1).xml', 'tomato003S(2).xml', 'tomato003S(31).xml', 'tomato003S(7).xml', 'tomato003S(6).xml', 'tomato003S(18).xml', 'tomato003S(21).xml', 'tomato003S(15).xml', 'tomato003S(4).xml', 'tomato003S(13).xml', 'tomato003S(20).xml', 'tomato003S(5).xml', 'tomato003S(12).xml']
# tomato003 ['tomato003T(5).xml', 'tomato003T(28).xml', 'tomato003T(29).xml', 'tomato003T(24).xml', 'tomato003T(13).xml', 'tomato003T(11).xml', 'tomato003T(16).xml', 'tomato003T(6).xml', 'tomato003T(25).xml', 'tomato003T(14).xml', 'tomato003T(27).xml', 'tomato003T(22).xml', 'tomato003T(3).xml', 'tomato003T(31).xml', 'tomato003T(1).xml', 'tomato003T(4).xml', 'tomato003T(18).xml', 'tomato003T(2).xml', 'tomato003T(33).xml', 'tomato003T(30).xml', 'tomato003T(23).xml', 'tomato003T(10).xml', 'tomato003T(17).xml', 'tomato003T(9).xml', 'tomato003T(19).xml', 'tomato003T(12).xml', 'tomato003T(26).xml', 'tomato003T(7).xml', 'tomato003T(21).xml', 'tomato003T(20).xml', 'tomato003T(8).xml', 'tomato003T(32).xml', 'tomato003T(34).xml', 'tomato003T(15).xml']
#
# 27 25 SIDE>>>>>>>> tomato004
# 27 25 TOP>>>>>>>> tomato004
# tomato004 ['tomato004S(24).xml', 'tomato004S(8).xml', 'tomato004S(25).xml', 'tomato004S(2).xml', 'tomato004S(20).xml', 'tomato004S(1).xml', 'tomato004S(27).xml', 'tomato004S(9).xml', 'tomato004S(18).xml', 'tomato004S(6).xml', 'tomato004S(15).xml', 'tomato004S(16).xml', 'tomato004S(7).xml', 'tomato004S(10).xml', 'tomato004S(11).xml', 'tomato004S(12).xml', 'tomato004S(26).xml', 'tomato004S(13).xml', 'tomato004S(21).xml', 'tomato004S(22).xml', 'tomato004S(23).xml', 'tomato004S(5).xml', 'tomato004S(19).xml', 'tomato004S(14).xml', 'tomato004S(17).xml', 'tomato004S(3).xml', 'tomato004S(4).xml']
# tomato004 ['tomato004T(25).xml', 'tomato004T(9).xml', 'tomato004T(4).xml', 'tomato004T(23).xml', 'tomato004T(24).xml', 'tomato004T(21).xml', 'tomato004T(15).xml', 'tomato004T(22).xml', 'tomato004T(7).xml', 'tomato004T(27).xml', 'tomato004T(3).xml', 'tomato004T(11).xml', 'tomato004T(1).xml', 'tomato004T(17).xml', 'tomato004T(8).xml', 'tomato004T(6).xml', 'tomato004T(12).xml', 'tomato004T(2).xml', 'tomato004T(5).xml', 'tomato004T(20).xml', 'tomato004T(19).xml', 'tomato004T(18).xml', 'tomato004T(14).xml', 'tomato004T(16).xml', 'tomato004T(26).xml', 'tomato004T(13).xml', 'tomato004T(10).xml']
#
# 15 14 SIDE>>>>>>>> tomato002
# 15 14 TOP>>>>>>>> tomato002
# tomato002 ['tomato002S(12).xml', 'tomato002S(8).xml', 'tomato002S(1).xml', 'tomato002S(4).xml', 'tomato002S(2).xml', 'tomato002S(11).xml', 'tomato002S(5).xml', 'tomato002S(3).xml', 'tomato002S(14).xml', 'tomato002S(7).xml', 'tomato002S(13).xml', 'tomato002S(15).xml', 'tomato002S(9).xml', 'tomato002S(6).xml', 'tomato002S(10).xml']
# tomato002 ['tomato002T(13).xml', 'tomato002T(9).xml', 'tomato002T(12).xml', 'tomato002T(5).xml', 'tomato002T(8).xml', 'tomato002T(4).xml', 'tomato002T(6).xml', 'tomato002T(10).xml', 'tomato002T(7).xml', 'tomato002T(11).xml', 'tomato002T(1).xml', 'tomato002T(2).xml', 'tomato002T(14).xml', 'tomato002T(15).xml', 'tomato002T(3).xml']
#
# 53 10000000050 SIDE>>>>>>>>
# 55 46 TOP>>>>>>>>
# dict_keys(['mix004', 'mix012', 'mix002', 'mix006', 'mix010', 'mix014', 'mix007', 'mix013', 'mix009', 'mix001', 'mix008', 'mix003', 'mix005', 'mix011'])
# 4 3 SIDE>>>>>>>> mix004
# 4 3 TOP>>>>>>>> mix004
# mix004 ['mix004S(3).xml', 'mix004S(4).xml', 'mix004S(1).xml', 'mix004S(2).xml']
# mix004 ['mix004T(1).xml', 'mix004T(2).xml', 'mix004T(4).xml', 'mix004T(3).xml']
#
# 4 3 SIDE>>>>>>>> mix012
# 4 3 TOP>>>>>>>> mix012
# mix012 ['mix012S(4).xml', 'mix012S(2).xml', 'mix012S(3).xml', 'mix012S(1).xml']
# mix012 ['mix012T(4).xml', 'mix012T(2).xml', 'mix012T(1).xml', 'mix012T(3).xml']
#
# 4 3 SIDE>>>>>>>> mix002
# 4 3 TOP>>>>>>>> mix002
# mix002 ['mix002S(4).xml', 'mix002S(3).xml', 'mix002S(2).xml', 'mix002S(1).xml']
# mix002 ['mix002T(4).xml', 'mix002T(3).xml', 'mix002T(2).xml', 'mix002T(1).xml']
#
# 4 3 SIDE>>>>>>>> mix006
# 4 3 TOP>>>>>>>> mix006
# mix006 ['mix006S(3).xml', 'mix006S(1).xml', 'mix006S(4).xml', 'mix006S(2).xml']
# mix006 ['mix006T(3).xml', 'mix006T(2).xml', 'mix006T(1).xml', 'mix006T(4).xml']
#
# 6 5 SIDE>>>>>>>> mix010
# 7 6 TOP>>>>>>>> mix010
# mix010 ['mix010S(3).xml', 'mix010S(1).xml', 'mix010S(6).xml', 'mix010S(5).xml', 'mix010S(2).xml', 'mix010S(4).xml']
# mix010 ['mix010T(2).xml', 'mix010T(4).xml', 'mix010T(7).xml', 'mix010T(3).xml', 'mix010T(5).xml', 'mix010T(1).xml', 'mix010T(6).xml']
#
# 4 3 SIDE>>>>>>>> mix014
# 4 3 TOP>>>>>>>> mix014
# mix014 ['mix014S(3).xml', 'mix014S(4).xml', 'mix014S(2).xml', 'mix014S(1).xml']
# mix014 ['mix014T(1).xml', 'mix014T(4).xml', 'mix014T(3).xml', 'mix014T(2).xml']
#
# 5 4 SIDE>>>>>>>> mix007
# 5 4 TOP>>>>>>>> mix007
# mix007 ['mix007S(1).xml', 'mix007S(2).xml', 'mix007S(5).xml', 'mix007S(4).xml', 'mix007S(3).xml']
# mix007 ['mix007T(2).xml', 'mix007T(4).xml', 'mix007T(1).xml', 'mix007T(3).xml', 'mix007T(5).xml']
#
# 4 3 SIDE>>>>>>>> mix013
# 4 3 TOP>>>>>>>> mix013
# mix013 ['mix013S(3).xml', 'mix013S(2).xml', 'mix013S(1).xml', 'mix013S(4).xml']
# mix013 ['mix013T(1).xml', 'mix013T(3).xml', 'mix013T(2).xml', 'mix013T(4).xml']
#
# 4 3 SIDE>>>>>>>> mix009
# 4 3 TOP>>>>>>>> mix009
# mix009 ['mix009S(4).xml', 'mix009S(2).xml', 'mix009S(3).xml', 'mix009S(1).xml']
# mix009 ['mix009T(2).xml', 'mix009T(1).xml', 'mix009T(3).xml', 'mix009T(4).xml']
#
# 2 1 SIDE>>>>>>>> mix001
# 2 1 TOP>>>>>>>> mix001
# mix001 ['mix001S(2).xml', 'mix001S(1).xml']
# mix001 ['mix001T(1).xml', 'mix001T(2).xml']
#
# 4 3 SIDE>>>>>>>> mix008
# 4 3 TOP>>>>>>>> mix008
# mix008 ['mix008S(2).xml', 'mix008S(3).xml', 'mix008S(4).xml', 'mix008S(1).xml']
# mix008 ['mix008T(3).xml', 'mix008T(2).xml', 'mix008T(1).xml', 'mix008T(4).xml']
#
# 3 2 SIDE>>>>>>>> mix003
# 3 2 TOP>>>>>>>> mix003
# mix003 ['mix003S(3).xml', 'mix003S(1).xml', 'mix003S(2).xml']
# mix003 ['mix003T(1).xml', 'mix003T(2).xml', 'mix003T(3).xml']
#
# 1 0 SIDE>>>>>>>> mix005
# 2 1 TOP>>>>>>>> mix005
# mix005 ['mix005S(4).xml']
# mix005 ['mix005T(4).xml', 'mix005T(6).xml']
#
# 4 3 SIDE>>>>>>>> mix011
# 4 3 TOP>>>>>>>> mix011
# mix011 ['mix011S(3).xml', 'mix011S(2).xml', 'mix011S(4).xml', 'mix011S(1).xml']
# mix011 ['mix011T(3).xml', 'mix011T(1).xml', 'mix011T(2).xml', 'mix011T(4).xml']

# %% [markdown]
# **Function to Split the ECUSTFD into Train and Test Sets**

# %%
from math import ceil,floor

# Create the Train and Test Folder in the JPEGImages Directory:
os.mkdir('/content/ECUSTFD-resized-/JPEGImages/train')
os.mkdir('/content/ECUSTFD-resized-/JPEGImages/test')

dic = { 'apple':[], 'banana':[], 'bread':[], 'bun':[],
        'doughnut':[], 'egg':[], 'fired':[],
        'grape':[], 'lemon':[], 'litchi':[], 'mango':[],
        'mooncake':[], 'orange':[], 'peach':[], 'pear':[],
        'plum':[], 'qiwi':[], 'sachima':[], 'tomato':[],'mix':[] }

for file in os.listdir('/content/ECUSTFD-resized-/Annotations/test'):
    te = file.split('.')[0]+'.JPG'
    shutil.move("/content/ECUSTFD-resized-/JPEGImages/"+te,"/content/ECUSTFD-resized-/JPEGImages/test/"+te)

for file in os.listdir('/content/ECUSTFD-resized-/Annotations/train'):
    te = file.split('.')[0]+'.JPG'
    shutil.move("/content/ECUSTFD-resized-/JPEGImages/"+te,"/content/ECUSTFD-resized-/JPEGImages/train/"+te)

# %% [markdown]
# **Function to Plot the Dataset**

# %%
dicTrain = { 'apple':[], 'banana':[], 'bread':[], 'bun':[],
        'doughnut':[], 'egg':[], 'fired_dough_twist':[],
        'grape':[], 'lemon':[], 'litchi':[], 'mango':[],
        'mooncake':[], 'orange':[], 'peach':[], 'pear':[],
        'plum':[], 'qiwi':[], 'sachima':[], 'tomato':[] }
dicTest = { 'apple':[], 'banana':[], 'bread':[], 'bun':[],
        'doughnut':[], 'egg':[], 'fired_dough_twist':[],
        'grape':[], 'lemon':[], 'litchi':[], 'mango':[],
        'mooncake':[], 'orange':[], 'peach':[], 'pear':[],
        'plum':[], 'qiwi':[], 'sachima':[], 'tomato':[] }

foods = ['apple','egg','lemon','orange','peach','plum','qiwi','tomato','mix',
         ' bread','grape','mooncake','sachima','banana','bun','doughnut',
          'fired_dough_twist','litchi','mango','pear']

mixTest, mixTrain =0, 0
for elem in os.listdir("/content/ECUSTFD-resized-/JPEGImages/test"):
    if 'mix' in elem:
        mixTest+=1
        continue
    for keys in dicTest.keys():
        if keys in elem:
            dicTest[keys].append(elem)
            break

for elem in os.listdir("/content/ECUSTFD-resized-/JPEGImages/train"):
    if 'mix' in elem:
        mixTrain+=1
        continue
    for keys in dicTest.keys():
        if keys in elem:
            dicTrain[keys].append(elem)
            break

print(mixTest, mixTrain)

names=dicTest.keys()

groupCount=len(names)
fig,ax=plt.subplots()
index=np.arange(groupCount)
bar_width = 0.35
opacity = 0.8

countTest=[]
countTrain=[]
for elem in names:
    countTest.append(len(dicTest[elem]))
    countTrain.append(len(dicTrain[elem]))

rects1 = plt.barh(index, countTest, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Test')

rects2 = plt.barh(index + bar_width, countTrain, bar_width,
                 alpha=opacity,
                 color='r',
                 label='Train')

ax.set_yticks(index)
ax.set_yticklabels(names)
ax.invert_yaxis()
ax.set_xlabel('Counts')
ax.set_title("Counts of Used Food")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 28 80

# %% [markdown]
# ##**Perform Object Detection**

# %% [markdown]
# **Install and Upload the Required Dependencies for Object Detection**

# %%
# !pip install -U --pre tensorflow=="2.*"
# !pip install tf_slim
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow==2.* in /usr/local/lib/python3.10/dist-packages (2.12.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.*) (0.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.*) (1.16.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.*) (3.8.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.*) (1.14.1)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.*) (2.12.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.*) (1.54.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.*) (0.4.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.*) (67.7.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.*) (3.20.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.*) (0.4.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.*) (1.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.*) (23.1)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.*) (2.12.2)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.*) (2.12.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.*) (1.6.3)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.*) (16.0.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.*) (2.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.*) (23.3.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.*) (0.32.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.*) (1.22.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.*) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.*) (4.5.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.*) (0.40.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow==2.*) (1.10.1)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow==2.*) (0.1.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.*) (2.17.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.*) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.*) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.*) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.*) (3.4.3)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.*) (2.3.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.*) (2.27.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.*) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.*) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.*) (0.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.*) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.*) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.*) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.*) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.*) (1.26.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow==2.*) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.*) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.*) (3.2.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tf_slim in /usr/local/lib/python3.10/dist-packages (1.1.0)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from tf_slim) (1.4.0)

# %%
# !pip install pycocotools
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (2.0.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pycocotools) (1.22.4)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools) (3.7.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (4.39.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (0.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)

# %%
os.getcwd()
# Out:
# '/content/ECUSTFD-resized-'

# %%
# %cd /content
# Out:
# /content

# %% [markdown]
# **Get tensorflow/models or cd to parent directory of the repository.**

# %%
import pathlib

if "models" in pathlib.Path.cwd().parts:
  while "models" in pathlib.Path.cwd().parts:
    os.chdir('..')
elif not pathlib.Path('models').exists():
  # !git clone --depth 1 https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 3825, done.
# remote: Counting objects: 100% (3825/3825), done.
# remote: Compressing objects: 100% (2924/2924), done.
# remote: Total 3825 (delta 1111), reused 1947 (delta 851), pack-reused 0
# Receiving objects: 100% (3825/3825), 49.55 MiB | 18.95 MiB/s, done.
# Resolving deltas: 100% (1111/1111), done.

# %% [markdown]
# **Compile protobufs and install the object_detection package**

# %%
# %cd models/research/
# !protoc object_detection/protos/*.proto --python_out=.

# Install TensorFlow Object Detection API.
# !cp object_detection/packages/tf2/setup.py .
# !python -m pip install --use-feature=2020-resolver .
# Out:
# /content/models/research
#
# Usage:
#   /usr/bin/python3 -m pip install [options] <requirement specifier> [package-index-options] ...
#   /usr/bin/python3 -m pip install [options] -r <requirements file> [package-index-options] ...
#   /usr/bin/python3 -m pip install [options] [-e] <vcs project url> ...
#   /usr/bin/python3 -m pip install [options] [-e] <local project path> ...
#   /usr/bin/python3 -m pip install [options] <archive url/path> ...
#
# option --use-feature: invalid choice: '2020-resolver' (choose from 'fast-deps', 'truststore', 'no-binary-enable-wheel-cache')

# %%
os.getcwd()
# %cd /content/models/research/
# Out:
# /content/models/research

# %%
# !pip install cython
# !pip install git+https://github.com/philferriere/cocoapi.git#subdirectory=PythonAPI
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (0.29.34)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/philferriere/cocoapi.git#subdirectory=PythonAPI
#   Cloning https://github.com/philferriere/cocoapi.git to /tmp/pip-req-build-3l6u7fe1
#   Running command git clone --filter=blob:none --quiet https://github.com/philferriere/cocoapi.git /tmp/pip-req-build-3l6u7fe1
#   Resolved https://github.com/philferriere/cocoapi.git to commit 2929bd2ef6b451054755dfd7ceb09278f935f7ad
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (setup.py) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp310-cp310-linux_x86_64.whl size=386191 sha256=46e8640f81ae6f29084f948bf2293593e11a59d09572bc9e8ea5d3a6b9db3732
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w7g8yc_o/wheels/8e/1a/5f/0c984ae3d65a4d7da4ba3407d2a8d8c8e85dd55f84d4936f04
# Successfully built pycocotools
# Installing collected packages: pycocotools
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0.6
#     Uninstalling pycocotools-2.0.6:
#       Successfully uninstalled pycocotools-2.0.6
# Successfully installed pycocotools-2.0

# %%
# %cd /content/models/research/object_detection/packages/tf2
# !pip install .
# Out:
# /content/models/research/object_detection/packages/tf2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/models/research/object_detection/packages/tf2
#   Preparing metadata (setup.py) ... done
# Collecting avro-python3
#   Downloading avro-python3-1.10.2.tar.gz (38 kB)
#   Preparing metadata (setup.py) ... done
# Collecting apache-beam
#   Downloading apache_beam-2.46.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.2/14.2 MB 22.6 MB/s eta 0:00:00
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (8.4.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (4.9.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (3.7.1)
# Requirement already satisfied: Cython in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (0.29.34)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (0.6.0.post1)
# Requirement already satisfied: tf-slim in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (1.16.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (2.0)
# Collecting lvis
#   Downloading lvis-0.5.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (1.10.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (1.5.3)
# Collecting tf-models-official>=2.5.1
#   Downloading tf_models_official-2.12.0-py2.py3-none-any.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 33.0 MB/s eta 0:00:00
# Collecting tensorflow_io
#   Downloading tensorflow_io-0.32.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (28.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.0/28.0 MB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (2.12.0)
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 6.7 MB/s eta 0:00:00
# Collecting sacrebleu<=2.2.0
#   Downloading sacrebleu-2.2.0-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.6/116.6 kB 11.6 MB/s eta 0:00:00
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2022.10.31)
# Collecting portalocker
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (1.22.4)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.8.10)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (591 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.0/591.0 kB 25.1 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow~=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.12.0)
# Collecting tensorflow-text~=2.12.0
#   Downloading tensorflow_text-2.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 30.5 MB/s eta 0:00:00
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (9.0.0)
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.5.13)
# Collecting tensorflow-model-optimization>=0.4.1
#   Downloading tensorflow_model_optimization-0.7.4-py2.py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.6/240.6 kB 22.5 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.13.0)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.7.0.72)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.9.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 45.5 MB/s eta 0:00:00
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.8.3)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.84.0)
# Collecting immutabledict
#   Downloading immutabledict-2.2.4-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Collecting pyyaml<6.0,>=5.1
#   Downloading PyYAML-5.4.1.tar.gz (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.1/175.1 kB 16.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->object-detection==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->object-detection==0.1) (2022.7.1)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from tf-slim->object-detection==0.1) (1.4.0)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (1.4.2)
# Collecting fastavro<2,>=0.23.6
#   Downloading fastavro-1.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 27.5 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<4,>3.12.2 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (3.20.3)
# Collecting dill<0.3.2,>=0.3.1.1
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.0/152.0 kB 13.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting zstandard<1,>=0.18.0
#   Downloading zstandard-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 28.5 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (2.27.1)
# Collecting hdfs<3.0.0,>=2.1.0
#   Downloading hdfs-2.7.0-py3-none-any.whl (34 kB)
# Collecting objsize<0.7.0,>=0.6.1
#   Downloading objsize-0.6.1-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (4.5.0)
# Collecting crcmod<2.0,>=1.7
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 10.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (1.54.0)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (1.22.2)
# Collecting pymongo<4.0.0,>=3.8.0
#   Downloading pymongo-3.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (516 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.2/516.2 kB 22.6 MB/s eta 0:00:00
# Collecting fasteners<1.0,>=0.3
#   Downloading fasteners-0.18-py3-none-any.whl (18 kB)
# Requirement already satisfied: cloudpickle~=2.2.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (2.2.1)
# Collecting orjson<4.0
#   Downloading orjson-3.8.11-cp310-cp310-manylinux_2_28_x86_64.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: httplib2<0.22.0,>=0.8 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (0.21.0)
# Requirement already satisfied: pyarrow<10.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (9.0.0)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.10/dist-packages (from lvis->object-detection==0.1) (4.7.0.72)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from lvis->object-detection==0.1) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from lvis->object-detection==0.1) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->object-detection==0.1) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->object-detection==0.1) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->object-detection==0.1) (4.39.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.32.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_io->object-detection==0.1) (0.32.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.1.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.1.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.17.3)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.11.0)
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.26.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.65.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (8.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.4)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.8)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.14.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (23.3.3)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.12.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (67.7.2)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (3.8.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.8)
# Collecting numpy>=1.17
#   Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 65.7 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.3.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (4.9)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.2.2)
# Collecting typeguard<3.0.0,>=2.7
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: etils[enp,epath]>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.2.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.10.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (8.1.3)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.13.1)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.40.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (3.15.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (5.12.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.59.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (5.3.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.2.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.3.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.0.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.1.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (3.2.2)
# Building wheels for collected packages: object-detection, avro-python3, crcmod, dill, pyyaml, seqeval, docopt
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1226 sha256=a270cb79b093ebdba69526ba7272089e49133f148424b75842159f3e84d9548c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-juhbbe4p/wheels/a8/09/fe/91272187882c329f13b8a45767fac8d969e712c231f57d7d8c
#   Building wheel for avro-python3 (setup.py) ... done
#   Created wheel for avro-python3: filename=avro_python3-1.10.2-py3-none-any.whl size=44008 sha256=7ea3d0326d2cfbaa476b2db9982cb644e9af01e4b6933edca3283b5105c3f706
#   Stored in directory: /root/.cache/pip/wheels/bc/85/62/6cdd81c56f923946b401cecff38055b94c9b766927f7d8ca82
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp310-cp310-linux_x86_64.whl size=37114 sha256=3551b7470b33b5bd237f8cf6993a4a87961cc0b860bbb7f34cdb5c2fa533c01d
#   Stored in directory: /root/.cache/pip/wheels/85/4c/07/72215c529bd59d67e3dac29711d7aba1b692f543c808ba9e86
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78545 sha256=596ad929723b83df0ecb3c20dd09a77f2c1d45f69275b3db458bc7861b9b20db
#   Stored in directory: /root/.cache/pip/wheels/ea/e2/86/64980d90e297e7bf2ce588c2b96e818f5399c515c4bb8a7e4f
#   Building wheel for pyyaml (pyproject.toml) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.4.1-cp310-cp310-linux_x86_64.whl size=45658 sha256=d43c332b26de5a57656f6d8bb88d2d3dad7f4dcdfb6a8c43dda5de15ddc2df27
#   Stored in directory: /root/.cache/pip/wheels/c7/0d/22/696ee92245ad710f506eee79bb05c740d8abccd3ecdb778683
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=160af3f86d8c081c57301e556cdb3da9c46b80c87c249d3e00b4e1dd99cec935
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13721 sha256=663c5b91860574ea171180d5de3930545a95d54e2aeae836083a01ff092ea85a
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built object-detection avro-python3 crcmod dill pyyaml seqeval docopt
# Installing collected packages: sentencepiece, docopt, crcmod, zstandard, typeguard, tensorflow_io, pyyaml, pyparsing, pymongo, portalocker, orjson, objsize, numpy, immutabledict, fasteners, fastavro, dill, colorama, avro-python3, tensorflow-model-optimization, tensorflow-addons, sacrebleu, hdfs, apache-beam, seqeval, lvis, tensorflow-text, tf-models-official, object-detection
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
# Successfully installed apache-beam-2.46.0 avro-python3-1.10.2 colorama-0.4.6 crcmod-1.7 dill-0.3.1.1 docopt-0.6.2 fastavro-1.7.3 fasteners-0.18 hdfs-2.7.0 immutabledict-2.2.4 lvis-0.5.3 numpy-1.23.5 object-detection-0.1 objsize-0.6.1 orjson-3.8.11 portalocker-2.7.0 pymongo-3.13.0 pyparsing-2.4.7 pyyaml-5.4.1 sacrebleu-2.2.0 sentencepiece-0.1.99 seqeval-1.2.2 tensorflow-addons-0.20.0 tensorflow-model-optimization-0.7.4 tensorflow-text-2.12.1 tensorflow_io-0.32.0 tf-models-official-2.12.0 typeguard-2.13.3 zstandard-0.21.0

# %%
# !pip install tensorflow-object-detection-api
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-object-detection-api
#   Downloading tensorflow_object_detection_api-0.1.1.tar.gz (577 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 577.4/577.4 kB 13.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-object-detection-api) (8.4.0)
# Requirement already satisfied: Matplotlib>=2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-object-detection-api) (3.7.1)
# Requirement already satisfied: Cython>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-object-detection-api) (0.29.34)
# Requirement already satisfied: Protobuf in /usr/local/lib/python3.10/dist-packages (from tensorflow-object-detection-api) (3.20.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from tensorflow-object-detection-api) (4.9.2)
# Collecting jupyter
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from tensorflow-object-detection-api) (2.12.0)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.10/dist-packages (from tensorflow-object-detection-api) (0.6.0.post1)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from tensorflow-object-detection-api) (0.40.0)
# Collecting twine
#   Downloading twine-4.0.2-py3-none-any.whl (36 kB)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (2.8.2)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (1.23.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (23.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (4.39.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (0.11.0)
# Collecting qtconsole
#   Downloading qtconsole-5.4.2-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.2/121.2 kB 13.7 MB/s eta 0:00:00
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from jupyter->tensorflow-object-detection-api) (5.5.6)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from jupyter->tensorflow-object-detection-api) (6.5.4)
# Requirement already satisfied: notebook in /usr/local/lib/python3.10/dist-packages (from jupyter->tensorflow-object-detection-api) (6.4.8)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.10/dist-packages (from jupyter->tensorflow-object-detection-api) (6.1.0)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from jupyter->tensorflow-object-detection-api) (7.7.1)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->tensorflow-object-detection-api) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->tensorflow-object-detection-api) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->tensorflow-object-detection-api) (3.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->tensorflow-object-detection-api) (1.6.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->tensorflow-object-detection-api) (0.4.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->tensorflow-object-detection-api) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow->tensorflow-object-detection-api) (4.5.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->tensorflow-object-detection-api) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->tensorflow-object-detection-api) (0.32.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->tensorflow-object-detection-api) (0.2.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->tensorflow-object-detection-api) (1.14.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow->tensorflow-object-detection-api) (67.7.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->tensorflow-object-detection-api) (2.3.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow->tensorflow-object-detection-api) (2.12.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->tensorflow-object-detection-api) (1.54.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow->tensorflow-object-detection-api) (0.4.8)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->tensorflow-object-detection-api) (23.3.3)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->tensorflow-object-detection-api) (1.4.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->tensorflow-object-detection-api) (2.12.0)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from twine->tensorflow-object-detection-api) (2.27.1)
# Collecting requests-toolbelt!=0.9.0,>=0.8.0
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.3 MB/s eta 0:00:00
# Collecting readme-renderer>=35.0
#   Downloading readme_renderer-37.3-py3-none-any.whl (14 kB)
# Collecting pkginfo>=1.8.1
#   Downloading pkginfo-1.9.6-py3-none-any.whl (30 kB)
# Collecting rfc3986>=1.4.0
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from twine->tensorflow-object-detection-api) (13.3.4)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from twine->tensorflow-object-detection-api) (1.26.15)
# Collecting keyring>=15.1
#   Downloading keyring-23.13.1-py3-none-any.whl (37 kB)
# Collecting importlib-metadata>=3.6
#   Downloading importlib_metadata-6.6.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=3.6->twine->tensorflow-object-detection-api) (3.15.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow->tensorflow-object-detection-api) (0.1.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow->tensorflow-object-detection-api) (1.10.1)
# Collecting SecretStorage>=3.2
#   Downloading SecretStorage-3.3.3-py3-none-any.whl (15 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.8.0-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 6.5 MB/s eta 0:00:00
# Collecting jaraco.classes
#   Downloading jaraco.classes-3.2.3-py3-none-any.whl (6.0 kB)
# Requirement already satisfied: bleach>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from readme-renderer>=35.0->twine->tensorflow-object-detection-api) (6.0.0)
# Requirement already satisfied: Pygments>=2.5.1 in /usr/local/lib/python3.10/dist-packages (from readme-renderer>=35.0->twine->tensorflow-object-detection-api) (2.14.0)
# Requirement already satisfied: docutils>=0.13.1 in /usr/local/lib/python3.10/dist-packages (from readme-renderer>=35.0->twine->tensorflow-object-detection-api) (0.16)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->twine->tensorflow-object-detection-api) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->twine->tensorflow-object-detection-api) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->twine->tensorflow-object-detection-api) (2022.12.7)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.0.0->twine->tensorflow-object-detection-api) (2.2.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->tensorflow-object-detection-api) (2.17.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->tensorflow-object-detection-api) (3.4.3)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->tensorflow-object-detection-api) (2.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->tensorflow-object-detection-api) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->tensorflow-object-detection-api) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->tensorflow-object-detection-api) (1.0.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (0.2.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (6.1.12)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (5.7.1)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (6.2)
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->jupyter->tensorflow-object-detection-api) (3.0.7)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->jupyter->tensorflow-object-detection-api) (3.6.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-console->jupyter->tensorflow-object-detection-api) (3.0.38)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (1.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (2.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (0.7.4)
# Requirement already satisfied: jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (3.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (4.11.2)
# Requirement already satisfied: nbformat>=5.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (5.8.0)
# Requirement already satisfied: jupyter-core>=4.7 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (5.3.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (0.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (0.2.2)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->tensorflow-object-detection-api) (1.5.6)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->tensorflow-object-detection-api) (0.17.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->tensorflow-object-detection-api) (21.3.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->tensorflow-object-detection-api) (0.16.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->tensorflow-object-detection-api) (23.2.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->tensorflow-object-detection-api) (1.8.0)
# Collecting qtpy>=2.0.1
#   Downloading QtPy-2.3.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach>=2.1.0->readme-renderer>=35.0->twine->tensorflow-object-detection-api) (0.5.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->tensorflow-object-detection-api) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->tensorflow-object-detection-api) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->tensorflow-object-detection-api) (0.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->tensorflow-object-detection-api) (1.3.1)
# Collecting jedi>=0.16
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 47.9 MB/s eta 0:00:00
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter->tensorflow-object-detection-api) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter->tensorflow-object-detection-api) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter->tensorflow-object-detection-api) (4.8.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter->tensorflow-object-detection-api) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter->tensorflow-object-detection-api) (4.4.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.7->nbconvert->jupyter->tensorflow-object-detection-api) (3.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=12.0.0->twine->tensorflow-object-detection-api) (0.1.2)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.1->nbconvert->jupyter->tensorflow-object-detection-api) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.1->nbconvert->jupyter->tensorflow-object-detection-api) (4.3.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->tensorflow-object-detection-api) (0.2.6)
# Requirement already satisfied: cryptography>=2.0 in /usr/local/lib/python3.10/dist-packages (from SecretStorage>=3.2->keyring>=15.1->twine->tensorflow-object-detection-api) (40.0.2)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.10/dist-packages (from terminado>=0.8.3->notebook->jupyter->tensorflow-object-detection-api) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook->jupyter->tensorflow-object-detection-api) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->jupyter->tensorflow-object-detection-api) (2.4.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from jaraco.classes->keyring>=15.1->twine->tensorflow-object-detection-api) (9.1.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring>=15.1->twine->tensorflow-object-detection-api) (1.15.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->jupyter->tensorflow-object-detection-api) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->tensorflow-object-detection-api) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->tensorflow-object-detection-api) (0.19.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->tensorflow-object-detection-api) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->tensorflow-object-detection-api) (3.2.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring>=15.1->twine->tensorflow-object-detection-api) (2.21)
# Building wheels for collected packages: tensorflow-object-detection-api
#   Building wheel for tensorflow-object-detection-api (setup.py) ... done
#   Created wheel for tensorflow-object-detection-api: filename=tensorflow_object_detection_api-0.1.1-py3-none-any.whl size=844510 sha256=4dc5e82700a77d2fae825a69ccd0df66a0166ac85efa49f2ac31437140e926e4
#   Stored in directory: /root/.cache/pip/wheels/8a/55/68/c084bc2cd93c41fd8f7e2ef9e6bbcb2c35a3e4b49e42044d02
# Successfully built tensorflow-object-detection-api
# Installing collected packages: rfc3986, qtpy, pkginfo, jeepney, jedi, jaraco.classes, importlib-metadata, requests-toolbelt, readme-renderer, SecretStorage, qtconsole, keyring, twine, jupyter, tensorflow-object-detection-api
# Successfully installed SecretStorage-3.3.3 importlib-metadata-6.6.0 jaraco.classes-3.2.3 jedi-0.18.2 jeepney-0.8.0 jupyter-1.0.0 keyring-23.13.1 pkginfo-1.9.6 qtconsole-5.4.2 qtpy-2.3.1 readme-renderer-37.3 requests-toolbelt-1.0.0 rfc3986-2.0.0 tensorflow-object-detection-api-0.1.1 twine-4.0.2

# %%
# From within TensorFlow/models/research/
os.getcwd()
# %cd /content/models/research
# !python object_detection/builders/model_builder_tf2_test.py
# Out:
# /content/models/research
# 2023-05-04 05:43:02.746218: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Traceback (most recent call last):
#   File "/content/models/research/object_detection/builders/model_builder_tf2_test.py", line 24, in <module>
#     from object_detection.builders import model_builder
#   File "/usr/local/lib/python3.10/dist-packages/object_detection/builders/model_builder.py", line 22, in <module>
#     from object_detection.builders import box_predictor_builder
#   File "/usr/local/lib/python3.10/dist-packages/object_detection/builders/box_predictor_builder.py", line 20, in <module>
#     from object_detection.predictors import convolutional_box_predictor
#   File "/usr/local/lib/python3.10/dist-packages/object_detection/predictors/convolutional_box_predictor.py", line 22, in <module>
#     slim = tf.contrib.slim
# AttributeError: module 'tensorflow' has no attribute 'contrib'

# %% [markdown]
# **Import the object detection module**

# %%
# %cd /content
os.getcwd()
# Out:
# /content
# '/content'

# %%
sys.path.append("/content/models/research/object_detection/utils/")

from object_detection.utils import ops as utils_ops
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as vis_util

# %%
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# **Load Model Function**

# %%
def load_model(model_name):
  base_url = 'http://download.tensorflow.org/models/object_detection/'
  model_file = model_name + '.tar.gz'
  model_dir = tf.keras.utils.get_file(
    fname=model_name,
    origin=base_url + model_file,
    untar=True)

  model_dir = pathlib.Path(model_dir)/"saved_model"

  model = tf.saved_model.load(str(model_dir))

  return model

# %% [markdown]
# **Load the Model and label map**

# %%
sys.path.append("/content/SeeFood/code/prepareData/")

import visualization_utils as vis_util

# patch tf1 into `utils.ops`
utils_ops.tf = tf.compat.v1

# Patch the location of gfile
tf.gfile = tf.io.gfile

# What model to download.
MODEL_NAME = '/content/ECUSTFD-resized-/SeeFood/model/frcnn_inception'

# Path to frozen detection graph. This is the actual model that is used for the object detection.
PATH_TO_FROZEN_GRAPH = MODEL_NAME + '/frozen_inference_graph.pb'

# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = os.path.join('/content/ECUSTFD-resized-/SeeFood/model/frcnn_inception/frcnn.pbtxt')
# List of the strings that is used to add correct label for each box.
#PATH_TO_LABELS = os.path.join('legacy/data', 'object-detection.pbtxt')

detection_graph = tf.Graph()
with detection_graph.as_default():
  od_graph_def = tf.compat.v1.GraphDef()
  with tf.io.gfile.GFile(PATH_TO_FROZEN_GRAPH, 'rb') as fid:
    serialized_graph = fid.read()
    od_graph_def.ParseFromString(serialized_graph)
    tf.import_graph_def(od_graph_def, name='')

category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS, use_display_name=True)

# %% [markdown]
# **Add path to the images to the TEST_IMAGE_PATHS**

# %%
def load_image_into_numpy_array(image):
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape(
      (im_height, im_width, 3)).astype(np.uint8)

dicSd = {}
dicTp = {}

PATH_TO_TEST_IMAGES_DIR = '/content/ECUSTFD-resized-/JPEGImages/test'
TEST_IMAGE_PATHS = [ os.path.join(PATH_TO_TEST_IMAGES_DIR, file) for file in os.listdir(PATH_TO_TEST_IMAGES_DIR) if 'JPG' in file]
#TEST_IMAGE_PATHS=[os.path.join(PATH_TO_TEST_IMAGES_DIR,"fired_dough_twist001T(7).JPG")]
# Size, in inches, of the output images.
IMAGE_SIZE = (12, 8)

for file in os.listdir(PATH_TO_TEST_IMAGES_DIR):
    if 'JPG' in file:
        sito = file.split('(')[0][-1]
        cate = file.split('0')[0]
        speci = file.split('(')[0][:-1]
        if cate not in dicSd.keys():
            dicSd[cate]=defaultdict(list)
            dicTp[cate]=defaultdict(list)
print(dicSd)
# Out:
# {'doughnut': defaultdict(<class 'list'>, {}), 'mix': defaultdict(<class 'list'>, {}), 'apple': defaultdict(<class 'list'>, {}), 'plum': defaultdict(<class 'list'>, {}), 'pear': defaultdict(<class 'list'>, {}), 'bread': defaultdict(<class 'list'>, {}), 'orange': defaultdict(<class 'list'>, {}), 'lemon': defaultdict(<class 'list'>, {}), 'fired_dough_twist': defaultdict(<class 'list'>, {}), 'mango': defaultdict(<class 'list'>, {}), 'banana': defaultdict(<class 'list'>, {}), 'peach': defaultdict(<class 'list'>, {}), 'sachima': defaultdict(<class 'list'>, {}), 'qiwi': defaultdict(<class 'list'>, {}), 'egg': defaultdict(<class 'list'>, {}), 'bun': defaultdict(<class 'list'>, {}), 'litchi': defaultdict(<class 'list'>, {}), 'grape': defaultdict(<class 'list'>, {}), 'mooncake': defaultdict(<class 'list'>, {}), 'tomato': defaultdict(<class 'list'>, {})}

# %% [markdown]
# **Add a wrapper function to call the model, and cleanup the outputs**

# %%
def run_inference_for_single_image(image, graph):
  with graph.as_default():
    with tf.compat.v1.Session() as sess:
      # Get handles to input and output tensors
      ops = tf.compat.v1.get_default_graph().get_operations()
      all_tensor_names = {output.name for op in ops for output in op.outputs}
      tensor_dict = {}
      for key in [
          'num_detections', 'detection_boxes', 'detection_scores',
          'detection_classes', 'detection_masks'
      ]:
        tensor_name = key + ':0'
        if tensor_name in all_tensor_names:
          tensor_dict[key] = tf.compat.v1.get_default_graph().get_tensor_by_name(
              tensor_name)
      if 'detection_masks' in tensor_dict:
        # The following processing is only for single image
        detection_boxes = tf.squeeze(tensor_dict['detection_boxes'], [0])
        detection_masks = tf.squeeze(tensor_dict['detection_masks'], [0])
        # Reframe is required to translate mask from box coordinates to image coordinates and fit the image size.
        real_num_detection = tf.cast(tensor_dict['num_detections'][0], tf.int32)
        detection_boxes = tf.slice(detection_boxes, [0, 0], [real_num_detection, -1])
        detection_masks = tf.slice(detection_masks, [0, 0, 0], [real_num_detection, -1, -1])
        detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
            detection_masks, detection_boxes, image.shape[0], image.shape[1])
        detection_masks_reframed = tf.cast(
            tf.greater(detection_masks_reframed, 0.5), tf.uint8)
        # Follow the convention by adding back the batch dimension
        tensor_dict['detection_masks'] = tf.expand_dims(
            detection_masks_reframed, 0)
      image_tensor = tf.compat.v1.get_default_graph().get_tensor_by_name('image_tensor:0')

      # Run inference
      output_dict = sess.run(tensor_dict,
                             feed_dict={image_tensor: np.expand_dims(image, 0)})

      # all outputs are float32 numpy arrays, so convert types as appropriate
      output_dict['num_detections'] = int(output_dict['num_detections'][0])
      output_dict['detection_classes'] = output_dict[
          'detection_classes'][0].astype(np.uint8)
      output_dict['detection_boxes'] = output_dict['detection_boxes'][0]
      output_dict['detection_scores'] = output_dict['detection_scores'][0]
      if 'detection_masks' in output_dict:
        output_dict['detection_masks'] = output_dict['detection_masks'][0]
  return output_dict

# %% [markdown]
# **Load the Volume and Weight Information and Display the Length of the Test Dataset**

# %%
shape = {'ellipsoid':['apple','egg','lemon','orange','peach','plum','qiwi','tomato','mix'],
        'column':['bread','grape','mooncake','sachima'],
        'irregular':['banana','bun','doughnut','fired_dough_twist','litchi','mango','pear']}

def findShape(shapes,exp):
    for k,v in shapes.items():
        for elem in v:
            if exp==elem:
                return k

xls_to_dict={}
xls = pd.ExcelFile("/content/ECUSTFD-resized-/density.xls")

for i in range(20):
    sheetX = xls.parse(i) #2 is the sheet number
    idd = sheetX['id']
    typee = sheetX['type']
    vol = sheetX['volume(mm^3)']
    wei = sheetX['weight(g)']
    if 'mix' in idd[0]:
        xls_to_dict['mix']={}
    else:
        xls_to_dict[typee[0]]={}
    for k in range(len(idd)):
        if 'mix' in idd[0]:
            xls_to_dict['mix'][idd[k]]=[vol[k],wei[k]]
        else:
            xls_to_dict[typee[0]][idd[k]]=[vol[k],wei[k]]

dicSide = defaultdict(list)
dicTop = defaultdict(list)

print(len(TEST_IMAGE_PATHS),"<<<<TEST_IMAGE_PATHS LENGTH")
# Out:
# 338 <<<<TEST_IMAGE_PATHS LENGTH

# %% [markdown]
# **Perform the Object Detection and Visualize Results**

# %%
breaker = 0
cnt = 0
whichh = 'mix'

for image_path in TEST_IMAGE_PATHS:
  cnt+=1
  print(cnt, "<><><numero><><>")
  print(image_path)
  if whichh in image_path:
      continue
  image = Image.open(image_path)
  # the array based representation of the image will be used later in order to prepare the
  # result image with boxes and labels on it.
  image_np = load_image_into_numpy_array(image)

  # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
  image_np_expanded = np.expand_dims(image_np, axis=0)

  # Actual detection.
  output_dict = run_inference_for_single_image(image_np, detection_graph)

  # Visualization of the results of a detection.
  vis_util.visualize_boxes_and_labels_on_image_array(image_np,
                                                     output_dict['detection_boxes'],
                                                     output_dict['detection_classes'],
                                                     output_dict['detection_scores'],
                                                     category_index,
                                                     instance_masks=output_dict.get('detection_masks'),
                                                     use_normalized_coordinates=True,
                                                     line_thickness=8)
  display(Image.fromarray(image_np))
  #plt.figure(figsize=(12, 8))
  #plt.imshow(image_np)
  # Delete the image
  #os.remove(image_path)

# %%
vis_util.visualize_boxes_and_labels_on_image_array(image_np,
                                                     output_dict['detection_boxes'],
                                                     output_dict['detection_classes'],
                                                     output_dict['detection_scores'],
                                                     category_index,
                                                     instance_masks=output_dict.get('detection_masks'),
                                                     use_normalized_coordinates=True,
                                                     line_thickness=8)
display(Image.fromarray(image_np))

# %%
output_dict['detection_classes']
# Out:
# array([20,  1, 19, 14,  1,  6, 12, 16, 15, 16,  4, 10,  5, 17,  2,  6, 11,
#         7, 19,  2,  3, 10,  2, 20,  7,  4, 13,  5, 12,  8, 14,  8, 14,  2,
#         3, 17,  6, 10,  6, 19, 15,  5, 18,  9,  7,  8,  2, 13, 13, 10, 20,
#        17, 17, 18,  3, 10,  9,  8,  1,  7, 19, 13,  5, 10, 14,  2, 17,  9,
#        18, 11,  6,  6,  4, 11, 11, 15,  7,  1, 12, 15, 18,  3,  9, 12,  8,
#        18, 14, 16,  3, 17,  2, 13, 16,  7, 11,  8, 18,  1,  8,  2,  3, 20,
#         5, 13,  9,  1, 12, 10,  7, 12, 19,  9, 14, 17, 15,  7,  2,  6, 17,
#        14, 14,  6, 20,  1,  4, 20, 19, 14,  3,  9, 20, 18,  5,  7, 11, 13,
#         7, 11, 20,  3,  8,  8, 19,  8, 19, 16,  3, 17, 17,  1, 17, 18,  6,
#        19, 15,  9,  4,  8,  3,  7, 20,  4,  6, 11, 17, 13,  9,  4, 10, 12,
#        20, 14,  3,  6, 12,  6, 10,  5, 11, 19, 17, 16,  8, 15,  7, 12, 14,
#        10,  5, 18,  2, 19, 15, 10,  2, 12,  6, 20,  7, 16,  7,  8,  4, 13,
#         6,  6, 20,  5,  1, 11,  6,  8, 17,  4,  7, 14, 14,  2, 19, 15, 18,
#        15,  4,  2,  4,  7,  4, 11, 19, 14, 19, 14,  3, 15, 19, 17,  5, 17,
#         3,  7, 12, 11, 19,  1, 12, 10, 17, 15,  4, 16,  5, 12,  8, 20,  1,
#        12,  2, 18, 10, 14,  6, 20,  6, 14, 15, 11,  1,  7,  8, 10, 20,  2,
#        10,  8, 18, 10, 16,  9,  1,  6, 14,  8,  7, 15,  6,  7, 19, 16, 15,
#         5, 16, 16,  9,  5, 20,  8,  4,  3, 18, 11], dtype=uint8)

# %%
output_dict['detection_boxes'].shape
# Out:
# (300, 4)

# %%
output_dict['detection_scores'].shape
# Out:
# (300,)

# %%
category_index
# Out:
# {1: {'id': 1, 'name': 'apple'},
#  2: {'id': 2, 'name': 'banana'},
#  3: {'id': 3, 'name': 'bread'},
#  4: {'id': 4, 'name': 'bun'},
#  5: {'id': 5, 'name': 'doughnut'},
#  6: {'id': 6, 'name': 'egg'},
#  7: {'id': 7, 'name': 'fired_dough_twist'},
#  8: {'id': 8, 'name': 'grape'},
#  9: {'id': 9, 'name': 'lemon'},
#  10: {'id': 10, 'name': 'litchi'},
#  11: {'id': 11, 'name': 'mango'},
#  12: {'id': 12, 'name': 'mooncake'},
#  13: {'id': 13, 'name': 'orange'},
#  14: {'id': 14, 'name': 'peach'},
#  15: {'id': 15, 'name': 'pear'},
#  16: {'id': 16, 'name': 'plum'},
#  17: {'id': 17, 'name': 'qiwi'},
#  18: {'id': 18, 'name': 'sachima'},
#  19: {'id': 19, 'name': 'tomato'},
#  20: {'id': 20, 'name': 'coin'}}

# %% [markdown]
# ##**Perform Volume Estimation**

# %% [markdown]
# **Obtain the Detected Images Detailed Information for Volume and Calorie Estimation**

# %%
dataset = pd.read_csv('/content/ECUSTFD-resized-/SeeFood/code/volume_estiamtion/mix2csv.csv')
dataset

# %% [markdown]
# **Perform Exploratory Data Analysis on the Dataset**

# %%
# Attempt to read the CSV file with exception handling
try:
    df = pd.read_csv('/content/ECUSTFD-resized-/SeeFood/code/volume_estiamtion/mix2csv.csv')
except FileNotFoundError:
    print("File not found. Please make sure the filename is correct and the file is in the current directory.")
    exit(1)
except Exception as e:
    print("An error occurred while reading the file: {}".format(e))
    exit(1)

# The CSV file has been successfully read into a DataFrame
print("File read successfully!")

# %% [markdown]
# Obtain Statistical Description of the Dataset

# %%
df.describe().T

# %%
print("Summary statistics of the dataset:\n{}".format(df.describe()))

# %% [markdown]
# **Obtain Basic Information About the Dataset**

# %%
print("Dataset shape: {}".format(df.shape))
print("Dataset columns: {}".format(list(df.columns)))
print("Dataset data types:\n{}".format(df.dtypes))

# %% [markdown]
# **Check for Missing values**

# %%
if df.isnull().values.any():
    print("There are missing values in the dataset.")
    print("Number of missing values in each column:\n{}".format(df.isnull().sum()))
else:
     print("There are no missing values in the dataset.")

# %% [markdown]
# **Visualize the Correlation Among Dataset Features**

# %%
# Heatmap of the correlations between numerical variables in the dataset
today = date.today()
try:
    corr = df.select_dtypes(include=['float', 'int']).corr()
    fig, ax = plt.subplots(figsize=(20, 20), facecolor=(1, 1, 1))
    sns.heatmap(corr, annot=True, ax=ax)
    ax.set_title("Heatmap of Correlations Between Numerical Variables", size=15, fontweight='bold')
    plt.xticks(size=5, fontweight='bold')
    plt.yticks(size=5, fontweight='bold')
    plt.annotate(f" {today}.",
                 xy=(1, 1), xycoords='data',
                 xytext=(0.0, -0.10), textcoords='axes fraction',
                 color='black')
    plt.show()

# Handle any exceptions that may occur
except Exception as e:
    print("An error occurred while plotting heatmaps: {}".format(e))
    exit(1)

# %%
# Frequency tables for each categorical variable in the dataset
today = date.today()
try:
    for col in df.select_dtypes(include=['float', 'int']):
        freq_table = pd.DataFrame(df[col].value_counts(normalize=True))
        freq_table.reset_index(inplace=True)
        freq_table.columns = [col, 'proportion']
        fig, ax = plt.subplots(figsize=(10, 5), facecolor=(1, 1, 1))
        sns.barplot(x=col, y='proportion', data=freq_table, ax=ax)
        ax.set_xlabel(col, weight='bold').set_fontsize('18')
        ax.set_ylabel('Proportion', weight='bold').set_fontsize('18')
        ax.set_title("Frequency table of {}".format(col), size = 20, fontweight='bold')
        plt.xticks(rotation=90, size = 8, fontweight='bold')
        plt.yticks(size = 12, fontweight='bold')
        plt.annotate(f"{today}.",
             xy=(1, 1),  xycoords='data',
             xytext=(0.0, -0.10), textcoords='axes fraction',
             color='black')
        plt.show()

# Handle any exceptions that may occur
except Exception as e:
    print("An error occurred while plotting frequency tables: {}".format(e))
    exit(1)

# %% [markdown]
# **Prepare the Data for Machine Learning Modeling**

# %%
dataset = dataset.drop(dataset[dataset['Top_coinForeground_pixel'] < 1000].index)
dataset = dataset.drop(dataset[dataset['Side_coinForeground_pixel'] < 1000].index)
dataset = dataset.drop(dataset[dataset['Top_foodForeground_pixel'] < 1000].index)
dataset = dataset.drop(dataset[dataset['Side_foodForeground_pixel'] < 1000].index)

dataset["top_ratio"] = (dataset['Top_foodHeigth'] * dataset['Top_foodWidth']) / (dataset['Top_coinHeigth'] * dataset['Top_coinWidth'])
dataset['side_ratio'] = (dataset['Side_foodWidth'] * dataset['Side_foodHeigth']) / (dataset['Side_coinHeigth'] * dataset['Side_coinWidth'])
dataset['top_ratio_pixels'] = (dataset['Top_foodForeground_pixel'] / dataset['Top_coinForeground_pixel'])
dataset['side_ratio_pixels'] = (dataset['Side_foodForeground_pixel'] / dataset['Side_coinForeground_pixel'])

dataset['top_coin_ratio'] = 2.5 / ((dataset['Top_coinWidth'] + dataset['Top_coinHeigth']) )
dataset['side_coin_ratio'] = 2.5 / ((dataset['Side_coinWidth'] + dataset['Side_coinHeigth']))

dataset['top_area'] = (dataset['Top_foodHeigth'] * dataset['Top_foodWidth']) * dataset['top_coin_ratio'] * dataset['top_ratio_pixels']
dataset['side_area'] = (dataset['Side_foodHeigth'] * dataset['Side_foodWidth']) * dataset['side_coin_ratio'] * dataset['side_ratio_pixels']
dataset

# %% [markdown]
# **Split the Dataset into 70% Training and 30% Testing Sets**

# %%
from sklearn.model_selection import train_test_split
dataset_train,dataset_test = train_test_split(dataset, test_size=0.3, random_state=42)

test_realCalori = dataset_test['real_calorie'].tolist()
test_reDens = dataset_test['realDensity'].tolist()
test_energy = dataset_test['energy'].tolist()
test_avDens = dataset_test['average_density'].tolist()

dicTrain = { 'apple':0, 'banana':0, 'bread':0, 'bun':0,
        'doughnut':0, 'egg':0, 'fired_dough_twist':0,
        'grape':0, 'lemon':0, 'litchi':0, 'mango':0,
        'mooncake':0, 'orange':0, 'peach':0, 'pear':0,
        'plum':0, 'qiwi':0, 'sachima':0, 'tomato':0 }
dicTest = { 'apple':0, 'banana':0, 'bread':0, 'bun':0,
        'doughnut':0, 'egg':0, 'fired_dough_twist':0,
        'grape':0, 'lemon':0, 'litchi':0, 'mango':0,
        'mooncake':0, 'orange':0, 'peach':0, 'pear':0,
        'plum':0, 'qiwi':0, 'sachima':0, 'tomato':0 }

foods=['apple','egg','lemon','orange','peach','plum','qiwi','tomato','mix',
        'bread','grape','mooncake','sachima','banana','bun','doughnut',
        'fired_dough_twist','litchi','mango','pear']

print(dataset_train, "X_train")

for x_t in dataset_train.iterrows():
    #print(x_t,len(x_t[1]), x_t[1][0])
    dicTrain[foods[int(x_t[1][0])]] += 1
print(dicTrain)

for x_t in dataset_test.iterrows():
    #print(x_t,len(x_t[1]), x_t[1][0])
    dicTest[foods[int(x_t[1][0])]] += 1
print(dicTest)

# %% [markdown]
# **Visulaize the Dataset**

# %%
plt.rcParams.update({'figure.max_open_warning': 0})

names = dicTest.keys()
groupCount = len(names)

fig, ax = plt.subplots()
index = np.arange(groupCount)
bar_width = 0.35
opacity = 0.8

countTest = []
countTrain = []
for elem in names:
    countTest.append(dicTest[elem])
    countTrain.append(dicTrain[elem])

rects1 = plt.barh(index, countTest, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Test')

rects2 = plt.barh(index + bar_width, countTrain, bar_width,
                 alpha=opacity,
                 color='r',
                 label='Train')

ax.set_yticks(index)
ax.set_yticklabels(names)
ax.invert_yaxis()
ax.set_xlabel('Counts')
ax.set_title("Counts of Used Food")
plt.legend()

plt.tight_layout()
#plt.show()

# %% [markdown]
# **Prepare X Training Features and y Target Feature**

# %%
columns_2_drop = ['realVolume', 'realDensity', 'Top_coinWidth',
                            'Top_coinHeigth', 'Side_coinWidth', 'Side_coinHeigth',
                            'real_calorie']

X_train = dataset_train.drop(columns_2_drop, axis=1)
y_train = dataset_train['realVolume']
X_test = dataset_test.drop(columns_2_drop, axis=1)
y_test = dataset_test['realVolume']

# %% [markdown]
# **Normalize the Dataset**

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

x_train_scaled = scaler.fit_transform(X_train)
X_train = pd.DataFrame(x_train_scaled)

x_test_scaled = scaler.fit_transform(X_test)
X_test = pd.DataFrame(x_test_scaled)

X_train

# %%
X_test

# %% [markdown]
# ##**Build the Machine Learning Models to Estimate the Volume and the Calories:**
#
# 1. Decision Tree (DT)
# 2. Random Forest (RF)
# 3. Support Vector Machine (SVM)

# %% [markdown]
# **Define the Evaluation Metrics**

# %%
def CORR(pred, true):
    u = ((true - true.mean(0)) * (pred - pred.mean(0))).sum(0)
    d = np.sqrt(((true - true.mean(0)) ** 2 * (pred - pred.mean(0)) ** 2).sum(0))
    return (u / d).mean(-1)

def MAE(pred, true):
    return np.mean(np.abs(pred - true))

def MSE(pred, true):
    return np.mean((pred - true) ** 2)

def RMSE(pred, true):
    return np.sqrt(MSE(pred, true))

def MAPE(pred, true):
    return np.mean(np.abs((pred - true) / true))

def metric(pred, true):
    #corr = CORR(pred, true)
    mae = MAE(pred, true)
    mse = MSE(pred, true)
    rmse = RMSE(pred, true)
    mape = MAPE(pred, true)

    return mae, mse, rmse, mape

# %% [markdown]
# ###**Build the DT Model**

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.tree import DecisionTreeRegressor
from math import sqrt

dec_tree_reg = DecisionTreeRegressor(random_state=0)
dec_tree_reg.fit(X_train, y_train)

y_pred_dec_tree_reg = dec_tree_reg.predict(X_test)

# %% [markdown]
# **Evaluate, and then Predict Image Volume and Calorie Values**

# %%
# Evaluation of Predicted Volume in terms of all Metrics
mae = MAE(y_test, y_pred_dec_tree_reg)
mse = MSE(y_test, y_pred_dec_tree_reg)
rmse = RMSE(y_test, y_pred_dec_tree_reg)
mape = MAPE(y_test, y_pred_dec_tree_reg)

print('=============================================')
print(f'Predicted Volume Mean Absolute Error: {mae}')
print(f'Predicted Volume Mean Square Error: {mse}')
print(f'Predicted Volume Root Mean Square Error: {rmse}')
print(f'Predicted Volume Mean Absolute Percentage Error: {mape * 100}')
print('==============================================')

countFood = [0] * len(foods)
meanRealVol = [0] * len(foods)
meanEstiamteVol = [0] * len(foods)

meanRealCal = [0] * len(foods)
meanEstiamteCal = [0] * len(foods)

imna = dataset_test['image_name'].tolist()
reVol = y_test.tolist()

pred_calorie = [0] * len(y_pred_dec_tree_reg)

for i in range(len(imna)):

    pred_calorie [i] = test_avDens[i] * test_energy[i] * y_pred_dec_tree_reg[i]
    meanRealCal[imna[i]] += test_realCalori[i]
    meanEstiamteCal[imna[i]] += pred_calorie[i]

    countFood[imna[i]] += 1
    meanRealVol[imna[i]] += reVol[i]
    meanEstiamteVol[imna[i]] += y_pred_dec_tree_reg[i]

# Evaluation of the Predicted Calories in terms of all Metrics
mae = MAE(np.array(test_realCalori), np.array(pred_calorie))
mse = MSE(np.array(test_realCalori), np.array(pred_calorie))
rmse = RMSE(np.array(test_realCalori), np.array(pred_calorie))
mape = MAPE(np.array(test_realCalori), np.array(pred_calorie))

print('=============================================')
print(f'Predicted Calorie Mean Absolute Error: {mae}')
print(f'Predicted Calorie Mean Square Error: {mse}')
print(f'Predicted Calorie Root Mean Square Error: {rmse}')
print(f'Predicted Calorie Mean Absolute Percentage Error: {mape * 100}')
print('==============================================')

# %% [markdown]
# **Visualize Model Real and Predicted Calorie Results**

# %%
# Example model outputs as Python arrays
array1 = np.array(y_test)
array2 = np.array(y_pred_dec_tree_reg)
array3 = np.array(test_realCalori)
array4 = np.array(pred_calorie)

# Create a dictionary to store the arrays as key-value pairs
data = {'Real Volume Value (mm^3)': array1, 'DT Model Predicted Volume (mm^3)': array2,
        'Real Calorie Value (kcal)': array3, 'DT Model Predicted Calorie (kcal)': array4}

# Create a Pandas DataFrame from the dictionary
df = pd.DataFrame(data)
print(df.to_markdown())

# %% [markdown]
# **Visualize the Results**

# %%
from pandas.plotting  import parallel_coordinates
plt.figure(figsize=(15, 10))
parallel_coordinates(dataset_train,'image_name')
plt.title("Paralel Cordinates Plot")
plt.xlabel('Features')
plt.ylabel('Feature Values')
plt.legend(loc=1,prop={'size':15},frameon=True,shadow=True,facecolor='white',edgecolor='black')
plt.show()

from pandas.plotting import andrews_curves
plt.figure(figsize=(15, 10))
andrews_curves(dataset_train,'image_name')
plt.title("Paralel Cordinates Plot")
plt.legend(loc=1,prop={'size':15},frameon=True,shadow=True,facecolor='white',edgecolor='black')
plt.show()

# %% [markdown]
# ###**Build the RF Model**

# %%
random_forest_reg = RandomForestRegressor(random_state=0)
random_forest_reg.fit(X_train, y_train)

y_pred_random_forest_reg = random_forest_reg.predict(X_test)

# %% [markdown]
# **Evaluate, and then Predict Image Volume and Calorie Values**

# %%
# Evaluation of Predicted Volume in terms of all Metrics
mae = MAE(y_test, y_pred_random_forest_reg)
mse = MSE(y_test, y_pred_random_forest_reg)
rmse = RMSE(y_test, y_pred_random_forest_reg)
mape = MAPE(y_test, y_pred_random_forest_reg)

print('=============================================')
print(f'Predicted Volume Mean Absolute Error: {mae}')
print(f'Predicted Volume Mean Square Error: {mse}')
print(f'Predicted Volume Root Mean Square Error: {rmse}')
print(f'Predicted Volume Mean Absolute Percentage Error: {mape * 100}')
print('==============================================')

countFood = [0] * len(foods)
meanRealVol = [0] * len(foods)
meanEstiamteVol = [0] * len(foods)

meanRealCal = [0] * len(foods)
meanEstiamteCal = [0] * len(foods)

imna = dataset_test['image_name'].tolist()
reVol = y_test.tolist()

pred_calorie = [0] * len(y_pred_random_forest_reg)

for i in range(len(imna)):

    pred_calorie [i] = test_avDens[i] * test_energy[i] * y_pred_random_forest_reg[i]
    meanRealCal[imna[i]] += test_realCalori[i]
    meanEstiamteCal[imna[i]] += pred_calorie[i]

    countFood[imna[i]] += 1
    meanRealVol[imna[i]] += reVol[i]
    meanEstiamteVol[imna[i]] += y_pred_random_forest_reg[i]

# Evaluation of the Predicted Calories in terms of all Metrics
mae = MAE(np.array(test_realCalori), np.array(pred_calorie))
mse = MSE(np.array(test_realCalori), np.array(pred_calorie))
rmse = RMSE(np.array(test_realCalori), np.array(pred_calorie))
mape = MAPE(np.array(test_realCalori), np.array(pred_calorie))

print('=============================================')
print(f'Predicted Calorie Mean Absolute Error: {mae}')
print(f'Predicted Calorie Mean Square Error: {mse}')
print(f'Predicted Calorie Root Mean Square Error: {rmse}')
print(f'Predicted Calorie Mean Absolute Percentage Error: {mape * 100}')
print('==============================================')

# %% [markdown]
# **Visualize Model Real and Predicted calorie Results**

# %%
# Example model outputs as Python arrays
array1 = np.array(y_test)
array2 = np.array(y_pred_random_forest_reg)
array3 = np.array(test_realCalori)
array4 = np.array(pred_calorie)

# Create a dictionary to store the arrays as key-value pairs
data = {'Real Volume Value (mm^3)': array1, 'RF Model Predicted Volume (mm^3)': array2,
        'Real Calorie Value (kcal)': array3, 'RF Model Predicted Calorie (kcal)': array4}

# Create a Pandas DataFrame from the dictionary
df = pd.DataFrame(data)
print(df.to_markdown())

# %% [markdown]
# ###**Build the SVM Model**

# %%
# instantiate and fit SVM to train data
svc = SVR(C=1.0, epsilon=0.2)
clf = svc
clf.fit(X_train, y_train)

# check parameters of SVM
clf.get_params()

y_pred_svc = clf.predict(X_test)

# %% [markdown]
# **Evaluate, and then Predict Image Volume and Calorie Values**

# %%
# Evaluation of Predicted Volume in terms of all Metrics
mae = MAE(y_test, y_pred_svc)
mse = MSE(y_test, y_pred_svc)
rmse = RMSE(y_test, y_pred_svc)
mape = MAPE(y_test, y_pred_svc)

print('=============================================')
print(f'Predicted Volume Mean Absolute Error: {mae}')
print(f'Predicted Volume Mean Square Error: {mse}')
print(f'Predicted Volume Root Mean Square Error: {rmse}')
print(f'Predicted Volume Mean Absolute Percentage Error: {mape * 100}')
print('==============================================')

countFood = [0] * len(foods)
meanRealVol = [0] * len(foods)
meanEstiamteVol = [0] * len(foods)

meanRealCal = [0] * len(foods)
meanEstiamteCal = [0] * len(foods)

imna = dataset_test['image_name'].tolist()
reVol = y_test.tolist()

pred_calorie = [0] * len(y_pred_svc)

for i in range(len(imna)):

    pred_calorie [i] = test_avDens[i] * test_energy[i] * y_pred_svc[i]
    meanRealCal[imna[i]] += test_realCalori[i]
    meanEstiamteCal[imna[i]] += pred_calorie[i]

    countFood[imna[i]] += 1
    meanRealVol[imna[i]] += reVol[i]
    meanEstiamteVol[imna[i]] += y_pred_svc[i]

# Evaluation of the Predicted Calories in terms of all Metrics
mae = MAE(np.array(test_realCalori), np.array(pred_calorie))
mse = MSE(np.array(test_realCalori), np.array(pred_calorie))
rmse = RMSE(np.array(test_realCalori), np.array(pred_calorie))
mape = MAPE(np.array(test_realCalori), np.array(pred_calorie))

print('=============================================')
print(f'Predicted Calorie Mean Absolute Error: {mae}')
print(f'Predicted Calorie Mean Square Error: {mse}')
print(f'Predicted Calorie Root Mean Square Error: {rmse}')
print(f'Predicted Calorie Mean Absolute Percentage Error: {mape * 100}')
print('==============================================')

# %% [markdown]
# **Visualize Model Real and Predicted calorie Results**

# %%
# Example model outputs as Python arrays
array1 = np.array(y_test)
array2 = np.array(y_pred_svc)
array3 = np.array(test_realCalori)
array4 = np.array(pred_calorie)

# Create a dictionary to store the arrays as key-value pairs
data = {'Real Volume Value (mm^3)': array1, 'SVM Model Predicted Volume (mm^3)': array2,
        'Real Calorie Value (kcal)': array3, 'SVM Model Predicted Calorie (kcal)': array4}

# Create a Pandas DataFrame from the dictionary
df = pd.DataFrame(data)
print(df.to_markdown())

# %% [markdown]
# ###**Evaluate all Models Performance in terms of different Metrics**

# %%
today = date.today()
DT = [70.061217137772, 58578.77581258899, 242.03052661304727, 19.283757848679606]
RF = [61.64918045092737, 40362.488294178744, 200.90417689579962, 16.11765006181976]
SVM = [131.69196993093632, 125055.40151127253, 353.6317314824456, 36.53613367087476]

N = 4
x = np.arange(N)
c = ['red', 'orange', 'blue']
width = 0.5

# Set position of bar on X axis
r1 = np.arange(0, len(DT) * 3, 3)
r2 = [x + width for x in r1]
r3 = [x + width for x in r2]

plt.figure(figsize=(15, 8))
plt.clf()
#plt.style.use('fivethirtyeight')
plt.ylabel("Error", weight='bold').set_fontsize('17')
plt.bar(r1, DT, width, edgecolor='white', label='Decision Tree')
plt.bar(r2, RF, width, edgecolor='white', label='Random Forest')
plt.bar(r3, SVM, width, edgecolor='white', label='Support Vector Machine')
plt.xlabel('METRICS', weight='bold').set_fontsize('22')
plt.xticks([r + width for r in range(0, len(DT) * 3, 3)], ['MAE', 'MSE', 'RMSE', 'MAPE (%)'], rotation=45, size = 15, fontweight='bold')
plt.title('Performance Comparison of Calorie Predictions Between Models', size = 18, fontweight='bold')
plt.legend(loc = 'best', bbox_to_anchor = (1.0, 1.0), ncol = 1, fontsize = '15',
           fancybox=True, framealpha=1, shadow=True, borderpad=1)
plt.grid(True)
plt.yscale('log')
plt.annotate(f"Bassey Kalu {today}.",
             xy=(1, 1),  xycoords='data',
             xytext=(0, -0.40), textcoords='axes fraction',
             color='black')
plt.savefig('Performance Comparison of Predictions Between Models.png')
